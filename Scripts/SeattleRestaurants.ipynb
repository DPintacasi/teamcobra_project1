# %%
#Dependencies & setup
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import gmaps
import os
import json
import pprint

#Import yelp API key
from config import yelp_api

# Import Google API key
from config import google_key

# %%
# read in seattle zip csv
seattle_zips = pd.read_csv("./Resources/seattle_zipcodes.csv")
# drop last line (citation)
seattle_zips.drop(seattle_zips.tail(1).index,inplace=True)
#rename column header
seattle_zips = seattle_zips.rename(columns={"Seattle":"zipcode"})
seattle_zips.head(5)

# %%
# create empty lists for data
name = []
city = []
latitude = []
longitude = []
zipcode = []
ethnicity = []
price = []
rating = []

# %% [markdown]
# *Each Yelp API call will return max 50 results.  Therefore, I will do a separate query for each ethnicity, create a list of each json dictionary & append to create a "master" dataframe

# %%
# type/ethnicity of food is stored in yelp API under "categories:alias -- MUST BE ONE WORD!"
ethnicity = ['chinese','french','greek','indian','italian','japanese','brazilian','mexican','new american','soul food','thai']
# YELP base URL
endpoint = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_api}
params = {"term": "restaurants", "location": "seattle", "limit": 50, "categories": "chinese"}
#max results per call is 50, so add offset param ("offset" = 50, 100, etc.) to get full list per ethnicity
#"limit": 50

# Pretty Print the output of JSON data
chinese1_response = requests.get(url=endpoint, headers=headers, params=params).json()
print(chinese1_response["total"])
print(json.dumps(chinese1_response, indent=4, sort_keys=True))

# %%
# type/ethnicity of food is stored in yelp API under "categories:alias -- MUST BE ONE WORD!"
#ethnicity = ['chinese','french','greek','indian','italian','japanese','brazilian','mexican','new american','soul food','thai']

# YELP base URL
endpoint = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_api}
params = {"term": "restaurants", "location": "seattle", "limit": 50, "offset": 50, "categories": "chinese"}
#max results per call is 50, so add offset param ("offset": 50, 100, etc.) to get full list per ethnicity
#"limit": 50

# Pretty Print the output of JSON data
chinese2_response = requests.get(url=endpoint, headers=headers, params=params).json()
#print(chinese2_response["total"])
#print(json.dumps(chinese1_response, indent=4, sort_keys=True))

# %%
# type/ethnicity of food is stored in yelp API under "categories:alias -- MUST BE ONE WORD!"
#ethnicity = ['chinese','french','greek','indian','italian','japanese','brazilian','mexican','new american','soul food','thai']

# YELP base URL
endpoint = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_api}
params = {"term": "restaurants", "location": "seattle", "limit": 50, "offset": 100, "categories": "chinese"}
#max results per call is 50, so add offset param ("offset": 50, 100, etc.) to get full list per ethnicity
#"limit": 50

# Pretty Print the output of JSON data
chinese3_response = requests.get(url=endpoint, headers=headers, params=params).json()
#print(chinese3_response["total"])
#print(json.dumps(chinese1_response, indent=4, sort_keys=True))

# %%
# type/ethnicity of food is stored in yelp API under "categories:alias -- MUST BE ONE WORD!"
#ethnicity = ['chinese','french','greek','indian','italian','japanese','brazilian','mexican','new american','soul food','thai']

# YELP base URL
endpoint = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_api}
params = {"term": "restaurants", "location": "seattle", "limit": 50, "offset": 150, "categories": "chinese"}
#max results per call is 50, so add offset param ("offset": 50, 100, etc.) to get full list per ethnicity
#"limit": 50

# Pretty Print the output of JSON data
chinese4_response = requests.get(url=endpoint, headers=headers, params=params).json()
#print(chinese4_response["total"])
#print(json.dumps(chinese1_response, indent=4, sort_keys=True))

# %%
# type/ethnicity of food is stored in yelp API under "categories:alias -- MUST BE ONE WORD!"
ethnicity = ['chinese','french','greek','indian','italian','japanese','brazilian','mexican','new american','soul food','thai']
# YELP base URL
endpoint = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_api}
params = {"term": "restaurants", "location": "seattle", "limit": 50, "categories": "french"}
#max results per call is 50, so add offset param ("offset" = 50, 100, etc.) to get full list per ethnicity
#"limit": 50

# Pretty Print the output of JSON data
french_response = requests.get(url=endpoint, headers=headers, params=params).json()
print(french_response["total"])
#print(json.dumps(french_response, indent=4, sort_keys=True))

# %%
# type/ethnicity of food is stored in yelp API under "categories:alias -- MUST BE ONE WORD!"
ethnicity = ['chinese','french','greek','indian','italian','japanese','brazilian','mexican','new american','soul food','thai']
# YELP base URL
endpoint = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_api}
params = {"term": "restaurants", "location": "seattle", "limit": 50, "categories": "greek"}
#max results per call is 50, so add offset param ("offset" = 50, 100, etc.) to get full list per ethnicity
#"limit": 50

# Pretty Print the output of JSON data
greek_response = requests.get(url=endpoint, headers=headers, params=params).json()
print(greek_response["total"])
#print(json.dumps(greek_response, indent=4, sort_keys=True))

# %%
# type/ethnicity of food is stored in yelp API under "categories:alias -- MUST BE ONE WORD!"
ethnicity = ['chinese','french','greek','indian','italian','japanese','brazilian','mexican','new american','soul food','thai']
# YELP base URL
endpoint = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_api}
params = {"term": "restaurants", "location": "seattle", "limit": 50, "offset": 50, "categories": "greek"}
#max results per call is 50, so add offset param ("offset" = 50, 100, etc.) to get full list per ethnicity
#"limit": 50

# Pretty Print the output of JSON data
greek2_response = requests.get(url=endpoint, headers=headers, params=params).json()
#print(greek2_response["total"])
#print(json.dumps(greek_response, indent=4, sort_keys=True))

# %%
# # type/ethnicity of food is stored in yelp API under "categories:alias -- MUST BE ONE WORD!"
# ethnicity = ['chinese','french','greek','indian','italian','japanese','brazilian','mexican','new american','soul food','thai']
# # YELP base URL
# endpoint = 'https://api.yelp.com/v3/businesses/search'
# headers = {'Authorization': 'Bearer %s' % yelp_api}
# params = {"term": "restaurants", "location": "seattle", "limit": 50, "categories": "indian"}
# #max results per call is 50, so add offset param ("offset" = 50, 100, etc.) to get full list per ethnicity
# #"limit": 50

# # Pretty Print the output of JSON data
# indian_response = requests.get(url=endpoint, headers=headers, params=params).json()
# print(indian_response["total"])
# #print(json.dumps(indian_response, indent=4, sort_keys=True))

# %%
# type/ethnicity of food is stored in yelp API under "categories:alias -- MUST BE ONE WORD!"
ethnicity = ['chinese','french','greek','indian','italian','japanese','brazilian','mexican','new american','soul food','thai']
# YELP base URL
endpoint = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_api}
params = {"term": "restaurants", "location": "seattle", "limit": 50, "categories": "italian"}
#max results per call is 50, so add offset param ("offset" = 50, 100, etc.) to get full list per ethnicity
#"limit": 50

# Pretty Print the output of JSON data
italian1_response = requests.get(url=endpoint, headers=headers, params=params).json()
print(italian1_response["total"])
#print(json.dumps(italian1_response, indent=4, sort_keys=True))

# %%
# type/ethnicity of food is stored in yelp API under "categories:alias -- MUST BE ONE WORD!"
ethnicity = ['chinese','french','greek','indian','italian','japanese','brazilian','mexican','new american','soul food','thai']
# YELP base URL
endpoint = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_api}
params = {"term": "restaurants", "location": "seattle", "limit": 50, "categories": "italian"}
#max results per call is 50, so add offset param ("offset" = 50, 100, etc.) to get full list per ethnicity
#"limit": 50

# Pretty Print the output of JSON data
italian2_response = requests.get(url=endpoint, headers=headers, params=params).json()
#print(italian2_response["total"])
#print(json.dumps(italian2_response, indent=4, sort_keys=True))

# %%
# type/ethnicity of food is stored in yelp API under "categories:alias -- MUST BE ONE WORD!"
ethnicity = ['chinese','french','greek','indian','italian','japanese','brazilian','mexican','new american','soul food','thai']
# YELP base URL
endpoint = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_api}
params = {"term": "restaurants", "location": "seattle", "limit": 50, "categories": "italian"}
#max results per call is 50, so add offset param ("offset" = 50, 100, etc.) to get full list per ethnicity
#"limit": 50

# Pretty Print the output of JSON data
italian3_response = requests.get(url=endpoint, headers=headers, params=params).json()
#print(italian3_response["total"])
#print(json.dumps(italian3_response, indent=4, sort_keys=True))

# %%
# type/ethnicity of food is stored in yelp API under "categories:alias -- MUST BE ONE WORD!"
ethnicity = ['chinese','french','greek','indian','italian','japanese','brazilian','mexican','new american','soul food','thai']
# YELP base URL
endpoint = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_api}
params = {"term": "restaurants", "location": "seattle", "limit": 50, "categories": "italian"}
#max results per call is 50, so add offset param ("offset" = 50, 100, etc.) to get full list per ethnicity
#"limit": 50

# Pretty Print the output of JSON data
italian4_response = requests.get(url=endpoint, headers=headers, params=params).json()
#print(italian4_response["total"])
#print(json.dumps(italian1_response, indent=4, sort_keys=True))

# %%
# type/ethnicity of food is stored in yelp API under "categories:alias -- MUST BE ONE WORD!"
ethnicity = ['chinese','french','greek','indian','italian','japanese','brazilian','mexican','new american','soul food','thai']
# YELP base URL
endpoint = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_api}
params = {"term": "restaurants", "location": "seattle", "limit": 50, "categories": "japanese"}
#max results per call is 50, so add offset param ("offset": 50, 100, etc.) to get full list per ethnicity
#"limit": 50

# Pretty Print the output of JSON data
japanese1_response = requests.get(url=endpoint, headers=headers, params=params).json()
print(japanese1_response["total"])
#print(json.dumps(japanese1_response, indent=4, sort_keys=True))

# %%
# type/ethnicity of food is stored in yelp API under "categories:alias -- MUST BE ONE WORD!"
ethnicity = ['chinese','french','greek','indian','italian','japanese','brazilian','mexican','new american','soul food','thai']
# YELP base URL
endpoint = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_api}
params = {"term": "restaurants", "location": "seattle", "limit": 50, "offset": 50, "categories": "japanese"}
#max results per call is 50, so add offset param ("offset": 50, 100, etc.) to get full list per ethnicity
#"limit": 50

# Pretty Print the output of JSON data
japanese2_response = requests.get(url=endpoint, headers=headers, params=params).json()
#print(japanese2_response["total"])
#print(json.dumps(japanese2_response, indent=4, sort_keys=True))
# Out:
# 222

# %%
# type/ethnicity of food is stored in yelp API under "categories:alias -- MUST BE ONE WORD!"
ethnicity = ['chinese','french','greek','indian','italian','japanese','brazilian','mexican','new american','soul food','thai']
# YELP base URL
endpoint = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_api}
params = {"term": "restaurants", "location": "seattle", "limit": 50, "offset": 100, "categories": "japanese"}
#max results per call is 50, so add offset param ("offset": 50, 100, etc.) to get full list per ethnicity
#"limit": 50

# Pretty Print the output of JSON data
japanese3_response = requests.get(url=endpoint, headers=headers, params=params).json()
#print(japanese3_response["total"])
#print(json.dumps(japanese1_response, indent=4, sort_keys=True))
# Out:
# 222

# %%
# type/ethnicity of food is stored in yelp API under "categories:alias -- MUST BE ONE WORD!"
ethnicity = ['chinese','french','greek','indian','italian','japanese','brazilian','mexican','new american','soul food','thai']
# YELP base URL
endpoint = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_api}
params = {"term": "restaurants", "location": "seattle", "limit": 50, "offset": 150, "categories": "japanese"}
#max results per call is 50, so add offset param ("offset": 50, 100, etc.) to get full list per ethnicity
#"limit": 50

# Pretty Print the output of JSON data
japanese4_response = requests.get(url=endpoint, headers=headers, params=params).json()
#print(japanese4_response["total"])
#print(json.dumps(japanese4_response, indent=4, sort_keys=True))
# Out:
# 222

# %%
# type/ethnicity of food is stored in yelp API under "categories:alias -- MUST BE ONE WORD!"
ethnicity = ['chinese','french','greek','indian','italian','japanese','brazilian','mexican','new american','soul food','thai']
# YELP base URL
endpoint = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_api}
params = {"term": "restaurants", "location": "seattle", "limit": 50, "offset": 200, "categories": "japanese"}
#max results per call is 50, so add offset param ("offset": 50, 100, etc.) to get full list per ethnicity
#"limit": 50

# Pretty Print the output of JSON data
japanese5_response = requests.get(url=endpoint, headers=headers, params=params).json()
#print(japanese5_response["total"])
#print(json.dumps(japanese1_response, indent=4, sort_keys=True))
# Out:
# 222

# %%
# type/ethnicity of food is stored in yelp API under "categories:alias -- MUST BE ONE WORD!"
ethnicity = ['chinese','french','greek','indian','italian','japanese','brazilian','mexican','new american','soul food','thai']
# YELP base URL
endpoint = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_api}
params = {"term": "restaurants", "location": "seattle", "limit": 50, "categories": "brazilian"}
#max results per call is 50, so add offset param ("offset": 50, 100, etc.) to get full list per ethnicity
#"limit": 50

# Pretty Print the output of JSON data
brazilian_response = requests.get(url=endpoint, headers=headers, params=params).json()
print(brazilian_response["total"])
#print(json.dumps(brazilian_response, indent=4, sort_keys=True))
# Out:
# 5
# {
#     "businesses": [
#         {
#             "alias": "botteco-brazil-shoreline",
#             "categories": [
#                 {
#                     "alias": "steak",
#                     "title": "Steakhouses"
#                 },
#                 {
#                     "alias": "brazilian",
#                     "title": "Brazilian"
#                 },
#                 {
#                     "alias": "chickenshop",
#                     "title": "Chicken Shop"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.735442,
#                 "longitude": -122.292885
#             },
#             "display_phone": "(206) 466-2445",
#             "distance": 12641.515894964647,
#             "id": "33Hs4HKANsdWsMYdkCSc8g",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/BScRLjqY9zDpApBuH5rfow/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "14561 Bothell Way NE",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Shoreline",
#                 "country": "US",
#                 "display_address": [
#                     "14561 Bothell Way NE",
#                     "Shoreline, WA 98155"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98155"
#             },
#             "name": "Botteco Brazil",
#             "phone": "+12064662445",
#             "rating": 4.5,
#             "review_count": 4,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/botteco-brazil-shoreline?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "the-grill-from-ipanema-seattle",
#             "categories": [
#                 {
#                     "alias": "brazilian",
#                     "title": "Brazilian"
#                 },
#                 {
#                     "alias": "steak",
#                     "title": "Steakhouses"
#                 },
#                 {
#                     "alias": "buffets",
#                     "title": "Buffets"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.61358,
#                 "longitude": -122.34719
#             },
#             "display_phone": "(206) 457-4885",
#             "distance": 1587.725786924837,
#             "id": "nhRCkR9FY1OTpw-bv1u5Aw",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/hiMxdExN6errVs_1GKYMaQ/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "2313 1st Ave",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "2313 1st Ave",
#                     "Seattle, WA 98121"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98121"
#             },
#             "name": "The Grill From Ipanema",
#             "phone": "+12064574885",
#             "price": "$$$",
#             "rating": 4.0,
#             "review_count": 975,
#             "transactions": [
#                 "delivery",
#                 "pickup",
#                 "restaurant_reservation"
#             ],
#             "url": "https://www.yelp.com/biz/the-grill-from-ipanema-seattle?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "fogo-de-chao-brazilian-steakhouse-bellevue-9",
#             "categories": [
#                 {
#                     "alias": "brazilian",
#                     "title": "Brazilian"
#                 },
#                 {
#                     "alias": "steak",
#                     "title": "Steakhouses"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.614539,
#                 "longitude": -122.201278
#             },
#             "display_phone": "(425) 450-4004",
#             "distance": 10133.22271442756,
#             "id": "pLKi8-z4yj07mWoUj5Dfyw",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/XUL6kJ5A-SLBTHSH4ZxRFQ/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "440 Bellevue Way NE",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Bellevue",
#                 "country": "US",
#                 "display_address": [
#                     "440 Bellevue Way NE",
#                     "Bellevue, WA 98004"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98004"
#             },
#             "name": "Fogo de Chao Brazilian Steakhouse",
#             "phone": "+14254504004",
#             "price": "$$$",
#             "rating": 4.0,
#             "review_count": 721,
#             "transactions": [
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/fogo-de-chao-brazilian-steakhouse-bellevue-9?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "tropical-berry-seattle",
#             "categories": [
#                 {
#                     "alias": "acaibowls",
#                     "title": "Acai Bowls"
#                 },
#                 {
#                     "alias": "brazilian",
#                     "title": "Brazilian"
#                 },
#                 {
#                     "alias": "juicebars",
#                     "title": "Juice Bars & Smoothies"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.69044026351096,
#                 "longitude": -122.29109047237584
#             },
#             "display_phone": "(206) 582-1291",
#             "distance": 7958.717578519253,
#             "id": "vFIEBT9IeFM1CCcpnLRn1Q",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/ojXCdAjEvcloryPV6XFXXA/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "8505 35th Ave NE",
#                 "address2": null,
#                 "address3": null,
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "8505 35th Ave NE",
#                     "Seattle, WA 98115"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98115"
#             },
#             "name": "Tropical Berry",
#             "phone": "+12065821291",
#             "rating": 4.5,
#             "review_count": 6,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/tropical-berry-seattle?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "novilhos-brazilian-steak-house-bellevue-2",
#             "categories": [
#                 {
#                     "alias": "steak",
#                     "title": "Steakhouses"
#                 },
#                 {
#                     "alias": "brazilian",
#                     "title": "Brazilian"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.57702,
#                 "longitude": -122.17298
#             },
#             "display_phone": "(425) 603-1111",
#             "distance": 13309.275382942971,
#             "id": "ULznZoVOyFb2mrYGV0ULsA",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/0wxG_TnoJ1pf6npXcQOV0Q/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "12405 SE 38th St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Bellevue",
#                 "country": "US",
#                 "display_address": [
#                     "12405 SE 38th St",
#                     "Bellevue, WA 98006"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98006"
#             },
#             "name": "Novilhos Brazilian Steak House",
#             "phone": "+14256031111",
#             "price": "$$$",
#             "rating": 3.5,
#             "review_count": 971,
#             "transactions": [
#                 "delivery",
#                 "pickup",
#                 "restaurant_reservation"
#             ],
#             "url": "https://www.yelp.com/biz/novilhos-brazilian-steak-house-bellevue-2?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         }
#     ],
#     "region": {
#         "center": {
#             "latitude": 47.62541904760501,
#             "longitude": -122.33551025390625
#         }
#     },
#     "total": 5
# }

# %%
# type/ethnicity of food is stored in yelp API under "categories:alias -- MUST BE ONE WORD!"
ethnicity = ['chinese','french','greek','indian','italian','japanese','brazilian','mexican','new american','soul food','thai']
# YELP base URL
endpoint = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_api}
params = {"term": "restaurants", "location": "seattle", "limit": 50, "categories": "thai"}
#max results per call is 50, so add offset param ("offset": 50, 100, etc.) to get full list per ethnicity
#"limit": 50

# Pretty Print the output of JSON data
thai_response = requests.get(url=endpoint, headers=headers, params=params).json()
print(thai_response["total"])
#print(json.dumps(thai_response, indent=4, sort_keys=True))
# Out:
# 150

# %%
# type/ethnicity of food is stored in yelp API under "categories:alias -- MUST BE ONE WORD!"
ethnicity = ['chinese','french','greek','indian','italian','japanese','brazilian','mexican','new american','soul food','thai']
# YELP base URL
endpoint = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_api}
params = {"term": "restaurants", "location": "seattle", "limit": 50, "offset": 50, "categories": "thai"}
#max results per call is 50, so add offset param ("offset": 50, 100, etc.) to get full list per ethnicity
#"limit": 50

# Pretty Print the output of JSON data
thai2_response = requests.get(url=endpoint, headers=headers, params=params).json()
#print(thai2_response["total"])
#print(json.dumps(thai_response, indent=4, sort_keys=True))
# Out:
# 150

# %%
# type/ethnicity of food is stored in yelp API under "categories:alias -- MUST BE ONE WORD!"
ethnicity = ['chinese','french','greek','indian','italian','japanese','brazilian','mexican','new american','soul food','thai']
# YELP base URL
endpoint = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_api}
params = {"term": "restaurants", "location": "seattle", "limit": 50, "offset": 100, "categories": "thai"}
#max results per call is 50, so add offset param ("offset": 50, 100, etc.) to get full list per ethnicity
#"limit": 50

# Pretty Print the output of JSON data
thai3_response = requests.get(url=endpoint, headers=headers, params=params).json()
#print(thai3_response["total"])
#print(json.dumps(thai_response, indent=4, sort_keys=True))
# Out:
# 150

# %%
# type/ethnicity of food is stored in yelp API under "categories:alias -- MUST BE ONE WORD!"
ethnicity = ['chinese','french','greek','indian','italian','japanese','brazilian','mexican','new american','soul food','thai']
# YELP base URL
endpoint = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_api}
params = {"term": "restaurants", "location": "seattle", "limit": 50, "categories": "mexican"}
#max results per call is 50, so add offset param ("offset": 50, 100, etc.) to get full list per ethnicity
#"limit": 50

# Pretty Print the output of JSON data
mexican1_response = requests.get(url=endpoint, headers=headers, params=params).json()
print(mexican1_response["total"])
#print(json.dumps(mexican1_response, indent=4, sort_keys=True))
# Out:
# 261
# {
#     "businesses": [
#         {
#             "alias": "man-vs-fries-seattle-2",
#             "categories": [
#                 {
#                     "alias": "mexican",
#                     "title": "Mexican"
#                 },
#                 {
#                     "alias": "popuprestaurants",
#                     "title": "Pop-Up Restaurants"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.619533,
#                 "longitude": -122.3473513
#             },
#             "display_phone": "",
#             "distance": 1109.992476597566,
#             "id": "d0cad0b3PtXKfn1rgjsB3g",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/kInsHWMxbJJnf2Hh-9eVYg/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "130 5th Ave N",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "130 5th Ave N",
#                     "Seattle, WA 98109"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98109"
#             },
#             "name": "Man vs Fries",
#             "phone": "",
#             "rating": 4.0,
#             "review_count": 35,
#             "transactions": [
#                 "pickup",
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/man-vs-fries-seattle-2?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "fog\u00f3n-cocina-mexicana-seattle-2",
#             "categories": [
#                 {
#                     "alias": "mexican",
#                     "title": "Mexican"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.6154187,
#                 "longitude": -122.3241733
#             },
#             "display_phone": "(206) 320-7777",
#             "distance": 1399.4662463735258,
#             "id": "JQAKcOzObl2I7vLKZLkBdQ",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/M1D-cy7HIwyvvO0deCjyDA/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "600 E Pine St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "600 E Pine St",
#                     "Seattle, WA 98122"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98122"
#             },
#             "name": "Fog\u00f3n Cocina Mexicana",
#             "phone": "+12063207777",
#             "price": "$$",
#             "rating": 4.5,
#             "review_count": 1511,
#             "transactions": [
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/fog%C3%B3n-cocina-mexicana-seattle-2?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "asadero-ballard-seattle",
#             "categories": [
#                 {
#                     "alias": "mexican",
#                     "title": "Mexican"
#                 },
#                 {
#                     "alias": "steak",
#                     "title": "Steakhouses"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.66687,
#                 "longitude": -122.38282
#             },
#             "display_phone": "(206) 659-4499",
#             "distance": 5813.068535874572,
#             "id": "j2maiRNh_ErcsvPBiZCkqw",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/ngG8hHkMv2K6yNKIo-1Tfw/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "5405 Leary Ave NW",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "5405 Leary Ave NW",
#                     "Seattle, WA 98107"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98107"
#             },
#             "name": "Asadero Ballard",
#             "phone": "+12066594499",
#             "price": "$$",
#             "rating": 4.5,
#             "review_count": 672,
#             "transactions": [
#                 "pickup",
#                 "restaurant_reservation",
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/asadero-ballard-seattle?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "cactus-restaurants-seattle-3",
#             "categories": [
#                 {
#                     "alias": "tex-mex",
#                     "title": "Tex-Mex"
#                 },
#                 {
#                     "alias": "mexican",
#                     "title": "Mexican"
#                 },
#                 {
#                     "alias": "newmexican",
#                     "title": "New Mexican Cuisine"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.621798,
#                 "longitude": -122.336944
#             },
#             "display_phone": "(206) 913-2250",
#             "distance": 416.7328861024687,
#             "id": "waU7h3jwePqPuZo-OIgaGg",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/l4ooBb4ln0BqwtNSmxb5sA/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "350 Terry Ave N",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "350 Terry Ave N",
#                     "Seattle, WA 98109"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98109"
#             },
#             "name": "Cactus Restaurants",
#             "phone": "+12069132250",
#             "price": "$$",
#             "rating": 4.0,
#             "review_count": 782,
#             "transactions": [
#                 "pickup",
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/cactus-restaurants-seattle-3?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "el-grito-taqueria-seattle",
#             "categories": [
#                 {
#                     "alias": "mexican",
#                     "title": "Mexican"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.62069,
#                 "longitude": -122.33398
#             },
#             "display_phone": "(206) 659-4552",
#             "distance": 540.6320473729891,
#             "id": "wV2lc3dOoIHRT_SfmEohtA",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/LQdTUiJZ42WMsErbrPnimg/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "234 Fairview Ave N",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "234 Fairview Ave N",
#                     "Seattle, WA 98109"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98109"
#             },
#             "name": "El Grito Taqueria",
#             "phone": "+12066594552",
#             "price": "$$",
#             "rating": 4.0,
#             "review_count": 179,
#             "transactions": [
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/el-grito-taqueria-seattle?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "tacos-chukis-seattle-5",
#             "categories": [
#                 {
#                     "alias": "tacos",
#                     "title": "Tacos"
#                 },
#                 {
#                     "alias": "sandwiches",
#                     "title": "Sandwiches"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.6270336126469,
#                 "longitude": -122.342103158844
#             },
#             "display_phone": "(206) 518-9025",
#             "distance": 525.6876927552172,
#             "id": "nwrKWcWG1_g8nyUaaUwqlA",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/huHHXRboy1-VPKK376t8zw/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "832 Dexter Ave N",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "832 Dexter Ave N",
#                     "Seattle, WA 98109"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98109"
#             },
#             "name": "Tacos Chukis",
#             "phone": "+12065189025",
#             "price": "$",
#             "rating": 4.5,
#             "review_count": 408,
#             "transactions": [
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/tacos-chukis-seattle-5?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "tacos-chukis-seattle",
#             "categories": [
#                 {
#                     "alias": "mexican",
#                     "title": "Mexican"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.620570445175,
#                 "longitude": -122.321262359619
#             },
#             "display_phone": "(206) 905-8537",
#             "distance": 1196.2087504042854,
#             "id": "pzjQKP3PEkclhSD-mFn7jA",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/AU2LRinK4hKGU7nnCTq73Q/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "219 Broadway E",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "219 Broadway E",
#                     "Seattle, WA 98102"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98102"
#             },
#             "name": "Tacos Chukis",
#             "phone": "+12069058537",
#             "price": "$",
#             "rating": 4.5,
#             "review_count": 1724,
#             "transactions": [
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/tacos-chukis-seattle?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "man-vs-fries-seattle",
#             "categories": [
#                 {
#                     "alias": "mexican",
#                     "title": "Mexican"
#                 },
#                 {
#                     "alias": "popuprestaurants",
#                     "title": "Pop-Up Restaurants"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.6591899,
#                 "longitude": -122.3850448
#             },
#             "display_phone": "",
#             "distance": 5279.3955605040355,
#             "id": "LCiJZkDsKmML9fkN2gZUzw",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/a6f4NKLwi7kv0FQSLENvPA/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "4253 22nd Ave W",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "4253 22nd Ave W",
#                     "Seattle, WA 98199"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98199"
#             },
#             "name": "Man vs Fries",
#             "phone": "",
#             "rating": 4.0,
#             "review_count": 28,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/man-vs-fries-seattle?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "d-la-santa-seattle",
#             "categories": [
#                 {
#                     "alias": "mexican",
#                     "title": "Mexican"
#                 },
#                 {
#                     "alias": "steak",
#                     "title": "Steakhouses"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.64123,
#                 "longitude": -122.3202
#             },
#             "display_phone": "(206) 709-2222",
#             "distance": 2095.1433117626225,
#             "id": "B9QnfF7SF5aYoph_ijDObQ",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/osutj41yQGbbfaX5ngfYnQ/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "2359 10th Ave E",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "2359 10th Ave E",
#                     "Seattle, WA 98102"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98102"
#             },
#             "name": "D' La Santa",
#             "phone": "+12067092222",
#             "price": "$$",
#             "rating": 4.5,
#             "review_count": 291,
#             "transactions": [
#                 "pickup",
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/d-la-santa-seattle?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "el-mezcalito-seattle",
#             "categories": [
#                 {
#                     "alias": "mexican",
#                     "title": "Mexican"
#                 },
#                 {
#                     "alias": "bars",
#                     "title": "Bars"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.63777,
#                 "longitude": -122.35717
#             },
#             "display_phone": "(206) 216-4446",
#             "distance": 2136.3463763015543,
#             "id": "FdXeE401B1cVGnjLYu85zg",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/J2XIgkQOpXELPAHyhAxvww/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "2123 Queen Anne Ave N",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "2123 Queen Anne Ave N",
#                     "Seattle, WA 98109"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98109"
#             },
#             "name": "El Mezcalito",
#             "phone": "+12062164446",
#             "price": "$$",
#             "rating": 4.0,
#             "review_count": 378,
#             "transactions": [
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/el-mezcalito-seattle?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "la-palmera-family-restaurant-seattle",
#             "categories": [
#                 {
#                     "alias": "mexican",
#                     "title": "Mexican"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.62437,
#                 "longitude": -122.33943
#             },
#             "display_phone": "(206) 453-4403",
#             "distance": 333.90527640364166,
#             "id": "t2b3RRs-tjOg-_TZd66mVQ",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/T7bOGgCg-0oVOj9GWjlEYg/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "901 Mercer St",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "901 Mercer St",
#                     "Seattle, WA 98109"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98109"
#             },
#             "name": "La Palmera Family Restaurant",
#             "phone": "+12064534403",
#             "price": "$$",
#             "rating": 4.0,
#             "review_count": 77,
#             "transactions": [
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/la-palmera-family-restaurant-seattle?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "carmelos-tacos-seattle-2",
#             "categories": [
#                 {
#                     "alias": "tacos",
#                     "title": "Tacos"
#                 },
#                 {
#                     "alias": "foodstands",
#                     "title": "Food Stands"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.6188713536994,
#                 "longitude": -122.325116639028
#             },
#             "display_phone": "(206) 659-0159",
#             "distance": 1066.2470620133345,
#             "id": "edzGkH9Fd0chJbiTCDqq1A",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/lKT5a6P108hrtYrMxHEIQQ/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "110 Summit Ave E",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "110 Summit Ave E",
#                     "Seattle, WA 98102"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98102"
#             },
#             "name": "Carmelo's Tacos",
#             "phone": "+12066590159",
#             "price": "$",
#             "rating": 4.5,
#             "review_count": 286,
#             "transactions": [
#                 "pickup",
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/carmelos-tacos-seattle-2?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "sal-y-limon-seattle-3",
#             "categories": [
#                 {
#                     "alias": "mexican",
#                     "title": "Mexican"
#                 },
#                 {
#                     "alias": "bars",
#                     "title": "Bars"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.62506,
#                 "longitude": -122.35619
#             },
#             "display_phone": "(206) 283-7878",
#             "distance": 1550.3110400532755,
#             "id": "AN4L1f5yQF0wW-J97JSceg",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/OaGQRctQE_4m0KQ5vwMD9A/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "10 Mercer St",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "10 Mercer St",
#                     "Seattle, WA 98109"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98109"
#             },
#             "name": "Sal Y Limon",
#             "phone": "+12062837878",
#             "price": "$$",
#             "rating": 4.5,
#             "review_count": 232,
#             "transactions": [
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/sal-y-limon-seattle-3?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "tacontainer-seattle",
#             "categories": [
#                 {
#                     "alias": "foodstands",
#                     "title": "Food Stands"
#                 },
#                 {
#                     "alias": "tacos",
#                     "title": "Tacos"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.5807253995165,
#                 "longitude": -122.4062986373634
#             },
#             "display_phone": "",
#             "distance": 7270.874895540841,
#             "id": "GpAVasbtf4Q61Ql0vZFonA",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/uXfsgAFcVYePTzk37N33fw/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "2530 Alki Ave SW",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "2530 Alki Ave SW",
#                     "Seattle, WA 98116"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98116"
#             },
#             "name": "Tacontainer",
#             "phone": "",
#             "rating": 4.5,
#             "review_count": 5,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/tacontainer-seattle?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "al-bacha-restaurant-seattle",
#             "categories": [
#                 {
#                     "alias": "mediterranean",
#                     "title": "Mediterranean"
#                 },
#                 {
#                     "alias": "greek",
#                     "title": "Greek"
#                 },
#                 {
#                     "alias": "mexican",
#                     "title": "Mexican"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.6186249211818,
#                 "longitude": -122.321042440631
#             },
#             "display_phone": "(206) 413-5870",
#             "distance": 1321.5508077906234,
#             "id": "6cGW6DTYtkv2KAx4dsRKxQ",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/DV8LXtAscNacZPUNQLGmcA/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "1833 Broadway",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "1833 Broadway",
#                     "Seattle, WA 98122"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98122"
#             },
#             "name": "Al Bacha Restaurant",
#             "phone": "+12064135870",
#             "price": "$$",
#             "rating": 4.5,
#             "review_count": 108,
#             "transactions": [
#                 "pickup",
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/al-bacha-restaurant-seattle?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "casco-antiguo-seattle-5",
#             "categories": [
#                 {
#                     "alias": "mexican",
#                     "title": "Mexican"
#                 },
#                 {
#                     "alias": "bars",
#                     "title": "Bars"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.6162165470038,
#                 "longitude": -122.339313138024
#             },
#             "display_phone": "(206) 257-1182",
#             "distance": 1040.0238642112165,
#             "id": "M64un1ge4i0r_ri5wdOHvA",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/PwaCdWRP0JunXfNN3-3Bzg/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "2102 7th Ave",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "2102 7th Ave",
#                     "Seattle, WA 98121"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98121"
#             },
#             "name": "Casco Antiguo",
#             "phone": "+12062571182",
#             "price": "$$",
#             "rating": 3.5,
#             "review_count": 81,
#             "transactions": [
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/casco-antiguo-seattle-5?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "red-star-taco-bar-seattle",
#             "categories": [
#                 {
#                     "alias": "mexican",
#                     "title": "Mexican"
#                 },
#                 {
#                     "alias": "cocktailbars",
#                     "title": "Cocktail Bars"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.6514130785983,
#                 "longitude": -122.351609878242
#             },
#             "display_phone": "(206) 258-3087",
#             "distance": 3132.003793288908,
#             "id": "WqQKSw8YEyyImnbzggmG5w",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/gqhsth9aeO0utC-5n6L1jQ/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "513 N 36th St",
#                 "address2": "Ste E",
#                 "address3": "",
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "513 N 36th St",
#                     "Ste E",
#                     "Seattle, WA 98103"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98103"
#             },
#             "name": "Red Star Taco Bar",
#             "phone": "+12062583087",
#             "price": "$$",
#             "rating": 4.0,
#             "review_count": 337,
#             "transactions": [
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/red-star-taco-bar-seattle?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "taqueria-cantina-seattle",
#             "categories": [
#                 {
#                     "alias": "mexican",
#                     "title": "Mexican"
#                 },
#                 {
#                     "alias": "cocktailbars",
#                     "title": "Cocktail Bars"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.615886,
#                 "longitude": -122.350166
#             },
#             "display_phone": "(206) 995-8588",
#             "distance": 1530.2895069913675,
#             "id": "rVj2n1kfQ6BsR-x0KABZAg",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/62MVY7iRFCrrrBrRxGAEaQ/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "2630 1st Ave",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "2630 1st Ave",
#                     "Seattle, WA 98121"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98121"
#             },
#             "name": "Taqueria Cantina",
#             "phone": "+12069958588",
#             "price": "$$",
#             "rating": 4.0,
#             "review_count": 419,
#             "transactions": [
#                 "pickup",
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/taqueria-cantina-seattle?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "bounty-kitchen-denny-triangle-seattle",
#             "categories": [
#                 {
#                     "alias": "breakfast_brunch",
#                     "title": "Breakfast & Brunch"
#                 },
#                 {
#                     "alias": "tacos",
#                     "title": "Tacos"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.616505,
#                 "longitude": -122.337623
#             },
#             "display_phone": "(206) 602-6045",
#             "distance": 1003.3686866148538,
#             "id": "1I6YoO6ALgu-IEG4It9ekw",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/Mj1VW4ghGFrLOb3clvA29g/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "801 Lenora St",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "801 Lenora St",
#                     "Seattle, WA 98121"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98121"
#             },
#             "name": "Bounty Kitchen Denny Triangle",
#             "phone": "+12066026045",
#             "price": "$$",
#             "rating": 4.5,
#             "review_count": 72,
#             "transactions": [
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/bounty-kitchen-denny-triangle-seattle?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "cactus-restaurants-seattle",
#             "categories": [
#                 {
#                     "alias": "tex-mex",
#                     "title": "Tex-Mex"
#                 },
#                 {
#                     "alias": "mexican",
#                     "title": "Mexican"
#                 },
#                 {
#                     "alias": "newmexican",
#                     "title": "New Mexican Cuisine"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.636175,
#                 "longitude": -122.2776929
#             },
#             "display_phone": "(206) 324-4140",
#             "distance": 4494.57991878981,
#             "id": "58cEuMDzyS2TkDm_oYEROQ",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/VWUon_XD8l9kWeGFO9Uegg/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "4220 E Madison St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "4220 E Madison St",
#                     "Seattle, WA 98112"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98112"
#             },
#             "name": "Cactus Restaurants",
#             "phone": "+12063244140",
#             "price": "$$",
#             "rating": 4.0,
#             "review_count": 517,
#             "transactions": [
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/cactus-restaurants-seattle?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "moderno-mexicano-seattle-2",
#             "categories": [
#                 {
#                     "alias": "mexican",
#                     "title": "Mexican"
#                 },
#                 {
#                     "alias": "cocktailbars",
#                     "title": "Cocktail Bars"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.61160333,
#                 "longitude": -122.34095167
#             },
#             "display_phone": "(206) 443-0899",
#             "distance": 1600.491865395324,
#             "id": "8Xb8xruotfuSmCGBAnLl8A",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/FhhpuKm3JvPDL5zGHmAbhw/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "1920A 2nd Ave",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "1920A 2nd Ave",
#                     "Seattle, WA 98101"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98101"
#             },
#             "name": "Moderno Mexicano",
#             "phone": "+12064430899",
#             "price": "$$",
#             "rating": 4.0,
#             "review_count": 100,
#             "transactions": [
#                 "pickup",
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/moderno-mexicano-seattle-2?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "cactus-restaurants-seattle-2",
#             "categories": [
#                 {
#                     "alias": "tex-mex",
#                     "title": "Tex-Mex"
#                 },
#                 {
#                     "alias": "mexican",
#                     "title": "Mexican"
#                 },
#                 {
#                     "alias": "newmexican",
#                     "title": "New Mexican Cuisine"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.578254,
#                 "longitude": -122.412888
#             },
#             "display_phone": "(206) 933-6000",
#             "distance": 7822.329228762279,
#             "id": "ye3n048GGn9Nl7X9jAQOwg",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/LFEuS2uK-8UARjrfJnONFg/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "2820 Alki Ave Sw",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "2820 Alki Ave Sw",
#                     "Seattle, WA 98116"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98116"
#             },
#             "name": "Cactus Restaurants",
#             "phone": "+12069336000",
#             "price": "$$",
#             "rating": 4.0,
#             "review_count": 833,
#             "transactions": [
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/cactus-restaurants-seattle-2?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "la-cocina-oaxaquena-seattle",
#             "categories": [
#                 {
#                     "alias": "mexican",
#                     "title": "Mexican"
#                 },
#                 {
#                     "alias": "bars",
#                     "title": "Bars"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.6154747009277,
#                 "longitude": -122.328178405762
#             },
#             "display_phone": "(206) 623-8226",
#             "distance": 1243.4473905147036,
#             "id": "dyN-UDqTKMk9lnv99DBbhw",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/X1Nc8XnQ6aqi3SXseOLQ8Q/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "1216 Pine St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "1216 Pine St",
#                     "Seattle, WA 98101"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98101"
#             },
#             "name": "La Cocina Oaxaquena",
#             "phone": "+12066238226",
#             "price": "$$",
#             "rating": 4.0,
#             "review_count": 485,
#             "transactions": [
#                 "pickup",
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/la-cocina-oaxaquena-seattle?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "pablo-y-pablo-seattle",
#             "categories": [
#                 {
#                     "alias": "mexican",
#                     "title": "Mexican"
#                 },
#                 {
#                     "alias": "cocktailbars",
#                     "title": "Cocktail Bars"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.64793,
#                 "longitude": -122.33855
#             },
#             "display_phone": "(206) 973-3505",
#             "distance": 2509.999055295642,
#             "id": "1xKrv2QFYV-5A83fOUtlOQ",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/XToSYl1Dj1nJImpxvnaZ9w/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "1605 N 34th St",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "1605 N 34th St",
#                     "Seattle, WA 98103"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98103"
#             },
#             "name": "Pablo y Pablo",
#             "phone": "+12069733505",
#             "price": "$$",
#             "rating": 3.5,
#             "review_count": 332,
#             "transactions": [
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/pablo-y-pablo-seattle?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "uncle-panchos-food-truck-seattle",
#             "categories": [
#                 {
#                     "alias": "foodtrucks",
#                     "title": "Food Trucks"
#                 },
#                 {
#                     "alias": "tacos",
#                     "title": "Tacos"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.66866,
#                 "longitude": -122.37815
#             },
#             "display_phone": "(206) 735-7055",
#             "distance": 5695.5914081054425,
#             "id": "HK4molP31sJg_RGouLvjIw",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/0CqiQ5Vzq1b8YmN3I9hkTg/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": null,
#                 "address2": null,
#                 "address3": null,
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "Seattle, WA 98107"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98107"
#             },
#             "name": "Uncle Pancho's Food Truck",
#             "phone": "+12067357055",
#             "rating": 5.0,
#             "review_count": 6,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/uncle-panchos-food-truck-seattle?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "la-josies-seattle-2",
#             "categories": [
#                 {
#                     "alias": "mexican",
#                     "title": "Mexican"
#                 },
#                 {
#                     "alias": "cocktailbars",
#                     "title": "Cocktail Bars"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.61424,
#                 "longitude": -122.32477
#             },
#             "display_phone": "(206) 535-7168",
#             "distance": 1475.779181089445,
#             "id": "U8d7_YR1JfKZ_ywJEFrn2Q",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/t5_C6TeD9D_5mAzE3e6X7Q/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "514 E Pike St",
#                 "address2": null,
#                 "address3": null,
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "514 E Pike St",
#                     "Seattle, WA 98122"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98122"
#             },
#             "name": "La Josie's",
#             "phone": "+12065357168",
#             "rating": 4.5,
#             "review_count": 13,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/la-josies-seattle-2?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "carnitas-michoacan-seattle-2",
#             "categories": [
#                 {
#                     "alias": "tacos",
#                     "title": "Tacos"
#                 },
#                 {
#                     "alias": "latin",
#                     "title": "Latin American"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.58083,
#                 "longitude": -122.31394
#             },
#             "display_phone": "(206) 323-3688",
#             "distance": 5220.00878419919,
#             "id": "N2E6bOyKqwHWClwVTYPaEA",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/GTdDtHcYEHHSoOFvNIvvrg/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "2503 Beacon Ave S",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "2503 Beacon Ave S",
#                     "Seattle, WA 98144"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98144"
#             },
#             "name": "Carnitas Michoacan",
#             "phone": "+12063233688",
#             "price": "$",
#             "rating": 4.5,
#             "review_count": 138,
#             "transactions": [
#                 "pickup",
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/carnitas-michoacan-seattle-2?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "el-legendario-mexican-restaurant-seattle",
#             "categories": [
#                 {
#                     "alias": "mexican",
#                     "title": "Mexican"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.6630959404654,
#                 "longitude": -122.347594946623
#             },
#             "display_phone": "(206) 539-9731",
#             "distance": 4286.177935486444,
#             "id": "2dJiZfjTjNayPiey0AAo2Q",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/1w9fT3zg4oO_b0eW7b-rZg/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "4705 Aurora Ave N",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "4705 Aurora Ave N",
#                     "Seattle, WA 98103"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98103"
#             },
#             "name": "El Legendario Mexican Restaurant",
#             "phone": "+12065399731",
#             "price": "$$",
#             "rating": 4.0,
#             "review_count": 174,
#             "transactions": [
#                 "pickup",
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/el-legendario-mexican-restaurant-seattle?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "la-carta-de-oaxaca-seattle",
#             "categories": [
#                 {
#                     "alias": "mexican",
#                     "title": "Mexican"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.66806,
#                 "longitude": -122.38577
#             },
#             "display_phone": "(206) 782-8722",
#             "distance": 6058.746485768122,
#             "id": "s4TBcqOpkoZnjnyGmO_7_w",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/emF93uUIPUtGXUPvD2M0EQ/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "5431 Ballard Ave NW",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "5431 Ballard Ave NW",
#                     "Seattle, WA 98107"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98107"
#             },
#             "name": "La Carta de Oaxaca",
#             "phone": "+12067828722",
#             "price": "$$",
#             "rating": 4.0,
#             "review_count": 1273,
#             "transactions": [
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/la-carta-de-oaxaca-seattle?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "cocina-oaxaca-seattle-2",
#             "categories": [
#                 {
#                     "alias": "mexican",
#                     "title": "Mexican"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.6857307252324,
#                 "longitude": -122.337145201195
#             },
#             "display_phone": "(206) 729-0980",
#             "distance": 6707.46304984547,
#             "id": "bKuX7i96PXUUg-3PdPXWzg",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/qWNwZQA6ZAoByeALARnmSw/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "7900 E Green Lake Dr N",
#                 "address2": "Ste 107",
#                 "address3": null,
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "7900 E Green Lake Dr N",
#                     "Ste 107",
#                     "Seattle, WA 98115"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98115"
#             },
#             "name": "Cocina Oaxaca",
#             "phone": "+12067290980",
#             "price": "$$",
#             "rating": 4.5,
#             "review_count": 89,
#             "transactions": [
#                 "pickup",
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/cocina-oaxaca-seattle-2?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "el-coste\u00f1o-seattle",
#             "categories": [
#                 {
# ...
#                 "latitude": 47.60022,
#                 "longitude": -122.33131
#             },
#             "display_phone": "(206) 914-5992",
#             "distance": 2817.5578442272936,
#             "id": "SkkJng4iLrfP5cU-U9Y-Ag",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/Jl4v8y2u0ETbOU2AUBU4pQ/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "240 2nd Ave S",
#                 "address2": "",
#                 "address3": "Flatstick Pub",
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "240 2nd Ave S",
#                     "Flatstick Pub",
#                     "Seattle, WA 98104"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98104"
#             },
#             "name": "Manu's Tacos",
#             "phone": "+12069145992",
#             "price": "$",
#             "rating": 4.0,
#             "review_count": 35,
#             "transactions": [
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/manus-tacos-seattle?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "tnt-taqueria-seattle",
#             "categories": [
#                 {
#                     "alias": "mexican",
#                     "title": "Mexican"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.6615085566491,
#                 "longitude": -122.332939538228
#             },
#             "display_phone": "(206) 322-0124",
#             "distance": 4017.5845514886028,
#             "id": "Nm0amaHjKa97jR-PeJq6Zw",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/CqExfjtvH5y7ykrM5XsM9A/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "2114 N 45th St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "2114 N 45th St",
#                     "Seattle, WA 98103"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98103"
#             },
#             "name": "TNT Taqueria",
#             "phone": "+12063220124",
#             "price": "$",
#             "rating": 4.0,
#             "review_count": 442,
#             "transactions": [
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/tnt-taqueria-seattle?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "la-tienda-mexicana-el-oaxaque-seattle",
#             "categories": [
#                 {
#                     "alias": "mexican",
#                     "title": "Mexican"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.5626077028691,
#                 "longitude": -122.313647026018
#             },
#             "display_phone": "(206) 762-2218",
#             "distance": 7174.136541533936,
#             "id": "2ALmjpeJj0tiPw8U6CGXfg",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/w-tYJP5vxlEfZRlsEHIAvw/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "4515 15th Ave S",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "4515 15th Ave S",
#                     "Seattle, WA 98108"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98108"
#             },
#             "name": "La Tienda Mexicana El Oaxaque",
#             "phone": "+12067622218",
#             "price": "$",
#             "rating": 4.5,
#             "review_count": 8,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/la-tienda-mexicana-el-oaxaque-seattle?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "agua-verde-cafe-seattle",
#             "categories": [
#                 {
#                     "alias": "mexican",
#                     "title": "Mexican"
#                 },
#                 {
#                     "alias": "venues",
#                     "title": "Venues & Event Spaces"
#                 },
#                 {
#                     "alias": "breakfast_brunch",
#                     "title": "Breakfast & Brunch"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.65161,
#                 "longitude": -122.31441
#             },
#             "display_phone": "(206) 545-8570",
#             "distance": 3311.812688622327,
#             "id": "Y_smWaJnZrOT3-uRBGkgLA",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/6f-9uGnJmGXk7B3m8GjJsA/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "1303 NE Boat St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "1303 NE Boat St",
#                     "Seattle, WA 98105"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98105"
#             },
#             "name": "Agua Verde Cafe",
#             "phone": "+12065458570",
#             "price": "$$",
#             "rating": 3.5,
#             "review_count": 994,
#             "transactions": [
#                 "pickup",
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/agua-verde-cafe-seattle?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "el-farol-mexican-restaurant-seattle",
#             "categories": [
#                 {
#                     "alias": "mexican",
#                     "title": "Mexican"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.62296,
#                 "longitude": -122.31288
#             },
#             "display_phone": "(206) 325-9005",
#             "distance": 1722.7130599574452,
#             "id": "ZNXRhAwOqfUWhwBHloLZJA",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/euoq1lWFhF-wdfyUBSxFQg/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "1467 E Republican St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "1467 E Republican St",
#                     "Seattle, WA 98112"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98112"
#             },
#             "name": "El Farol Mexican Restaurant",
#             "phone": "+12063259005",
#             "price": "$$",
#             "rating": 4.0,
#             "review_count": 185,
#             "transactions": [
#                 "pickup",
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/el-farol-mexican-restaurant-seattle?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "mas-cafe-seattle",
#             "categories": [
#                 {
#                     "alias": "coffee",
#                     "title": "Coffee & Tea"
#                 },
#                 {
#                     "alias": "mexican",
#                     "title": "Mexican"
#                 },
#                 {
#                     "alias": "breakfast_brunch",
#                     "title": "Breakfast & Brunch"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.648195,
#                 "longitude": -122.334589
#             },
#             "display_phone": "(206) 420-4623",
#             "distance": 2533.3121378634523,
#             "id": "Dz2iqMDZyGA50g9VXT89QA",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/iwdcjU3mJhqwdGSSlOoxgQ/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "1906 N 34th St",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "1906 N 34th St",
#                     "Seattle, WA 98103"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98103"
#             },
#             "name": "Mas Cafe",
#             "phone": "+12064204623",
#             "rating": 4.5,
#             "review_count": 15,
#             "transactions": [
#                 "pickup",
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/mas-cafe-seattle?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "el-borracho-seattle",
#             "categories": [
#                 {
#                     "alias": "mexican",
#                     "title": "Mexican"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.60934,
#                 "longitude": -122.34076
#             },
#             "display_phone": "(206) 538-0440",
#             "distance": 1832.000010794913,
#             "id": "1MPANypfo13kepMxUEfJ1A",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/8B9nNUb2-pk11MwK1JXcQw/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "1521 1st Ave",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "1521 1st Ave",
#                     "Seattle, WA 98101"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98101"
#             },
#             "name": "El Borracho",
#             "phone": "+12065380440",
#             "price": "$$",
#             "rating": 3.5,
#             "review_count": 818,
#             "transactions": [
#                 "pickup",
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/el-borracho-seattle?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "guanacos-tacos-pupuseria-seattle",
#             "categories": [
#                 {
#                     "alias": "salvadoran",
#                     "title": "Salvadoran"
#                 },
#                 {
#                     "alias": "tacos",
#                     "title": "Tacos"
#                 },
#                 {
#                     "alias": "gluten_free",
#                     "title": "Gluten-Free"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.65714142901622,
#                 "longitude": -122.3140288
#             },
#             "display_phone": "(206) 547-2369",
#             "distance": 3877.16600344353,
#             "id": "USoCUrnuGw1mwzVpo_dlmA",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/slOoO4gSe-OTfN9z6v4mnA/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "4106 Brooklyn Ave NE",
#                 "address2": "Ste 102A",
#                 "address3": "",
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "4106 Brooklyn Ave NE",
#                     "Ste 102A",
#                     "Seattle, WA 98105"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98105"
#             },
#             "name": "Guanaco's Tacos Pupuseria",
#             "phone": "+12065472369",
#             "price": "$$",
#             "rating": 4.0,
#             "review_count": 337,
#             "transactions": [
#                 "pickup",
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/guanacos-tacos-pupuseria-seattle?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "pecado-bueno-seattle-5",
#             "categories": [
#                 {
#                     "alias": "mexican",
#                     "title": "Mexican"
#                 },
#                 {
#                     "alias": "breakfast_brunch",
#                     "title": "Breakfast & Brunch"
#                 },
#                 {
#                     "alias": "diners",
#                     "title": "Diners"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.64122,
#                 "longitude": -122.32552
#             },
#             "display_phone": "(206) 687-7423",
#             "distance": 1915.5889944760565,
#             "id": "7DPYPiqvGluEN_UXHTBhTQ",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/rva6j5KIcHORtpox1xi2eQ/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "2356 Eastlake Ave E",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "2356 Eastlake Ave E",
#                     "Seattle, WA 98102"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98102"
#             },
#             "name": "Pecado Bueno",
#             "phone": "+12066877423",
#             "price": "$$",
#             "rating": 3.5,
#             "review_count": 109,
#             "transactions": [
#                 "pickup",
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/pecado-bueno-seattle-5?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "pecado-bueno-seattle-6",
#             "categories": [
#                 {
#                     "alias": "mexican",
#                     "title": "Mexican"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.6592445373535,
#                 "longitude": -122.350311279297
#             },
#             "display_phone": "(206) 457-8837",
#             "distance": 3921.4405624471983,
#             "id": "bu5AlZ9P93829vbmAk97iw",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/j0jL0mAK901HdIKbk66ssQ/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "4307 Fremont Ave N",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "4307 Fremont Ave N",
#                     "Seattle, WA 98103"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98103"
#             },
#             "name": "Pecado Bueno",
#             "phone": "+12064578837",
#             "price": "$$",
#             "rating": 3.5,
#             "review_count": 540,
#             "transactions": [
#                 "pickup",
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/pecado-bueno-seattle-6?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         }
#     ],
#     "region": {
#         "center": {
#             "latitude": 47.62541904760501,
#             "longitude": -122.33551025390625
#         }
#     },
#     "total": 261
# }

# %%
# type/ethnicity of food is stored in yelp API under "categories:alias -- MUST BE ONE WORD!"
ethnicity = ['chinese','french','greek','indian','italian','japanese','brazilian','mexican','new american','soul food','thai']
# YELP base URL
endpoint = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_api}
params = {"term": "restaurants", "location": "seattle", "limit": 50, "offset": 50, "categories": "mexican"}
#max results per call is 50, so add offset param ("offset": 50, 100, etc.) to get full list per ethnicity
#"limit": 50

# Pretty Print the output of JSON data
mexican2_response = requests.get(url=endpoint, headers=headers, params=params).json()
#print(mexican2_response["total"])
#print(json.dumps(mexican1_response, indent=4, sort_keys=True))

# %%
# type/ethnicity of food is stored in yelp API under "categories:alias -- MUST BE ONE WORD!"
ethnicity = ['chinese','french','greek','indian','italian','japanese','brazilian','mexican','new american','soul food','thai']
# YELP base URL
endpoint = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_api}
params = {"term": "restaurants", "location": "seattle", "limit": 50, "offset": 100, "categories": "mexican"}
#max results per call is 50, so add offset param ("offset": 50, 100, etc.) to get full list per ethnicity
#"limit": 50

# Pretty Print the output of JSON data
mexican3_response = requests.get(url=endpoint, headers=headers, params=params).json()
#print(mexican3_response["total"])
#print(json.dumps(mexican1_response, indent=4, sort_keys=True))

# %%
# type/ethnicity of food is stored in yelp API under "categories:alias -- MUST BE ONE WORD!"
ethnicity = ['chinese','french','greek','indian','italian','japanese','brazilian','mexican','new american','soul food','thai']
# YELP base URL
endpoint = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_api}
params = {"term": "restaurants", "location": "seattle", "limit": 50, "offset": 150, "categories": "mexican"}
#max results per call is 50, so add offset param ("offset": 50, 100, etc.) to get full list per ethnicity
#"limit": 50

# Pretty Print the output of JSON data
mexican4_response = requests.get(url=endpoint, headers=headers, params=params).json()
#print(mexican4_response["total"])
#print(json.dumps(mexican1_response, indent=4, sort_keys=True))

# %%
# type/ethnicity of food is stored in yelp API under "categories:alias -- MUST BE ONE WORD!"
ethnicity = ['chinese','french','greek','indian','italian','japanese','brazilian','mexican','new american','soul food','thai']
# YELP base URL
endpoint = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_api}
params = {"term": "restaurants", "location": "seattle", "limit": 50, "offset": 200, "categories": "mexican"}
#max results per call is 50, so add offset param ("offset": 50, 100, etc.) to get full list per ethnicity
#"limit": 50

# Pretty Print the output of JSON data
mexican5_response = requests.get(url=endpoint, headers=headers, params=params).json()
#print(mexican5_response["total"])
#print(json.dumps(mexican1_response, indent=4, sort_keys=True))

# %%
# type/ethnicity of food is stored in yelp API under "categories:alias -- MUST BE ONE WORD!"
ethnicity = ['chinese','french','greek','indian','italian','japanese','brazilian','mexican','new american','soul food','thai']
# YELP base URL
endpoint = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_api}
params = {"term": "restaurants", "location": "seattle", "limit": 50, "offset": 250, "categories": "mexican"}
#max results per call is 50, so add offset param ("offset": 50, 100, etc.) to get full list per ethnicity
#"limit": 50

# Pretty Print the output of JSON data
mexican6_response = requests.get(url=endpoint, headers=headers, params=params).json()
#print(mexican6_response["total"])
#print(json.dumps(mexican1_response, indent=4, sort_keys=True))

# %%
# type/ethnicity of food is stored in yelp API under "categories:alias -- MUST BE ONE WORD!"
ethnicity = ['chinese','french','greek','indian','italian','japanese','brazilian','mexican','new american','soul food','thai']
# YELP base URL
endpoint = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_api}
params = {"term": "restaurants", "location": "seattle", "limit": 50, "categories": "soulfood"}
#max results per call is 50, so add offset param ("offset": 50, 100, etc.) to get full list per ethnicity
#"limit": 50

# Pretty Print the output of JSON data
soulfood_response = requests.get(url=endpoint, headers=headers, params=params).json()
print(soulfood_response["total"])
#print(json.dumps(soulfood_response, indent=4, sort_keys=True))
# Out:
# 12
# {
#     "businesses": [
#         {
#             "alias": "fats-fried-chicken-and-waffles-seattle",
#             "categories": [
#                 {
#                     "alias": "southern",
#                     "title": "Southern"
#                 },
#                 {
#                     "alias": "soulfood",
#                     "title": "Soul Food"
#                 },
#                 {
#                     "alias": "waffles",
#                     "title": "Waffles"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.6081253897776,
#                 "longitude": -122.296459855298
#             },
#             "display_phone": "(206) 602-6863",
#             "distance": 3502.1747233188867,
#             "id": "WZbZ8h_60QMQvO4vpIWpxQ",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/BfBidhqNi2U5kjGennd5KA/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "2726 E Cherry St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "2726 E Cherry St",
#                     "Seattle, WA 98122"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98122"
#             },
#             "name": "Fat's Fried Chicken & Waffles",
#             "phone": "+12066026863",
#             "price": "$$",
#             "rating": 4.5,
#             "review_count": 595,
#             "transactions": [
#                 "delivery",
#                 "pickup"
#             ],
#             "url": "https://www.yelp.com/biz/fats-fried-chicken-and-waffles-seattle?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "simply-soulful-seattle",
#             "categories": [
#                 {
#                     "alias": "desserts",
#                     "title": "Desserts"
#                 },
#                 {
#                     "alias": "soulfood",
#                     "title": "Soul Food"
#                 },
#                 {
#                     "alias": "southern",
#                     "title": "Southern"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.624083,
#                 "longitude": -122.294851
#             },
#             "display_phone": "(206) 474-9841",
#             "distance": 3050.763799502014,
#             "id": "scZE9CoorAjDPO4CiVTRHg",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/ZdyvtonFE82JHpnw_svtjA/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "2909-B E Madison Ave",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "2909-B E Madison Ave",
#                     "Seattle, WA 98112"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98112"
#             },
#             "name": "Simply Soulful",
#             "phone": "+12064749841",
#             "price": "$$",
#             "rating": 4.5,
#             "review_count": 314,
#             "transactions": [
#                 "delivery",
#                 "pickup"
#             ],
#             "url": "https://www.yelp.com/biz/simply-soulful-seattle?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "where-ya-at-matt-seattle",
#             "categories": [
#                 {
#                     "alias": "cajun",
#                     "title": "Cajun/Creole"
#                 },
#                 {
#                     "alias": "soulfood",
#                     "title": "Soul Food"
#                 },
#                 {
#                     "alias": "foodtrucks",
#                     "title": "Food Trucks"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.6032409667969,
#                 "longitude": -122.328681945801
#             },
#             "display_phone": "",
#             "distance": 2664.033451734304,
#             "id": "2l1vbc9zwpyTwzywo8Y17Q",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/wrvIrTzZyfItE9K-XkNbXA/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "Seattle, WA 98104"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98104"
#             },
#             "name": "Where Ya At Matt",
#             "phone": "",
#             "price": "$$",
#             "rating": 4.0,
#             "review_count": 306,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/where-ya-at-matt-seattle?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "island-soul-rum-bar-and-soul-shack-seattle",
#             "categories": [
#                 {
#                     "alias": "caribbean",
#                     "title": "Caribbean"
#                 },
#                 {
#                     "alias": "bars",
#                     "title": "Bars"
#                 },
#                 {
#                     "alias": "soulfood",
#                     "title": "Soul Food"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.55812,
#                 "longitude": -122.28544
#             },
#             "display_phone": "(206) 329-1202",
#             "distance": 8372.147532633484,
#             "id": "IsWM7BrvfZgZfZnC22_64w",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/LE_5YmHQn9G0u3fsXbWVbQ/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "4869 Rainier Ave S",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "4869 Rainier Ave S",
#                     "Seattle, WA 98118"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98118"
#             },
#             "name": "Island Soul Rum Bar & Soul Shack",
#             "phone": "+12063291202",
#             "price": "$$",
#             "rating": 4.0,
#             "review_count": 862,
#             "transactions": [
#                 "delivery",
#                 "pickup"
#             ],
#             "url": "https://www.yelp.com/biz/island-soul-rum-bar-and-soul-shack-seattle?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "soulful-dishes-seattle",
#             "categories": [
#                 {
#                     "alias": "soulfood",
#                     "title": "Soul Food"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.60181,
#                 "longitude": -122.30876
#             },
#             "display_phone": "(206) 485-7123",
#             "distance": 3303.778343211855,
#             "id": "Yh8ws9L4Ss-3QOdYXOH5ZA",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/G43s4x7ODId0122sG4jPow/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "1800 E Yesler Way",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "1800 E Yesler Way",
#                     "Seattle, WA 98122"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98122"
#             },
#             "name": "Soulful Dishes",
#             "phone": "+12064857123",
#             "rating": 4.0,
#             "review_count": 36,
#             "transactions": [
#                 "delivery",
#                 "pickup"
#             ],
#             "url": "https://www.yelp.com/biz/soulful-dishes-seattle?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "soul-seattle-2",
#             "categories": [
#                 {
#                     "alias": "catering",
#                     "title": "Caterers"
#                 },
#                 {
#                     "alias": "fooddeliveryservices",
#                     "title": "Food Delivery Services"
#                 },
#                 {
#                     "alias": "soulfood",
#                     "title": "Soul Food"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.651101,
#                 "longitude": -122.3504901
#             },
#             "display_phone": "(206) 395-9668",
#             "distance": 3068.337060267142,
#             "id": "MU4MCsnWEIY8WxlRFnD9wA",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/gy6yVeHNZ4A3z5FfN4CFRw/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "3518 Fremont Pl N",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "3518 Fremont Pl N",
#                     "Seattle, WA 98103"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98103"
#             },
#             "name": "Soul",
#             "phone": "+12063959668",
#             "rating": 4.0,
#             "review_count": 1,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/soul-seattle-2?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "communion-restaurant-and-bar-seattle",
#             "categories": [
#                 {
#                     "alias": "soulfood",
#                     "title": "Soul Food"
#                 },
#                 {
#                     "alias": "soup",
#                     "title": "Soup"
#                 },
#                 {
#                     "alias": "cocktailbars",
#                     "title": "Cocktail Bars"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.61315,
#                 "longitude": -122.30157
#             },
#             "display_phone": "(206) 391-8140",
#             "distance": 2912.0980666108767,
#             "id": "o6NnFJwKAHbJQ3NtsV8nCA",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/Jfskz44fSnhtSV4BDVNIIw/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "2350 E Union St",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "2350 E Union St",
#                     "Seattle, WA 98122"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98122"
#             },
#             "name": "COMMUNION Restaurant and Bar",
#             "phone": "+12063918140",
#             "rating": 4.5,
#             "review_count": 21,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/communion-restaurant-and-bar-seattle?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "seattle-biscuit-company-seattle",
#             "categories": [
#                 {
#                     "alias": "foodtrucks",
#                     "title": "Food Trucks"
#                 },
#                 {
#                     "alias": "southern",
#                     "title": "Southern"
#                 },
#                 {
#                     "alias": "soulfood",
#                     "title": "Soul Food"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.65631,
#                 "longitude": -122.362445
#             },
#             "display_phone": "",
#             "distance": 3983.816399777888,
#             "id": "p-ov1sITh3OPSvUT-5PtCQ",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/7DdCnuLCk6EMGJOaZ7PARg/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "4001 Leary Way NW",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "4001 Leary Way NW",
#                     "Seattle, WA 98107"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98107"
#             },
#             "name": "Seattle Biscuit Company",
#             "phone": "",
#             "price": "$$",
#             "rating": 4.0,
#             "review_count": 140,
#             "transactions": [
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/seattle-biscuit-company-seattle?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "freshys-seattle",
#             "categories": [
#                 {
#                     "alias": "coffee",
#                     "title": "Coffee & Tea"
#                 },
#                 {
#                     "alias": "soulfood",
#                     "title": "Soul Food"
#                 },
#                 {
#                     "alias": "sandwiches",
#                     "title": "Sandwiches"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.5782775878906,
#                 "longitude": -122.387054443359
#             },
#             "display_phone": "(206) 937-4316",
#             "distance": 6523.8221090554225,
#             "id": "FQUfvH4It4Z1cBaTpo7j2g",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/bbnyOlgX7yGTnaE7cBXOMQ/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "2735 California Ave SW",
#                 "address2": "Ste 120",
#                 "address3": "",
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "2735 California Ave SW",
#                     "Ste 120",
#                     "Seattle, WA 98116"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98116"
#             },
#             "name": "Freshy's",
#             "phone": "+12069374316",
#             "price": "$",
#             "rating": 4.0,
#             "review_count": 149,
#             "transactions": [],
#             "url": "https://www.yelp.com/biz/freshys-seattle?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "kings-deli-seattle-2",
#             "categories": [
#                 {
#                     "alias": "delis",
#                     "title": "Delis"
#                 },
#                 {
#                     "alias": "soulfood",
#                     "title": "Soul Food"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.6081771850586,
#                 "longitude": -122.295875549316
#             },
#             "display_phone": "(206) 323-0332",
#             "distance": 3532.106180605853,
#             "id": "ASTqFXe5wZc_rCjQkED1tQ",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/j6HxiZrK7kwKqqJ6mC_f1w/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "2800 E Cherry St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "2800 E Cherry St",
#                     "Seattle, WA 98122"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98122"
#             },
#             "name": "King's Deli",
#             "phone": "+12063230332",
#             "price": "$",
#             "rating": 4.0,
#             "review_count": 2,
#             "transactions": [
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/kings-deli-seattle-2?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "the-comfort-zone-seattle",
#             "categories": [
#                 {
#                     "alias": "soulfood",
#                     "title": "Soul Food"
#                 },
#                 {
#                     "alias": "seafood",
#                     "title": "Seafood"
#                 },
#                 {
#                     "alias": "tradamerican",
#                     "title": "American (Traditional)"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.5566797,
#                 "longitude": -122.2839219
#             },
#             "display_phone": "(206) 246-2800",
#             "distance": 8566.754994129247,
#             "id": "zq9xLldo9tQifAFsMa_3dw",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/0XzhCwscocnn_vetMsmy7A/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "5016 Rainier Ave S",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "5016 Rainier Ave S",
#                     "Seattle, WA 98118"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98118"
#             },
#             "name": "The Comfort Zone",
#             "phone": "+12062462800",
#             "price": "$$",
#             "rating": 4.0,
#             "review_count": 120,
#             "transactions": [
#                 "delivery",
#                 "pickup"
#             ],
#             "url": "https://www.yelp.com/biz/the-comfort-zone-seattle?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         },
#         {
#             "alias": "soul-seattle",
#             "categories": [
#                 {
#                     "alias": "soulfood",
#                     "title": "Soul Food"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 47.651174,
#                 "longitude": -122.350493
#             },
#             "display_phone": "(206) 395-9668",
#             "distance": 3068.337060267142,
#             "id": "6qPYN9QkoceUNnYJZ4MLxQ",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/XPuevDyiaRMTOGHYmxY7tw/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "3518 Fremont Pl N",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Seattle",
#                 "country": "US",
#                 "display_address": [
#                     "3518 Fremont Pl N",
#                     "Seattle, WA 98103"
#                 ],
#                 "state": "WA",
#                 "zip_code": "98103"
#             },
#             "name": "Soul",
#             "phone": "+12063959668",
#             "rating": 3.5,
#             "review_count": 16,
#             "transactions": [
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/soul-seattle?adjust_creative=OSdFtpeq2OSud3WQeM68Dg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OSdFtpeq2OSud3WQeM68Dg"
#         }
#     ],
#     "region": {
#         "center": {
#             "latitude": 47.62541904760501,
#             "longitude": -122.33551025390625
#         }
#     },
#     "total": 12
# }

# %%
# type/ethnicity of food is stored in yelp API under "categories:alias -- MUST BE ONE WORD!"
ethnicity = ['chinese','french','greek','indian','italian','japanese','brazilian','mexican','new american','soul food','thai']
# YELP base URL
endpoint = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_api}
params = {"term": "restaurants", "location": "seattle", "limit": 50, "categories": "newamerican"}
#max results per call is 50, so add offset param ("offset": 50, 100, etc.) to get full list per ethnicity
#"limit": 50

# Pretty Print the output of JSON data
newamerican1_response = requests.get(url=endpoint, headers=headers, params=params).json()
print(newamerican1_response["total"])
#print(json.dumps(newamerican1_response, indent=4, sort_keys=True))
# Out:
# 243

# %%
# type/ethnicity of food is stored in yelp API under "categories:alias -- MUST BE ONE WORD!"
ethnicity = ['chinese','french','greek','indian','italian','japanese','brazilian','mexican','new american','soul food','thai']
# YELP base URL
endpoint = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_api}
params = {"term": "restaurants", "location": "seattle", "limit": 50, "offset": 50, "categories": "newamerican"}
#max results per call is 50, so add offset param ("offset": 50, 100, etc.) to get full list per ethnicity
#"limit": 50

# Pretty Print the output of JSON data
newamerican2_response = requests.get(url=endpoint, headers=headers, params=params).json()
#print(newamerican2_response["total"])
#print(json.dumps(newamerican1_response, indent=4, sort_keys=True))

# %%
# type/ethnicity of food is stored in yelp API under "categories:alias -- MUST BE ONE WORD!"
ethnicity = ['chinese','french','greek','indian','italian','japanese','brazilian','mexican','new american','soul food','thai']
# YELP base URL
endpoint = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_api}
params = {"term": "restaurants", "location": "seattle", "limit": 50, "offset": 100, "categories": "newamerican"}
#max results per call is 50, so add offset param ("offset": 50, 100, etc.) to get full list per ethnicity
#"limit": 50

# Pretty Print the output of JSON data
newamerican3_response = requests.get(url=endpoint, headers=headers, params=params).json()
#print(newamerican3_response["total"])
#print(json.dumps(newamerican1_response, indent=4, sort_keys=True))

# %%
# type/ethnicity of food is stored in yelp API under "categories:alias -- MUST BE ONE WORD!"
ethnicity = ['chinese','french','greek','indian','italian','japanese','brazilian','mexican','new american','soul food','thai']
# YELP base URL
endpoint = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_api}
params = {"term": "restaurants", "location": "seattle", "limit": 50, "offset": 150, "categories": "newamerican"}
#max results per call is 50, so add offset param ("offset": 50, 100, etc.) to get full list per ethnicity
#"limit": 50

# Pretty Print the output of JSON data
newamerican4_response = requests.get(url=endpoint, headers=headers, params=params).json()
#print(newamerican4_response["total"])
#print(json.dumps(newamerican1_response, indent=4, sort_keys=True))

# %%
# type/ethnicity of food is stored in yelp API under "categories:alias -- MUST BE ONE WORD!"
ethnicity = ['chinese','french','greek','indian','italian','japanese','brazilian','mexican','new american','soul food','thai']
# YELP base URL
endpoint = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_api}
params = {"term": "restaurants", "location": "seattle", "limit": 50, "offset": 200, "categories": "newamerican"}
#max results per call is 50, so add offset param ("offset": 50, 100, etc.) to get full list per ethnicity
#"limit": 50

# Pretty Print the output of JSON data
newamerican5_response = requests.get(url=endpoint, headers=headers, params=params).json()
#print(newamerican5_response["total"])
#print(json.dumps(newamerican1_response, indent=4, sort_keys=True))

# %%
# list of json response dictionaries
seattle_yelp = ['chinese1_response', 
               'chinese2_response', 
                'chinese3_response', 
                'chinese4_response',
               'french_response', 
               'greek_response', 
                'greek2_response',
               'indian_response', 
               'italian1_response', 
               'italian2_response', 
               'italian3_response', 
                'italian4_response',
               'japanese1_response', 
               'japanese2_response', 
                'japanese3_response', 
                'japanese4_response',
                'japanese5_response',
               'brazilian_response',
               'thai_response', 
                'thai2_response', 
                'thai3_response',
               'soulfood_response', 
               'newamerican1_response',
               'newamerican2_response',
               'newamerican3_response', 
               'newamerican4_response',
                'newamerican5_response',
               'mexican1_response', 
                'mexican2_response',
                'mexican3_response',
                'mexican4_response',
                'mexican5_response', 
                'mexican6_response']

# %%
#json response:"name", "categories", "location.address1", "location.city", "location.state", "location.zip_code", "price" 
for business in response['businesses']:
    name.append(response['name'])
    city.append(response['location']['city'])
    latitude.append(response['coordinates']['latitude'])
    longitude.append(response['coordinates']['longitude'])
    zipcode.append(response['location']['zip_code'])
    ethnicity.append(response['categories']['alias'])
    price.append(response['price'])
    rating.append(response['rating'])

# %%
# create dictionary for restaurant data
restaurant_dict = {
    "name": name,
    "city": city,
    "latitude": latitude,
    "longitude": longitude,
    "zipcode": zipcode,
    "ethnicity": ethnicity,
    "price": price,
    "rating": rating}

# %%
# create dataframe from dictionary data
seattle_restaurants = pd.DataFrame(restaurant_dict)

# %%
# outer merge with zipcode df
seattle_merge = pd.merge(seattle_zips, seattle_restaurants, on='Zip_Code', how=outer)
seattle_merge

# %%
# export to CSV
#seattle_merge.to_csv(seattle_restaurants, index=None, header=True)
