# %%
# %matplotlib notebook

# %%
#import dependencies

import requests
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import gmaps
import os 
import pprint

# %%
# read in atlanta csv

atlanta_restaurant_totals = pd.read_csv("../Output/atlanta_restaurants.csv")

# %%
atlanta_restaurants
# Out:
#      Unnamed: 0                                        name     city  \
# 0             0                             Bao Bun Hibachi  Atlanta
# 1             1                              Little Bangkok  Atlanta
# 2             2                                    Urban Wu  Atlanta
# 3             3                               Food Terminal  Atlanta
# 4             4                              Hibachi Buffet  Atlanta
# ..          ...                                         ...      ...
# 484         484                                    T1 Bento  Atlanta
# 485         485                    Saigon Cafe - Cumberland  Atlanta
# 486         486                                   Thai Cafe  Atlanta
# 487         487  Tin Drum Asian Kitchen - Akers Mill Square  Atlanta
# 488         488                                  ThaiPointe  Atlanta
#
#       latitude  longitude  zipcode ethnicity price  rating
# 0    33.801160 -84.414700    30318   chinese     $     4.5
# ...

# %%
atlanta_restaurants.loc[atlanta_restaurants.ethnicity == 'chinese', 'ethnicity'].count()
# Out:
# 60
