# %%
#import dependencies

import requests
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import gmaps
import os 
import pprint
import urllib

#import yelp_key
from config import yelp_key

# %%
#read in zipcode CSVs

atlanta_zips = pd.read_csv("../Resources/atlanta_zipcodes.csv")

# %%
#clean zip codes of url reference at bottom
atlanta_zips.drop(atlanta_zips.tail(1).index,inplace=True)


#check that this worked
atlanta_zips.tail()
# Out:
#    Atlanta
# 23   30336
# 24   30342
# 25   30344
# 26   30354
# 27   30363

# %%
# set up list for zip codes
atlanta_zips = [zips for zips in atlanta_zips['Atlanta'] ]
atlanta_zips
# Out:
# ['30032',
#  '30303',
#  '30305',
#  '30306',
#  '30307',
#  '30308',
#  '30309',
#  '30310',
#  '30311',
#  '30312',
#  '30313',
#  '30314',
#  '30315',
#  '30316',
#  '30317',
#  '30318',
#  '30319',
#  '30324',
#  '30326',
#  '30327',
#  '30331',
#  '30332',
#  '30334',
#  '30336',
#  '30342',
#  '30344',
#  '30354',
#  '30363']

# %%
#read in ethnicites csv
restaurant_ethnicities = pd.read_csv("../Resources/rest_enthinicity.csv")
restaurant_ethnicities.head()
# Out:
#   ethnicity
# 0   chinese
# 1    french
# 2     greek
# 3    indian
# 4   italian

# %%
# set up list for ethnicities (this can be used for all cities)

restaurant_ethnic = [ethnicity for ethnicity in restaurant_ethnicities['ethnicity'] ]

restaurant_ethnic
# Out:
# ['chinese',
#  'french',
#  'greek',
#  'indian',
#  'italian',
#  'japanese',
#  'brazillian',
#  'mexican',
#  'new american',
#  'soul food',
#  'thai']

# %%
atlanta_ethnic_totals = pd.DataFrame({"City":'Atlanta'},index = [0])
atlanta_ethnic_totals['Ethnicity'] = ''
atlanta_ethnic_totals['Total Restaurants'] = ''

# %%
#starting call for atlanta
atlanta_coords = "39.952583, -75.165222"

#realized Yelp API will only return 50 responses at a time. Will need to make separate calls for each ethnicity, pull the "Total" and base additional offset calls on total



#chinese calls for details
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'atlanta', 'categories':'chinese', 'limit':50}
    
atlanta_chinese1 = requests.get(API_HOST,headers=headers, params=params).json()
atlanta_chinese1["Ethnicity"]="chinese"   
 
atlanta_ethnic_totals.loc[0, 'Ethnicity'] = 'Chinese'
atlanta_ethnic_totals.loc[0, 'Total Restaurants'] = (atlanta_chinese1["total"])
atlanta_ethnic_totals
# Out:
#       City Ethnicity Total Restaurants
# 0  Atlanta   Chinese               149

# %%
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'atlanta', 'categories':'chinese', 'offset':50, 'limit':50}
    
atlanta_chinese2 = requests.get(API_HOST,headers=headers, params=params).json()
atlanta_chinese2["Ethnicity"]="chinese"

# %%
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'atlanta', 'categories':'chinese', 'offset':100, 'limit':50}
    
atlanta_chinese3 = requests.get(API_HOST,headers=headers, params=params).json()
atlanta_chinese3["Ethnicity"]="chinese"

# %%
#each of the next ethinicities for atlanta will be in separate cell
#french
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'atlanta', 'categories':'french' , 'limit':50}
    
atlanta_french = requests.get(API_HOST,headers=headers, params=params).json()
atlanta_french["Ethnicity"]="french"

atlanta_ethnic_totals.loc[1, 'City'] = 'Atlanta'
atlanta_ethnic_totals.loc[1, 'Ethnicity'] = 'French'
atlanta_ethnic_totals.loc[1, 'Total Restaurants'] = (atlanta_french["total"])

atlanta_french
# Out:
# {'businesses': [{'id': '85s4Qh0VUxKCRFnEkHeXRA',
#    'alias': 'le-colonial-atlanta-atlanta-2',
#    'name': 'Le Colonial - Atlanta',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hSyJKftn8X2hlouScsR1Vg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-colonial-atlanta-atlanta-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 158,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.837408, 'longitude': -84.380267},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '3035 Peachtree Rd NE',
#     'address2': 'Ste A201',
#     'address3': None,
#     'city': 'Atlanta',
#     'zip_code': '30305',
#     'country': 'US',
#     'state': 'GA',
# ...

# %%
#greek
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'Atlanta', 'categories':'greek', 'limit':50 }
    
atlanta_greek = requests.get(API_HOST,headers=headers, params=params).json()
atlanta_greek["Ethnicity"]="greek"
atlanta_ethnic_totals.loc[2, 'City'] = 'Atlanta'
atlanta_ethnic_totals.loc[2, 'Ethnicity'] = 'Greek'
atlanta_ethnic_totals.loc[2, 'Total Restaurants'] = (atlanta_greek["total"])

atlanta_greek
# Out:
# {'businesses': [{'id': 'ZdEohT36LcY3eKh4fJMGRQ',
#    'alias': 'cafe-agora-atlanta-3',
#    'name': 'Cafe Agora',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/WQj5mAgMli3KxgOLQNTIcA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-agora-atlanta-3?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 732,
#    'categories': [{'alias': 'turkish', 'title': 'Turkish'},
#     {'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.839617, 'longitude': -84.377384},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '318 E Paces Ferry Rd NE',
#     'address2': None,
#     'address3': '',
#     'city': 'Atlanta',
#     'zip_code': '30305',
#     'country': 'US',
#     'state': 'GA',
# ...

# %%
#indian
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'atlanta', 'categories':'indpak', 'limit':50}
    
atlanta_indian1 = requests.get(API_HOST,headers=headers, params=params).json()
atlanta_indian1["Ethnicity"]="indian"
atlanta_ethnic_totals.loc[3, 'City'] = 'Atlanta'
atlanta_ethnic_totals.loc[3, 'Ethnicity'] = 'Indian'
atlanta_ethnic_totals.loc[3, 'Total Restaurants'] = (atlanta_indian1["total"])

# %%
#indian
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'atlanta', 'categories':'indpak', 'offset':50, 'limit':50}
    
atlanta_indian2 = requests.get(API_HOST,headers=headers, params=params).json()
atlanta_indian2["Ethnicity"]="indian"

atlanta_indian2
# Out:
# {'businesses': [{'id': '_NLRUS8fVGNMHzPRLYRXKA',
#    'alias': 'masala-fresh-atlanta',
#    'name': 'Masala Fresh',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/alW5TXyryIlb-BRvPjXD5g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/masala-fresh-atlanta?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 16,
#    'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'},
#     {'alias': 'indpak', 'title': 'Indian'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 33.81633, 'longitude': -84.4455},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '',
#     'address2': '',
#     'address3': '',
#     'city': 'Atlanta',
#     'zip_code': '30318',
#     'country': 'US',
#     'state': 'GA',
#     'display_address': ['Atlanta, GA 30318']},
#    'phone': '+17702418998',
#    'display_phone': '(770) 241-8998',
# ...

# %%
#italian
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'atlanta', 'categories':'italian' , 'limit':50}
    
atlanta_italian1 = requests.get(API_HOST,headers=headers, params=params).json()
atlanta_italian1["Ethnicity"]="italian"
atlanta_ethnic_totals.loc[4, 'City'] = 'Atlanta'
atlanta_ethnic_totals.loc[4, 'Ethnicity'] = 'Italian'
atlanta_ethnic_totals.loc[4, 'Total Restaurants'] = (atlanta_italian1["total"])

atlanta_italian1
# Out:
# {'businesses': [{'id': 'KqHES_Rr8btKCdz4RmpR_Q',
#    'alias': 'grana-atlanta',
#    'name': 'Grana',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/P3iJeeQFPs9g0WiuEwYgkQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grana-atlanta?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 198,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.805648, 'longitude': -84.3666786},
#    'transactions': ['delivery'],
#    'location': {'address1': '1835 Piedmont Ave NE',
#     'address2': None,
#     'address3': None,
#     'city': 'Atlanta',
#     'zip_code': '30324',
#     'country': 'US',
#     'state': 'GA',
#     'display_address': ['1835 Piedmont Ave NE', 'Atlanta, GA 30324']},
#    'phone': '+14042319000',
# ...

# %%
#italian
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'atlanta', 'categories':'italian', 'offset':50 , 'limit':50}
    
atlanta_italian2 = requests.get(API_HOST,headers=headers, params=params).json()
atlanta_italian2["Ethnicity"]="italian"
atlanta_italian2
# Out:
# {'businesses': [{'id': '4T94pO46YPpdG-hX6buvdg',
#    'alias': 'figo-pasta-atlanta-17',
#    'name': 'FIGO Pasta',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/r3tzCbKqSWkULxBLr4p9wg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/figo-pasta-atlanta-17?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 174,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 33.811966, 'longitude': -84.426416},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2080 Defoor Ave',
#     'address2': 'Ste 100',
#     'address3': '',
#     'city': 'Atlanta',
#     'zip_code': '30318',
#     'country': 'US',
#     'state': 'GA',
#     'display_address': ['2080 Defoor Ave', 'Ste 100', 'Atlanta, GA 30318']},
#    'phone': '+14043519667',
# ...

# %%
#italian
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'atlanta', 'categories':'italian', 'offset':100 , 'limit':50}
    
atlanta_italian3 = requests.get(API_HOST,headers=headers, params=params).json()
atlanta_italian3["Ethnicity"]="italian"
atlanta_italian3
# Out:
# {'businesses': [{'id': '0zKpsqidY1WQaco_TZnDsA',
#    'alias': 'villa-christina-atlanta',
#    'name': 'Villa Christina',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/InzPn27d7UglzeBxeyDTNQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/villa-christina-atlanta?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 55,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 33.91344, 'longitude': -84.341989},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '4000 Summit Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Atlanta',
#     'zip_code': '30319',
#     'country': 'US',
#     'state': 'GA',
#     'display_address': ['4000 Summit Blvd', 'Atlanta, GA 30319']},
# ...

# %%
#japanese
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'atlanta', 'categories':'japanese', 'limit':50 }
    
atlanta_japanese1 = requests.get(API_HOST,headers=headers, params=params).json()
atlanta_japanese1["Ethnicity"]="japanese"
atlanta_ethnic_totals.loc[5, 'City'] = 'Atlanta'
atlanta_ethnic_totals.loc[5, 'Ethnicity'] = 'Japanese'
atlanta_ethnic_totals.loc[5, 'Total Restaurants'] = (atlanta_japanese1["total"])
atlanta_ethnic_totals
# Out:
#       City Ethnicity Total Restaurants
# 0  Atlanta   Chinese               149
# 1  Atlanta    French                24
# 2  Atlanta     Greek                31
# 3  Atlanta    Indian                59
# 4  Atlanta   Italian               128
# 5  Atlanta  Japanese               103

# %%
#japanese
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'atlanta', 'categories':'japanese', 'offset':50 , 'limit':50}
    
atlanta_japanese2 = requests.get(API_HOST,headers=headers, params=params).json()
atlanta_japanese2["Ethnicity"]="japanese"

# %%
#japanese
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'atlanta', 'categories':'japanese', 'offset':100, 'limit':50 }
    
atlanta_japanese3 = requests.get(API_HOST,headers=headers, params=params).json()
atlanta_japanese3["Ethnicity"]="japanese"
atlanta_japanese3
# Out:
# {'businesses': [{'id': 'lHCX-SxcyyQ_bzG6IthKkw',
#    'alias': 'tokyo-grill-doraville',
#    'name': 'Tokyo Grill',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/0Mfue-QPVrzcmOOS601yCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tokyo-grill-doraville?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 12,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 33.907933, 'longitude': -84.287666},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '6035 Peachtree Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Doraville',
#     'zip_code': '30341',
#     'country': 'US',
#     'state': 'GA',
#     'display_address': ['6035 Peachtree Rd', 'Doraville, GA 30341']},
#    'phone': '',
#    'display_phone': '',
# ...

# %%
#brazilian
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'atlanta', 'categories':'brazilian' , 'limit':50}
    
atlanta_brazilian = requests.get(API_HOST,headers=headers, params=params).json()
atlanta_brazilian["Ethnicity"]="brazilian"
atlanta_ethnic_totals.loc[6, 'City'] = 'Atlanta'
atlanta_ethnic_totals.loc[6, 'Ethnicity'] = 'Brazilian'
atlanta_ethnic_totals.loc[6, 'Total Restaurants'] = (atlanta_brazilian["total"])

atlanta_brazilian
# Out:
# {'businesses': [{'id': '6Y0lQh4O-9JCutgyuMNq0g',
#    'alias': 'loca-luna-atlanta',
#    'name': 'Loca Luna',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pijBejuCEHsu6WR7iRwBVw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/loca-luna-atlanta?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 662,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'brazilian', 'title': 'Brazilian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 33.7886082610087,
#     'longitude': -84.3690906034915},
#    'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '550 Amsterdam Ave NE',
#     'address2': '',
#     'address3': '',
#     'city': 'Atlanta',
#     'zip_code': '30306',
#     'country': 'US',
# ...

# %%
#mexican
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'atlanta', 'categories':'mexican' , 'limit':50}
    
atlanta_mexican1 = requests.get(API_HOST,headers=headers, params=params).json()
atlanta_mexican1["Ethnicity"]="mexican"
atlanta_ethnic_totals.loc[7, 'City'] = 'Atlanta'
atlanta_ethnic_totals.loc[7, 'Ethnicity'] = 'Mexican'
atlanta_ethnic_totals.loc[7, 'Total Restaurants'] = (atlanta_mexican1["total"])
atlanta_ethnic_totals
# Out:
#       City  Ethnicity Total Restaurants
# 0  Atlanta    Chinese               149
# 1  Atlanta     French                24
# 2  Atlanta      Greek                31
# 3  Atlanta     Indian                59
# 4  Atlanta    Italian               128
# 5  Atlanta   Japanese               103
# 6  Atlanta  Brazilian                 5
# 7  Atlanta    Mexican               252

# %%
#mexican
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'atlanta', 'categories':'mexican', 'offset':50 , 'limit':50}
    
atlanta_mexican2 = requests.get(API_HOST,headers=headers, params=params).json()
atlanta_mexican2["Ethnicity"]="mexican"
atlanta_mexican2
# Out:
# {'businesses': [{'id': 'q6FVApCsCKMm32Rg3UmTHw',
#    'alias': 'las-tortas-locas-atlanta-2',
#    'name': 'Las Tortas Locas',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/T0wSVnz-j-8QZGvxI635oQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/las-tortas-locas-atlanta-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 50,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.859923679213,
#     'longitude': -84.3089949540922},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '4005 Buford Hwy',
#     'address2': 'Ste H',
#     'address3': '',
#     'city': 'Atlanta',
#     'zip_code': '30345',
#     'country': 'US',
#     'state': 'GA',
#     'display_address': ['4005 Buford Hwy', 'Ste H', 'Atlanta, GA 30345']},
#    'phone': '+14049820777',
# ...

# %%
#mexican
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'atlanta', 'categories':'mexican', 'offset':100,'limit':50}
    
atlanta_mexican3 = requests.get(API_HOST,headers=headers, params=params).json()
atlanta_mexican3["Ethnicity"]="mexican"
atlanta_mexican3
# Out:
# {'businesses': [{'id': 'FxvotvjV6TBPa1MkoFbqig',
#    'alias': 'red-pepper-taqueria-brookhaven-2',
#    'name': 'Red Pepper Taqueria',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/W2thTcjvdJn86m8sDWjMJw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/red-pepper-taqueria-brookhaven-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 111,
#    'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 33.8697765890681,
#     'longitude': -84.3357199651097},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '705 Town Blvd',
#     'address2': 'Ste  Q310',
#     'address3': None,
#     'city': 'Brookhaven',
#     'zip_code': '30319',
#     'country': 'US',
#     'state': 'GA',
# ...

# %%
#mexican
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'atlanta', 'categories':'mexican', 'offset':150, 'limit':50}
    
atlanta_mexican4 = requests.get(API_HOST,headers=headers, params=params).json()
atlanta_mexican4["Ethnicity"]="mexican"

# %%
#mexican
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'atlanta', 'categories':'mexican', 'offset':200, 'limit':50}
    
atlanta_mexican5 = requests.get(API_HOST,headers=headers, params=params).json()
atlanta_mexican5["Ethnicity"]="mexican"
atlanta_mexican5
# Out:
# {'businesses': [{'id': '716IrWLJ6fTezQyk9Y5m1w',
#    'alias': 'don-juan-mexican-cantina-atlanta',
#    'name': 'Don Juan Mexican Cantina',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/jbggdAus49lQk7CJxjRbLA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/don-juan-mexican-cantina-atlanta?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 17,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 33.757649, 'longitude': -84.394644},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '190 Marietta St NW',
#     'address2': '',
#     'address3': '',
#     'city': 'Atlanta',
#     'zip_code': '30303',
#     'country': 'US',
#     'state': 'GA',
#     'display_address': ['190 Marietta St NW', 'Atlanta, GA 30303']},
#    'phone': '+14042220898',
# ...

# %%
#mexican
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'atlanta', 'categories':'mexican', 'offset':250, 'limit':50 }
    
atlanta_mexican6 = requests.get(API_HOST,headers=headers, params=params).json()
atlanta_mexican6["Ethnicity"]="mexican"
atlanta_mexican6
# Out:
# {'businesses': [{'id': 'GjuNNX4BnF2B4buDuZ4X4Q',
#    'alias': 'taco-bell-atlanta-25',
#    'name': 'Taco Bell',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ln_2M0iZxZmN0sQBs2oh4g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taco-bell-atlanta-25?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 1,
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 33.879171, 'longitude': -84.471564},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': 'Cumberland Mall',
#     'address2': '1000 Cumberland Mall SE',
#     'address3': None,
#     'city': 'Atlanta',
#     'zip_code': '30339',
#     'country': 'US',
#     'state': 'GA',
#     'display_address': ['Cumberland Mall',
#      '1000 Cumberland Mall SE',
# ...

# %%
#new american
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'atlanta', 'categories':'newamerican', 'limit':50 }
    
atlanta_new_american1 = requests.get(API_HOST,headers=headers, params=params).json()
atlanta_new_american1["Ethnicity"]="new_american"
atlanta_ethnic_totals.loc[8, 'City'] = 'Atlanta'
atlanta_ethnic_totals.loc[8, 'Ethnicity'] = 'New American'
atlanta_ethnic_totals.loc[8, 'Total Restaurants'] = (atlanta_new_american1["total"])
atlanta_ethnic_totals
# Out:
#       City     Ethnicity Total Restaurants
# 0  Atlanta       Chinese               149
# 1  Atlanta        French                24
# 2  Atlanta         Greek                31
# 3  Atlanta        Indian                59
# 4  Atlanta       Italian               128
# 5  Atlanta      Japanese               103
# 6  Atlanta     Brazilian                 5
# 7  Atlanta       Mexican               252
# 8  Atlanta  New American               235

# %%
#new american
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'atlanta', 'categories':'newamerican', 'offset':50, 'limit':50 }
    
atlanta_new_american2 = requests.get(API_HOST,headers=headers, params=params).json()
atlanta_new_american2["Ethnicity"]="new_american"

# %%
#new american
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'atlanta', 'categories':'newamerican', 'offset':100, 'limit':50 }
    
atlanta_new_american3 = requests.get(API_HOST,headers=headers, params=params).json()
atlanta_new_american3["Ethnicity"]="new_american"

# %%
#new american
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'atlanta', 'categories':'newamerican', 'offset':150 , 'limit':50}
    
atlanta_new_american4 = requests.get(API_HOST,headers=headers, params=params).json()
atlanta_new_american4["Ethnicity"]="new_american"

# %%
#new american
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'atlanta', 'categories':'newamerican', 'offset':200, 'limit':50 }
    
atlanta_new_american5 = requests.get(API_HOST,headers=headers, params=params).json()
atlanta_new_american5["Ethnicity"]="new_american"

# %%
#soul food
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'atlanta', 'categories':'soulfood', 'limit':50 }
    
atlanta_soul_food1 = requests.get(API_HOST,headers=headers, params=params).json()
atlanta_soul_food1["Ethnicity"]="soulfood"
atlanta_ethnic_totals.loc[9, 'City'] = 'Atlanta'
atlanta_ethnic_totals.loc[9, 'Ethnicity'] = 'Soul Food'
atlanta_ethnic_totals.loc[9, 'Total Restaurants'] = (atlanta_soul_food1["total"])
atlanta_ethnic_totals
# Out:
#       City     Ethnicity Total Restaurants
# 0  Atlanta       Chinese               149
# 1  Atlanta        French                24
# 2  Atlanta         Greek                31
# 3  Atlanta        Indian                59
# 4  Atlanta       Italian               128
# 5  Atlanta      Japanese               103
# 6  Atlanta     Brazilian                 5
# 7  Atlanta       Mexican               252
# 8  Atlanta  New American               235
# 9  Atlanta     Soul Food                37

# %%
#thai
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'atlanta', 'categories':'thai' , 'limit':50}
    
atlanta_thai1 = requests.get(API_HOST,headers=headers, params=params).json()
atlanta_thai1["Ethnicity"]="thai"
atlanta_ethnic_totals.loc[10, 'City'] = 'Atlanta'
atlanta_ethnic_totals.loc[10, 'Ethnicity'] = 'Thai'
atlanta_ethnic_totals.loc[10, 'Total Restaurants'] = (atlanta_thai1["total"])
atlanta_ethnic_totals
# Out:
#        City     Ethnicity Total Restaurants
# 0   Atlanta       Chinese               149
# 1   Atlanta        French                24
# 2   Atlanta         Greek                31
# 3   Atlanta        Indian                59
# 4   Atlanta       Italian               128
# 5   Atlanta      Japanese               103
# 6   Atlanta     Brazilian                 5
# 7   Atlanta       Mexican               252
# 8   Atlanta  New American               235
# 9   Atlanta     Soul Food                37
# 10  Atlanta          Thai                60

# %%
#thai
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'atlanta', 'categories':'thai', 'offset':50 , 'limit':50}
    
atlanta_thai2 = requests.get(API_HOST,headers=headers, params=params).json()
atlanta_thai2["Ethnicity"]="thai"

# %%
atlanta_responses = [atlanta_chinese1, 
                    atlanta_chinese2, 
                    atlanta_chinese3, 
                    atlanta_french,
                    atlanta_greek,
                    atlanta_indian1,
                    atlanta_indian2,
                    atlanta_italian1,
                    atlanta_italian2,
                    atlanta_italian3,
                    atlanta_japanese1,
                    atlanta_japanese2,
                    atlanta_japanese3,
                    atlanta_brazilian,
                    atlanta_mexican1,
                    atlanta_mexican2,
                    atlanta_mexican3,
                    atlanta_mexican4,
                    atlanta_mexican5,
                    atlanta_mexican6,
                    atlanta_new_american1,
                    atlanta_new_american2,
                    atlanta_new_american3,
                    atlanta_new_american4,
                    atlanta_new_american5,
                    atlanta_soul_food1,
                    atlanta_thai1,
                    atlanta_thai2]
atlanta_responses
# Out:
# [{'businesses': [{'id': 'kzXrQKJpN2JyLd68iwH3hg',
#     'alias': 'little-bangkok-atlanta',
#     'name': 'Little Bangkok',
#     'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/0vyHiWquSQAAXSwrE2iRQQ/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/little-bangkok-atlanta?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 771,
#     'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#      {'alias': 'thai', 'title': 'Thai'}],
#     'rating': 4.0,
#     'coordinates': {'latitude': 33.81593, 'longitude': -84.35219},
#     'transactions': ['delivery'],
#     'price': '$$',
#     'location': {'address1': '2225 Cheshire Bridge Rd Ne',
#      'address2': '',
#      'address3': '',
#      'city': 'Atlanta',
#      'zip_code': '30324',
#      'country': 'US',
#      'state': 'GA',
# ...

# %%
# create empty lists for data
name = []
city = []
latitude = []
longitude = []
zipcode = []
ethnicity = []
price = []
rating = []

for i in range(len(atlanta_responses)):
    for j in range(len(atlanta_responses[i]['businesses'])):
        name.append(atlanta_responses[i]["businesses"][j]["name"])
        city.append("Atlanta")
        latitude.append(atlanta_responses[i]["businesses"][j]["coordinates"]["latitude"])
        longitude.append(atlanta_responses[i]["businesses"][j]["coordinates"]["longitude"])
        zipcode.append(atlanta_responses[i]["businesses"][j]["location"]["zip_code"])
        ethnicity.append((atlanta_responses[i]['Ethnicity']))
        try:
            price.append(atlanta_responses[i]["businesses"][j]["price"])
        except KeyError:
            price.append("N/A")
        rating.append(atlanta_responses[i]["businesses"][j]["rating"])

# %%
print(len(name))
print(len(city))
print(len(latitude))
print(len(longitude))
print(len(zipcode))
print(len(rating))
# Out:
# 1083
# 1083
# 1083
# 1083
# 1083
# 1083

# %%
atlanta_all_responses = {
    "name": name,
    "city": city,
    "latitude": latitude,
    "longitude": longitude,
    "zipcode": zipcode,
    "ethnicity": ethnicity,
    "price": price,
    "rating": rating}

# %%
atlanta_restaurants = pd.DataFrame(atlanta_all_responses)
atlanta_restaurants
# Out:
#                                             name     city   latitude  \
# 0                                 Little Bangkok  Atlanta  33.815930
# 1                                Bao Bun Hibachi  Atlanta  33.801160
# 2                                       Urban Wu  Atlanta  33.846710
# 3                                  Food Terminal  Atlanta  33.778829
# 4                                 Hibachi Buffet  Atlanta  33.841328
# ...                                          ...      ...        ...
# 1078                    Saigon Cafe - Cumberland  Atlanta  33.887040
# 1079                                   Thai Cafe  Atlanta  33.879660
# 1080                                    T1 Bento  Atlanta  33.907766
# 1081  Tin Drum Asian Kitchen - Akers Mill Square  Atlanta  33.882804
# 1082                                  ThaiPointe  Atlanta  33.893510
#
#       longitude zipcode ethnicity price  rating
# 0    -84.352190   30324   chinese    $$     4.0
# ...

# %%
atlanta_ethnic_totals.to_csv('../Output/Data/atlanta_extract_totals.csv')

# %%
atlanta_restaurants.to_csv('../Output/Data/atlanta_restaurants.csv')
