# %%
#import dependencies

import requests
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import gmaps
import os 
import pprint
import urllib

#import yelp_key
from config import yelp_key

# %%
#read in zipcode CSVs

philadelphia_zips = pd.read_csv("../Resources/philadelphia_zipcodes.csv")

# %%
#clean zip codes of url reference at bottom
philadelphia_zips.drop(philadelphia_zips.tail(1).index,inplace=True)


#check that this worked
philadelphia_zips.tail()
# Out:
#    Philadelphia
# 43        19150
# 44        19151
# 45        19152
# 46        19153
# 47        19154

# %%
# set up list for zip codes
philly_zips = [zips for zips in philadelphia_zips['Philadelphia'] ]
philly_zips
# Out:
# ['19102',
#  '19103',
#  '19104',
#  '19106',
#  '19107',
#  '19109',
#  '19111',
#  '19112',
#  '19114',
#  '19115',
#  '19116',
#  '19118',
#  '19119',
#  '19120',
#  '19121',
#  '19122',
#  '19123',
#  '19124',
#  '19125',
#  '19126',
#  '19127',
#  '19128',
#  '19129',
#  '19130',
#  '19131',
#  '19132',
#  '19133',
#  '19134',
#  '19135',
#  '19136',
#  '19137',
#  '19138',
#  '19139',
#  '19140',
#  '19141',
#  '19142',
#  '19143',
#  '19144',
#  '19145',
#  '19146',
#  '19147',
#  '19148',
#  '19149',
#  '19150',
#  '19151',
#  '19152',
#  '19153',
#  '19154']

# %%
#read in ethnicites csv
restaurant_ethnicities = pd.read_csv("../Resources/rest_enthinicity.csv")
restaurant_ethnicities.head()
# Out:
#   ethnicity
# 0   chinese
# 1    french
# 2     greek
# 3    indian
# 4   italian

# %%
# set up list for ethnicities (this can be used for all cities)

restaurant_ethnic = [ethnicity for ethnicity in restaurant_ethnicities['ethnicity'] ]

restaurant_ethnic
# Out:
# ['chinese',
#  'french',
#  'greek',
#  'indian',
#  'italian',
#  'japanese',
#  'brazillian',
#  'mexican',
#  'new american',
#  'soul food',
#  'thai']

# %%
philly_ethnic_details = pd.DataFrame({"City":'Philadelphia'},index = [0])
philly_ethnic_details['Name'] = ''
philly_ethnic_details['City'] = ''
philly_ethnic_details['Latitude'] = ''
philly_ethnic_details['Longitude'] = ''
philly_ethnic_details['ZipCode'] = ''
philly_ethnic_details['Ethnicity'] = ''
philly_ethnic_details['Price Level'] = ''
philly_ethnic_details['Rating'] = ''

philly_ethnic_details
# Out:
#   City Name Latitude Longitude ZipCode Ethnicity Price Level Rating
# 0

# %%
philly_ethnic_totals = pd.DataFrame({"City":'Philadelphia'},index = [0])
philly_ethnic_totals['Ethnicity'] = ''
philly_ethnic_totals['Total Restaurants'] = ''

# %%
#starting call for philadelphia
philly_coords = "39.952583, -75.165222"
philly_zips = [zips for zips in philadelphia_zips['Philadelphia'] ]

#realized Yelp API will only return 50 responses at a time. Will need to make separate calls for each ethnicity, pull the "Total" and base additional offset calls on total



#chinese calls for details
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'Philadelphia', 'categories':'chinese'}
    
philadelphia_chinese1 = requests.get(API_HOST,headers=headers, params=params).json()
philadelphia_chinese1["Ethnicity"]="chinese"   
    
philly_ethnic_totals.loc[0, 'Ethnicity'] = 'Chinese'
philly_ethnic_totals.loc[0, 'Total Restaurants'] = (philadelphia_chinese1["total"])
philly_ethnic_totals
# Out:
#            City Ethnicity Total Restaurants
# 0  Philadelphia   Chinese               413

# %%
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'Philadelphia', 'categories':'chinese', 'offset':50}
    
philadelphia_chinese2 = requests.get(API_HOST,headers=headers, params=params).json()
philadelphia_chinese2["Ethnicity"]="chinese"

# %%
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'Philadelphia', 'categories':'chinese', 'offset':100}
    
philadelphia_chinese3 = requests.get(API_HOST,headers=headers, params=params).json()
philadelphia_chinese3["Ethnicity"]="chinese"

# %%
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'Philadelphia', 'categories':'chinese', 'offset':150}
    
philadelphia_chinese4 = requests.get(API_HOST,headers=headers, params=params).json()
philadelphia_chinese4["Ethnicity"]="chinese"

# %%
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'Philadelphia', 'categories':'chinese', 'offset':200}
    
philadelphia_chinese5 = requests.get(API_HOST,headers=headers, params=params).json()
philadelphia_chinese5["Ethnicity"]="chinese"

# %%
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'Philadelphia', 'categories':'chinese', 'offset':250}
    
philadelphia_chinese6 = requests.get(API_HOST,headers=headers, params=params).json()
philadelphia_chinese6["Ethnicity"]="chinese"

# %%
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'Philadelphia', 'categories':'chinese', 'offset':300}
    
philadelphia_chinese7 = requests.get(API_HOST,headers=headers, params=params).json()
philadelphia_chinese7["Ethnicity"]="chinese"

# %%
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'Philadelphia', 'categories':'chinese', 'offset':350}
    
philadelphia_chinese8 = requests.get(API_HOST,headers=headers, params=params).json()
philadelphia_chinese8["Ethnicity"]="chinese"

# %%
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'Philadelphia', 'categories':'chinese', 'offset':400}
    
philadelphia_chinese9 = requests.get(API_HOST,headers=headers, params=params).json()
philadelphia_chinese9['Ethnicity']="chinese"

philadelphia_chinese9
# Out:
# {'businesses': [{'id': 'J2z_Yvh0jSTkLAe6SePUXg',
#    'alias': 'hot-wok-philadelphia',
#    'name': 'Hot Wok',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hot-wok-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 4,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.04273, 'longitude': -75.12883},
#    'transactions': ['delivery'],
#    'location': {'address1': '6005 N 5th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19120',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['6005 N 5th St', 'Philadelphia, PA 19120']},
#    'phone': '+12159278000',
#    'display_phone': '(215) 927-8000',
#    'distance': 10527.544983934315},
#   {'id': 'E-GajYuzihh0A1VNQImrkA',
#    'alias': 'great-wall-restaurant-philadelphia-4',
#    'name': 'Great Wall Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/MzkHbA49ltU5hNoUsAL6nQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/great-wall-restaurant-philadelphia-4?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 4,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.0241814, 'longitude': -75.0461426},
#    'transactions': ['delivery'],
#    'location': {'address1': '6705 Torresdale Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19135',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['6705 Torresdale Ave', 'Philadelphia, PA 19135']},
#    'phone': '+12153318883',
#    'display_phone': '(215) 331-8883',
#    'distance': 13224.548409541154},
#   {'id': '7Ct4QuWaY63DkAOXqEiVGA',
#    'alias': 'hong-kong-chinese-restaurant-glenolden',
#    'name': 'Hong Kong Chinese Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XjKaVBxfiMLfZ0HuwpkB-g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hong-kong-chinese-restaurant-glenolden?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 18,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 39.90347, 'longitude': -75.28426},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '326 N Chester Pike',
#     'address2': '',
#     'address3': '',
#     'city': 'Glenolden',
#     'zip_code': '19036',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['326 N Chester Pike', 'Glenolden, PA 19036']},
#    'phone': '+16104615370',
#    'display_phone': '(610) 461-5370',
#    'distance': 11165.406581567395},
#   {'id': 'TWJHKT9TvktOl5sCj8PxQw',
#    'alias': 'happy-garden-philadelphia-6',
#    'name': 'Happy Garden',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/H-5Fy9nsNtGRpKfPs5i9zg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/happy-garden-philadelphia-6?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 1,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.0406456, 'longitude': -75.1441879},
#    'transactions': [],
#    'location': {'address1': '5723 N Broad St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19141',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['5723 N Broad St', 'Philadelphia, PA 19141']},
#    'phone': '+12155486258',
#    'display_phone': '(215) 548-6258',
#    'distance': 9902.081745084488},
#   {'id': '-CW326s4UVLaZhy5BE4qiA',
#    'alias': 'tai-won-chinese-restaurant-philadelphia',
#    'name': 'Tai Won Chinese Restaurant',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tai-won-chinese-restaurant-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 2,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.00906, 'longitude': -75.10019},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1401 E Lycoming St',
#     'address2': 'Ste 3',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19124',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1401 E Lycoming St',
#      'Ste 3',
#      'Philadelphia, PA 19124']},
#    'phone': '+12152899628',
#    'display_phone': '(215) 289-9628',
#    'distance': 8626.649118772604},
#   {'id': '6ozWnjKn9336r-HWpl9p3w',
#    'alias': 'asia-express-philadelphia',
#    'name': 'Asia Express',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/oumgJVXWtp86Gej0-P2zDQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/asia-express-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 3,
#    'categories': [{'alias': 'cantonese', 'title': 'Cantonese'},
#     {'alias': 'szechuan', 'title': 'Szechuan'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.05096, 'longitude': -75.06677},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '7246 Castor Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19149',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['7246 Castor Ave', 'Philadelphia, PA 19149']},
#    'phone': '+12157257601',
#    'display_phone': '(215) 725-7601',
#    'distance': 13993.799076799483},
#   {'id': 'pZGUnFYoXr2ccOxWr-F9Cw',
#    'alias': 'fresh-garden-philadelphia',
#    'name': 'Fresh Garden',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Rt6LqKQKO20G6YrJl2vZDw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fresh-garden-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 19,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 1.5,
#    'coordinates': {'latitude': 40.0438271, 'longitude': -75.0534515},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2812 Cottman Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19149',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['2812 Cottman Ave', 'Philadelphia, PA 19149']},
#    'phone': '+12153388808',
#    'display_phone': '(215) 338-8808',
#    'distance': 14156.489767761885},
#   {'id': 'pqpWW-wiEBWhPTgqtlTFsA',
#    'alias': 'chows-chinese-restaurant-collingswood-2',
#    'name': "Chow's Chinese Restaurant",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/rhcd90okZWygbQ8aoUaD5Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chows-chinese-restaurant-collingswood-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 52,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 39.916815, 'longitude': -75.070022},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '657 Haddon Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Collingswood',
#     'zip_code': '08108',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['657 Haddon Ave', 'Collingswood, NJ 08108']},
#    'phone': '+18568582882',
#    'display_phone': '(856) 858-2882',
#    'distance': 9556.084219961613},
#   {'id': 'xhn7l8vk2GlIY2ErkAE5jw',
#    'alias': 'no-1-china-folcroft-2',
#    'name': 'No 1 China',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YsT8-wRj2cO9j_J56v6RrQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/no-1-china-folcroft-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 8,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 1.5,
#    'coordinates': {'latitude': 39.8926801, 'longitude': -75.28238},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '1844 Delmar Dr',
#     'address2': '',
#     'address3': '',
#     'city': 'Folcroft',
#     'zip_code': '19032',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1844 Delmar Dr', 'Folcroft, PA 19032']},
#    'phone': '+16102378982',
#    'display_phone': '(610) 237-8982',
#    'distance': 11735.992913712393},
#   {'id': 'jM_9HiTXoZQWOTo49zdf2g',
#    'alias': 'no-1-chinese-kitchen-haddonfield',
#    'name': 'No 1 Chinese Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/uOdKyIsFPPSfMHYusGrdmA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/no-1-chinese-kitchen-haddonfield?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 18,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 39.900891, 'longitude': -75.053177},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '413 W Crystal Lake Ave',
#     'address2': 'Ste 5',
#     'address3': '',
#     'city': 'Haddonfield',
#     'zip_code': '08033',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['413 W Crystal Lake Ave',
#      'Ste 5',
#      'Haddonfield, NJ 08033']},
#    'phone': '+18568540316',
#    'display_phone': '(856) 854-0316',
#    'distance': 11656.633491429006},
#   {'id': 'n5tFiNbFgwNQugDLLG96QQ',
#    'alias': 'lansdowne-chinese-restaurant-lansdowne',
#    'name': 'Lansdowne Chinese Restaurant',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lansdowne-chinese-restaurant-lansdowne?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 1,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 1.0,
#    'coordinates': {'latitude': 39.9384548658733,
#     'longitude': -75.2723349339402},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '10 N Lansdowne Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Lansdowne',
#     'zip_code': '19050',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['10 N Lansdowne Ave', 'Lansdowne, PA 19050']},
#    'phone': '+16102593739',
#    'display_phone': '(610) 259-3739',
#    'distance': 8793.767777334275},
#   {'id': 'Ii_rSNFmaXnHCMWuyy-iOA',
#    'alias': 'no-1-china-clifton-heights',
#    'name': 'No 1 China',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_eR2TY1jaVjfRJ9AuTcxWA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/no-1-china-clifton-heights?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 10,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 39.930172, 'longitude': -75.2952009},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '107 E Baltimore Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'Clifton Heights',
#     'zip_code': '19018',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['107 E Baltimore Ave', 'Clifton Heights, PA 19018']},
#    'phone': '+16103949973',
#    'display_phone': '(610) 394-9973',
#    'distance': 10911.319793898978},
#   {'id': 'zLbDAJyWh5dFFqKj27rmDA',
#    'alias': 'new-china-collingdale',
#    'name': 'New China',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qCbdhA4ELcBXiQa8-JVaLA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/new-china-collingdale?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 14,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 39.9088565, 'longitude': -75.2841067},
#    'transactions': ['pickup'],
#    'price': '$',
#    'location': {'address1': '1207 Macdade Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Collingdale',
#     'zip_code': '19036',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1207 Macdade Blvd', 'Collingdale, PA 19036']},
#    'phone': '+16105866770',
#    'display_phone': '(610) 586-6770',
#    'distance': 10959.829118510568}],
#  'total': 413,
#  'region': {'center': {'longitude': -75.17120361328125,
#    'latitude': 39.95378209544653}},
#  'Ethnicity': 'chinese'}

# %%
philadelphia_total_chinese = [philadelphia_chinese1,
                             philadelphia_chinese2,
                             philadelphia_chinese3,
                             philadelphia_chinese4,
                             philadelphia_chinese5,
                             philadelphia_chinese6,
                             philadelphia_chinese7,
                             philadelphia_chinese8,
                             philadelphia_chinese9,]

philadelphia_total_chinese
# Out:
# [{'businesses': [{'id': 'iksVwRfpWymIUUFqw0tXpw',
#     'alias': 'chubby-cattle-philadelphia-5',
#     'name': 'Chubby Cattle',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ZfoHNW4vJ7NQdUzf0CrKLQ/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/chubby-cattle-philadelphia-5?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 980,
#     'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#      {'alias': 'hotpot', 'title': 'Hot Pot'},
#      {'alias': 'seafood', 'title': 'Seafood'}],
#     'rating': 4.5,
#     'coordinates': {'latitude': 39.95498, 'longitude': -75.15622},
#     'transactions': ['delivery', 'pickup'],
#     'location': {'address1': '146 N 10th St',
#      'address2': '',
#      'address3': None,
#      'city': 'Philadelphia',
#      'zip_code': '19107',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['146 N 10th St', 'Philadelphia, PA 19107']},
#     'phone': '+18666228853',
#     'display_phone': '(866) 622-8853',
#     'distance': 1291.7130230735665},
#    {'id': 'ntiIq1FNqduOyyowMFGh5A',
#     'alias': 'nan-zhou-hand-drawn-noodle-house-philadelphia',
#     'name': 'Nan Zhou Hand Drawn Noodle House',
#     'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/te32sNbNRHe9J1q_IfO46w/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/nan-zhou-hand-drawn-noodle-house-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 2094,
#     'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#      {'alias': 'noodles', 'title': 'Noodles'}],
#     'rating': 4.0,
#     'coordinates': {'latitude': 39.9554005670665,
#      'longitude': -75.1569010985796},
#     'transactions': ['delivery', 'pickup'],
#     'price': '$',
#     'location': {'address1': '1022 Race St',
#      'address2': '',
#      'address3': '',
#      'city': 'Philadelphia',
#      'zip_code': '19107',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['1022 Race St', 'Philadelphia, PA 19107']},
#     'phone': '+12159231550',
#     'display_phone': '(215) 923-1550',
#     'distance': 1232.3121255489739},
#    {'id': 'AGlh4ZDv6jnoiYfz7At9mw',
#     'alias': 'dim-sum-garden-philadelphia',
#     'name': 'Dim Sum Garden',
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IJoELINHMt3UlM3u8SIPFg/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/dim-sum-garden-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 2510,
#     'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#      {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#      {'alias': 'shanghainese', 'title': 'Shanghainese'}],
#     'rating': 4.0,
#     'coordinates': {'latitude': 39.955399, 'longitude': -75.156727},
#     'transactions': ['delivery', 'pickup'],
#     'price': '$',
#     'location': {'address1': '1020 Race St',
#      'address2': None,
#      'address3': '',
#      'city': 'Philadelphia',
#      'zip_code': '19107',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['1020 Race St', 'Philadelphia, PA 19107']},
#     'phone': '+12158730258',
#     'display_phone': '(215) 873-0258',
#     'distance': 1246.9693914728973},
#    {'id': '0S3TvsmbCeOZ9UitnpRd1A',
#     'alias': 'dim-sum-house-philadelphia-3',
#     'name': 'Dim Sum House',
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9-w6csJcvW-tQWC5EaMRNQ/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/dim-sum-house-philadelphia-3?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 489,
#     'categories': [{'alias': 'szechuan', 'title': 'Szechuan'},
#      {'alias': 'dimsum', 'title': 'Dim Sum'},
#      {'alias': 'cantonese', 'title': 'Cantonese'}],
#     'rating': 4.0,
#     'coordinates': {'latitude': 39.9518854916096,
#      'longitude': -75.1724655926228},
#     'transactions': ['delivery', 'pickup'],
#     'price': '$$',
#     'location': {'address1': '1930 Chestnut St',
#      'address2': '',
#      'address3': '',
#      'city': 'Philadelphia',
#      'zip_code': '19103',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['1930 Chestnut St', 'Philadelphia, PA 19103']},
#     'phone': '+12155638800',
#     'display_phone': '(215) 563-8800',
#     'distance': 286.07777929632937},
#    {'id': 'kbXpjBSweedxQ1WrlJ5i7Q',
#     'alias': 'dan-dan-philadelphia-6',
#     'name': 'Dan Dan',
#     'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/lxrslIOiXOoGS4HUcTqHrQ/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/dan-dan-philadelphia-6?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 785,
#     'categories': [{'alias': 'szechuan', 'title': 'Szechuan'},
#      {'alias': 'taiwanese', 'title': 'Taiwanese'},
#      {'alias': 'noodles', 'title': 'Noodles'}],
#     'rating': 4.0,
#     'coordinates': {'latitude': 39.9502487182617,
#      'longitude': -75.167594909668},
#     'transactions': ['delivery'],
#     'price': '$$',
#     'location': {'address1': '126 S 16th St',
#      'address2': '',
#      'address3': '',
#      'city': 'Philadelphia',
#      'zip_code': '19102',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['126 S 16th St', 'Philadelphia, PA 19102']},
#     'phone': '+12158001165',
#     'display_phone': '(215) 800-1165',
#     'distance': 498.9735473199334},
#    {'id': 'kZ1q0K13tFYG_ZJrVvsJHA',
#     'alias': 'sampan-philadelphia-3',
#     'name': 'Sampan',
#     'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/AMXsEXLJSKl9rJkPe_wMWg/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/sampan-philadelphia-3?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 1880,
#     'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#      {'alias': 'chinese', 'title': 'Chinese'}],
#     'rating': 4.0,
#     'coordinates': {'latitude': 39.9495313759, 'longitude': -75.1621570259495},
#     'transactions': ['delivery'],
#     'price': '$$',
#     'location': {'address1': '124 S 13th St',
#      'address2': '',
#      'address3': '',
#      'city': 'Philadelphia',
#      'zip_code': '19107',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['124 S 13th St', 'Philadelphia, PA 19107']},
#     'phone': '+12157323501',
#     'display_phone': '(215) 732-3501',
#     'distance': 904.4638168348586},
#    {'id': 'QhgrhVKlXZtSY6gRThf8zA',
#     'alias': 'bing-bing-dim-sum-philadelphia',
#     'name': 'Bing Bing Dim Sum',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/dV6HPtXLhcAYeE41pTSDAg/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/bing-bing-dim-sum-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 515,
#     'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#      {'alias': 'dimsum', 'title': 'Dim Sum'},
#      {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#     'rating': 4.0,
#     'coordinates': {'latitude': 39.9289513, 'longitude': -75.164711},
#     'transactions': ['delivery'],
#     'price': '$$',
#     'location': {'address1': '1648 E Passyunk Ave',
#      'address2': '',
#      'address3': '',
#      'city': 'Philadelphia',
#      'zip_code': '19148',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['1648 E Passyunk Ave', 'Philadelphia, PA 19148']},
#     'phone': '+12152797702',
#     'display_phone': '(215) 279-7702',
#     'distance': 2811.2832796874904},
#    {'id': 'MMRRS6YhVRx_iN5-JhMRYg',
#     'alias': 'han-dynasty-philadelphia-11',
#     'name': 'Han Dynasty',
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BGnEpx1DSfjqKrmQbSD1CA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/han-dynasty-philadelphia-11?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 753,
#     'categories': [{'alias': 'szechuan', 'title': 'Szechuan'}],
#     'rating': 4.0,
#     'coordinates': {'latitude': 39.9567105160991,
#      'longitude': -75.1971027810898},
#     'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#     'price': '$$',
#     'location': {'address1': '3711 Market St',
#      'address2': '',
#      'address3': '',
#      'city': 'Philadelphia',
#      'zip_code': '19104',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['3711 Market St', 'Philadelphia, PA 19104']},
#     'phone': '+12152223711',
#     'display_phone': '(215) 222-3711',
#     'distance': 2231.427103572225},
#    {'id': 'QckgxxdTdsRPdE1O8IUG_w',
#     'alias': 'jane-gs-restaurant-philadelphia-2',
#     'name': "Jane G's Restaurant",
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Yn5vkKEG4PC8NsKWEuKLZA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/jane-gs-restaurant-philadelphia-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 4,
#     'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#      {'alias': 'bars', 'title': 'Bars'},
#      {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#     'rating': 4.5,
#     'coordinates': {'latitude': 39.951841, 'longitude': -75.173328},
#     'transactions': ['delivery', 'pickup'],
#     'location': {'address1': '1930 Chestnut St',
#      'address2': None,
#      'address3': None,
#      'city': 'Philadelphia',
#      'zip_code': '19103',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['1930 Chestnut St', 'Philadelphia, PA 19103']},
#     'phone': '+12155638800',
#     'display_phone': '(215) 563-8800',
#     'distance': 286.8789775204867},
#    {'id': 'L-qu3bjkz4Uar55Fxa5JZA',
#     'alias': 'hong-qi-gong-philadelphia',
#     'name': 'Hong Qi Gong',
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NAVfHsYXpbiq__7jpeoIAg/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/hong-qi-gong-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 3,
#     'categories': [{'alias': 'hotpot', 'title': 'Hot Pot'},
#      {'alias': 'chinese', 'title': 'Chinese'}],
#     'rating': 4.0,
#     'coordinates': {'latitude': 39.9544401036752,
#      'longitude': -75.1542798802257},
#     'transactions': [],
#     'location': {'address1': '135 N 9th St',
#      'address2': '',
#      'address3': None,
#      'city': 'Philadelphia',
#      'zip_code': '19107',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['135 N 9th St', 'Philadelphia, PA 19107']},
#     'phone': '',
#     'display_phone': '',
#     'distance': 1444.3890124970528},
#    {'id': 'zU5PPd9j4bYC_MepNSEDcA',
#     'alias': 'dim-sum-house-philadelphia',
#     'name': 'Dim Sum House',
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/aleFRNN07SNzaDVw4stTFg/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/dim-sum-house-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 415,
#     'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#      {'alias': 'cantonese', 'title': 'Cantonese'},
#      {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#     'rating': 4.0,
#     'coordinates': {'latitude': 39.9557715, 'longitude': -75.2016544},
#     'transactions': ['delivery', 'pickup'],
#     'price': '$$',
#     'location': {'address1': '3939 Chestnut St',
#      'address2': 'Fl 2',
#      'address3': None,
#      'city': 'Philadelphia',
#      'zip_code': '19104',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['3939 Chestnut St',
#       'Fl 2',
#       'Philadelphia, PA 19104']},
#     'phone': '+12159215377',
#     'display_phone': '(215) 921-5377',
#     'distance': 2604.9296335165545},
#    {'id': 'nIAbuktMEzVjT4P9pG89rQ',
#     'alias': 'buddakan-philadelphia',
#     'name': 'Buddakan',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/F7JAes4_Cp2qIOR5_WMiUg/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/buddakan-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 1488,
#     'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#      {'alias': 'chinese', 'title': 'Chinese'}],
#     'rating': 4.0,
#     'coordinates': {'latitude': 39.9489186, 'longitude': -75.1471667},
#     'transactions': ['delivery', 'pickup'],
#     'price': '$$$',
#     'location': {'address1': '325 Chestnut St',
#      'address2': '',
#      'address3': '',
#      'city': 'Philadelphia',
#      'zip_code': '19106',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['325 Chestnut St', 'Philadelphia, PA 19106']},
#     'phone': '+12155749440',
#     'display_phone': '(215) 574-9440',
#     'distance': 2119.093710726282},
#    {'id': 'qISf5ojuYbD9h71NumGUQA',
#     'alias': 'han-dynasty-philadelphia',
#     'name': 'Han Dynasty',
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fD2QVqaXp5p8H17kFSG2ng/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/han-dynasty-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 1449,
#     'categories': [{'alias': 'szechuan', 'title': 'Szechuan'}],
#     'rating': 4.0,
#     'coordinates': {'latitude': 39.9483978526255,
#      'longitude': -75.1435844420196},
#     'transactions': [],
#     'price': '$$',
#     'location': {'address1': '123 Chestnut St',
#      'address2': '',
#      'address3': '',
#      'city': 'Philadelphia',
#      'zip_code': '19106',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['123 Chestnut St', 'Philadelphia, PA 19106']},
#     'phone': '+12159221888',
#     'display_phone': '(215) 922-1888',
#     'distance': 2429.222436455929},
#    {'id': '15JFk0bn7HJ9g9-N7tXl_Q',
#     'alias': 'heung-fa-chun-sweet-house-philadelphia',
#     'name': 'Heung Fa Chun Sweet House',
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FukbEwqwO7f1tD8kNNuCRg/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/heung-fa-chun-sweet-house-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 217,
#     'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#      {'alias': 'desserts', 'title': 'Desserts'}],
#     'rating': 4.5,
#     'coordinates': {'latitude': 39.9539057451979,
#      'longitude': -75.1562611059858},
#     'transactions': [],
#     'price': '$',
#     'location': {'address1': '112 N 10th St',
#      'address2': '',
#      'address3': '',
#      'city': 'Philadelphia',
#      'zip_code': '19107',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['112 N 10th St', 'Philadelphia, PA 19107']},
#     'phone': '+12152388968',
#     'display_phone': '(215) 238-8968',
#     'distance': 1272.0799708510413},
#    {'id': 'VP8HMhVt-pKmqGNmDW4-TQ',
#     'alias': 'nom-wah-philadelphia-philadelphia-2',
#     'name': 'Nom Wah Philadelphia',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/K0fYkdVigr1XRDfUAGakFg/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/nom-wah-philadelphia-philadelphia-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 377,
#     'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#      {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#     'rating': 4.0,
#     'coordinates': {'latitude': 39.9565925598145,
#      'longitude': -75.160774230957},
#     'transactions': ['delivery'],
#     'price': '$$',
#     'location': {'address1': '218 N 13th St',
#      'address2': '',
#      'address3': '',
#      'city': 'Philadelphia',
#      'zip_code': '19107',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['218 N 13th St', 'Philadelphia, PA 19107']},
#     'phone': '+12675192889',
#     'display_phone': '(267) 519-2889',
#     'distance': 942.4855993829802},
#    {'id': '_V6hl1oGkTV2KbGeax_HPA',
#     'alias': 'sang-kee-peking-duck-house-philadelphia-2',
#     'name': 'Sang Kee Peking Duck House',
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wdd-2tvwzLJ4g7CY4PfbJQ/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/sang-kee-peking-duck-house-philadelphia-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 893,
#     'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#      {'alias': 'noodles', 'title': 'Noodles'},
#      {'alias': 'bbq', 'title': 'Barbeque'}],
#     'rating': 4.0,
#     'coordinates': {'latitude': 39.95639, 'longitude': -75.15433},
#     'transactions': ['delivery', 'pickup'],
#     'price': '$$',
#     'location': {'address1': '238 N 9th St',
#      'address2': '',
#      'address3': '',
#      'city': 'Philadelphia',
#      'zip_code': '19107',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['238 N 9th St', 'Philadelphia, PA 19107']},
#     'phone': '+12159257532',
#     'display_phone': '(215) 925-7532',
#     'distance': 1470.9417042395612},
#    {'id': 'qY-BUQY-SFBaSrFHowF3nA',
#     'alias': 'nine-ting-philadelphia',
#     'name': 'Nine Ting',
#     'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FY7G0QXX69sBFcZbez5ydA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/nine-ting-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 1141,
#     'categories': [{'alias': 'korean', 'title': 'Korean'},
#      {'alias': 'bbq', 'title': 'Barbeque'},
#      {'alias': 'chinese', 'title': 'Chinese'}],
#     'rating': 4.0,
#     'coordinates': {'latitude': 39.955083683693,
#      'longitude': -75.1552917273078},
#     'transactions': ['delivery', 'pickup'],
#     'price': '$$',
#     'location': {'address1': '926 Race St',
#      'address2': '',
#      'address3': '',
#      'city': 'Philadelphia',
#      'zip_code': '19107',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['926 Race St', 'Philadelphia, PA 19107']},
#     'phone': '+12152389996',
#     'display_phone': '(215) 238-9996',
#     'distance': 1363.9813292723472},
#    {'id': 'azfjxlAnSATyLBAGiuSq3A',
#     'alias': 'lau-kee-restaurant-philadelphia-3',
#     'name': 'Lau Kee Restaurant',
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LC8PCqz7wwxnoQyF8_7p-w/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/lau-kee-restaurant-philadelphia-3?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 67,
#     'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#     'rating': 4.5,
#     'coordinates': {'latitude': 39.95517, 'longitude': -75.15557},
#     'transactions': ['delivery'],
#     'location': {'address1': '934 Race St',
#      'address2': None,
#      'address3': '',
#      'city': 'Philadelphia',
#      'zip_code': '19107',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['934 Race St', 'Philadelphia, PA 19107']},
#     'phone': '+12152013511',
#     'display_phone': '(215) 201-3511',
#     'distance': 1341.5115301766887},
#    {'id': '7z16CBc74GhbyqalwZrJUQ',
#     'alias': 'ting-wong-restaurant-philadelphia',
#     'name': 'Ting Wong Restaurant',
#     'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/W5oCMuPnfNE0JMBwaJRtbQ/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/ting-wong-restaurant-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 445,
#     'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#      {'alias': 'noodles', 'title': 'Noodles'},
#      {'alias': 'seafood', 'title': 'Seafood'}],
#     'rating': 4.0,
#     'coordinates': {'latitude': 39.954754, 'longitude': -75.156191},
#     'transactions': ['delivery', 'pickup'],
#     'price': '$',
#     'location': {'address1': '138 N 10th St',
#      'address2': '',
#      'address3': '',
#      'city': 'Philadelphia',
#      'zip_code': '19107',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['138 N 10th St', 'Philadelphia, PA 19107']},
#     'phone': '+12159281883',
#     'display_phone': '(215) 928-1883',
#     'distance': 1284.1882874714945},
#    {'id': 'nzMsAREnsFlsCHsBUwL2SQ',
#     'alias': 'ho-sai-gai-restaurant-philadelphia-3',
#     'name': 'Ho Sai Gai Restaurant',
#     'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/qzZ0EPsv5OZXuiwb46l-yQ/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/ho-sai-gai-restaurant-philadelphia-3?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 200,
#     'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#     'rating': 4.0,
#     'coordinates': {'latitude': 39.9552230834961,
#      'longitude': -75.1560592651367},
#     'transactions': ['delivery', 'pickup'],
#     'price': '$$',
#     'location': {'address1': '1000 Race St',
#      'address2': '',
#      'address3': '',
#      'city': 'Philadelphia',
#      'zip_code': '19107',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['1000 Race St', 'Philadelphia, PA 19107']},
#     'phone': '+12159224930',
#     'display_phone': '(215) 922-4930',
#     'distance': 1294.7415596892286}],
#   'total': 413,
#   'region': {'center': {'longitude': -75.17120361328125,
#     'latitude': 39.95378209544653}},
#   'Ethnicity': 'chinese'},
#  {'businesses': [{'id': 'kiA1mrC2ZVoRmpsWgAT7ow',
#     'alias': 'hippot-shabu-shabu-philadelphia',
#     'name': 'Hippot Shabu Shabu',
#     'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/h0epqQlioueNj5hy82WEmw/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/hippot-shabu-shabu-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 281,
#     'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#      {'alias': 'hotpot', 'title': 'Hot Pot'},
#      {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#     'rating': 3.5,
#     'coordinates': {'latitude': 39.953486, 'longitude': -75.156575},
#     'transactions': ['delivery'],
#     'price': '$$',
#     'location': {'address1': '1002 Arch St',
#      'address2': '',
#      'address3': '',
#      'city': 'Philadelphia',
#      'zip_code': '19107',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['1002 Arch St', 'Philadelphia, PA 19107']},
#     'phone': '+12159288838',
#     'display_phone': '(215) 928-8838',
#     'distance': 1247.3479479807174},
#    {'id': 'Ke7FEXPJc6q54_DvVg995g',
#     'alias': 'hok-heng-philadelphia-2',
#     'name': 'Hok Heng',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/D0n_sZ3KxqDjWyJQtSFTTA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/hok-heng-philadelphia-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 6,
#     'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#      {'alias': 'chicken_wings', 'title': 'Chicken Wings'},
#      {'alias': 'pizza', 'title': 'Pizza'}],
#     'rating': 4.5,
#     'coordinates': {'latitude': 39.9792, 'longitude': -75.16336},
#     'transactions': [],
#     'location': {'address1': '1716 Cecil B Moore Ave',
#      'address2': '',
#      'address3': '',
#      'city': 'Philadelphia',
#      'zip_code': '19121',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['1716 Cecil B Moore Ave', 'Philadelphia, PA 19121']},
#     'phone': '+12157698772',
#     'display_phone': '(215) 769-8772',
#     'distance': 2900.8730237716804},
#    {'id': 'T9C1od-JorSPXwXgzSqM9Q',
#     'alias': 'davids-mai-lai-wah-philadelphia',
#     'name': "David's Mai Lai Wah",
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ApMvR2sSNF7ddL-O8gtAzw/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/davids-mai-lai-wah-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 512,
#     'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#      {'alias': 'seafood', 'title': 'Seafood'},
#      {'alias': 'chickenshop', 'title': 'Chicken Shop'}],
#     'rating': 3.0,
#     'coordinates': {'latitude': 39.9554942500129, 'longitude': -75.1559746},
#     'transactions': ['delivery'],
#     'price': '$$',
#     'location': {'address1': '1001 Race St',
#      'address2': '',
#      'address3': '',
#      'city': 'Philadelphia',
#      'zip_code': '19107',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['1001 Race St', 'Philadelphia, PA 19107']},
#     'phone': '+12156272610',
#     'display_phone': '(215) 627-2610',
#     'distance': 1311.9582030198292},
#    {'id': 'VRnJgj0IvxoksHppE78X2Q',
#     'alias': 'lee-how-fook-philadelphia',
#     'name': 'Lee How Fook',
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Brhw7Z48Kzy07VtOrN0W3A/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/lee-how-fook-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 220,
#     'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#      {'alias': 'cantonese', 'title': 'Cantonese'}],
#     'rating': 4.0,
#     'coordinates': {'latitude': 39.95626, 'longitude': -75.1570799},
#     'transactions': ['delivery', 'pickup'],
#     'price': '$$',
#     'location': {'address1': '219 N 11th St',
#      'address2': '',
#      'address3': '',
#      'city': 'Philadelphia',
#      'zip_code': '19107',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['219 N 11th St', 'Philadelphia, PA 19107']},
#     'phone': '+12159257266',
#     'display_phone': '(215) 925-7266',
#     'distance': 1235.0907861620942},
#    {'id': 'qDEcJ48kXdWxQGZefgG94w',
#     'alias': 'xun-yu-si-kao-philadelphia-2',
#     'name': 'Xun Yu Si Kao',
#     'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/nD4S1SCvvW1wlPeoz_7zAw/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/xun-yu-si-kao-philadelphia-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 88,
#     'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#      {'alias': 'hotpot', 'title': 'Hot Pot'},
#      {'alias': 'chinese', 'title': 'Chinese'}],
#     'rating': 4.0,
#     'coordinates': {'latitude': 39.954813, 'longitude': -75.156315},
#     'transactions': ['delivery'],
#     'price': '$$',
#     'location': {'address1': '140 N 10th St',
#      'address2': '',
#      'address3': None,
#      'city': 'Philadelphia',
#      'zip_code': '19107',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['140 N 10th St', 'Philadelphia, PA 19107']},
#     'phone': '+12152782366',
#     'display_phone': '(215) 278-2366',
#     'distance': 1274.2295652567975},
#    {'id': 'm0za_1Ocf0Q0rxlBYVDq7g',
#     'alias': 'paradise-inn-philadelphia',
#     'name': 'Paradise Inn',
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Vy4ce_e46PHRqNbqGYP0Kw/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/paradise-inn-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 7,
#     'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#     'rating': 4.5,
#     'coordinates': {'latitude': 39.97407, 'longitude': -75.18127},
#     'transactions': ['delivery'],
#     'location': {'address1': '2720 W Girard Ave',
#      'address2': '',
#      'address3': None,
#      'city': 'Philadelphia',
#      'zip_code': '19130',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['2720 W Girard Ave', 'Philadelphia, PA 19130']},
#     'phone': '+12157656094',
#     'display_phone': '(215) 765-6094',
#     'distance': 2421.9096296138237},
#    {'id': 'RnMGVQpGRmEmJlI7Uewi4A',
#     'alias': 'taijiang-snackies-philadelphia',
#     'name': 'Taijiang Snackies',
#     'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xe3YsYh2G0oc25nhSy_fOA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/taijiang-snackies-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 5,
#     'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#     'rating': 4.5,
#     'coordinates': {'latitude': 39.9538131, 'longitude': -75.1563882},
#     'transactions': [],
#     'price': '$',
#     'location': {'address1': '106 N 10th St',
#      'address2': '',
#      'address3': '',
#      'city': 'Philadelphia',
#      'zip_code': '19107',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['106 N 10th St', 'Philadelphia, PA 19107']},
#     'phone': '',
#     'display_phone': '',
#     'distance': 1268.1472518621626},
#    {'id': '6JeOgP-NpUedS4u5Iz3qlA',
#     'alias': 'ocean-harmony-philadelphia',
#     'name': 'Ocean Harmony',
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/RNhghAJjjjmtQIRSLFOD-g/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/ocean-harmony-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 24,
#     'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#      {'alias': 'seafood', 'title': 'Seafood'},
#      {'alias': 'chinese', 'title': 'Chinese'}],
#     'rating': 3.5,
#     'coordinates': {'latitude': 39.95551, 'longitude': -75.15558},
#     'transactions': ['delivery'],
#     'price': '$$',
#     'location': {'address1': '937 Race St',
#      'address2': '2nd Floor',
#      'address3': None,
#      'city': 'Philadelphia',
#      'zip_code': '19107',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['937 Race St',
#       '2nd Floor',
#       'Philadelphia, PA 19107']},
#     'phone': '+12159288826',
#     'display_phone': '(215) 928-8826',
#     'distance': 1338.467073165599},
#    {'id': 'tjjVkpJSZj6ZnzcChezCuA',
#     'alias': 'shaxian-delicacies-philadelphia',
#     'name': 'Shaxian Delicacies',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/pR4S62oEKUIYI_oRbYgXxQ/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/shaxian-delicacies-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 6,
#     'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#     'rating': 3.5,
#     'coordinates': {'latitude': 39.9539055255682,
#      'longitude': -75.1563203707337},
#     'transactions': ['delivery'],
#     'location': {'address1': '106 N 10th St',
#      'address2': '',
#      'address3': None,
#      'city': 'Philadelphia',
#      'zip_code': '19107',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['106 N 10th St', 'Philadelphia, PA 19107']},
#     'phone': '',
#     'display_phone': '',
#     'distance': 1268.687779184366},
#    {'id': 'uOpUwgX4Xf6copxDjNvvUA',
#     'alias': 'temple-star-philadelphia',
#     'name': 'Temple Star',
#     'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/NWMHxHwtEVWItqW3GV3pUQ/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/temple-star-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 23,
#     'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#     'rating': 3.0,
#     'coordinates': {'latitude': 39.9846, 'longitude': -75.15723},
#     'transactions': ['delivery', 'pickup'],
#     'price': '$$$$',
#     'location': {'address1': '1412 W Diamond St',
#      'address2': '',
#      'address3': '',
#      'city': 'Philadelphia',
#      'zip_code': '19121',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['1412 W Diamond St', 'Philadelphia, PA 19121']},
#     'phone': '+12152368990',
#     'display_phone': '(215) 236-8990',
#     'distance': 3631.5655855400105},
#    {'id': '0zWAsCBzvuCI_Ydx7yH1Jw',
#     'alias': 'shing-kee-philadelphia',
#     'name': 'Shing Kee',
#     'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/iZW1ZBY3M9NEA1rdHCEe_Q/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/shing-kee-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 77,
#     'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#      {'alias': 'noodles', 'title': 'Noodles'},
#      {'alias': 'soup', 'title': 'Soup'}],
#     'rating': 4.0,
#     'coordinates': {'latitude': 39.935049, 'longitude': -75.154918},
#     'transactions': [],
#     'price': '$$',
#     'location': {'address1': '600 Washington Ave',
#      'address2': '',
#      'address3': '',
#      'city': 'Philadelphia',
#      'zip_code': '19147',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['600 Washington Ave', 'Philadelphia, PA 19147']},
#     'phone': '+12156448954',
#     'display_phone': '(215) 644-8954',
#     'distance': 2503.2921246307596},
#    {'id': '880CBnInNNpxm_26vamRWQ',
#     'alias': 'hai-tien-restaurant-philadelphia',
#     'name': 'Hai Tien Restaurant',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ZMwTTycUaa2KF_G9QvEKag/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/hai-tien-restaurant-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 6,
#     'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#      {'alias': 'vietnamese', 'title': 'Vietnamese'}],
#     'rating': 4.5,
#     'coordinates': {'latitude': 39.9383386111494,
#      'longitude': -75.1702273320272},
#     'transactions': [],
#     'price': '$',
#     'location': {'address1': '1603 Washington Ave',
#      'address2': '',
#      'address3': '',
#      'city': 'Philadelphia',
#      'zip_code': '19146',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['1603 Washington Ave', 'Philadelphia, PA 19146']},
#     'phone': '+12157328970',
#     'display_phone': '(215) 732-8970',
#     'distance': 1750.7837029436396},
#    {'id': 'momyNsSDMDk6fR8W-JgqFw',
#     'alias': 'michaels-chinese-kitchen-philadelphia',
#     'name': "Michael's Chinese Kitchen",
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/matSp16GdJ1B4DiW38sQCQ/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/michaels-chinese-kitchen-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 26,
#     'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#      {'alias': 'sushi', 'title': 'Sushi Bars'}],
#     'rating': 4.0,
#     'coordinates': {'latitude': 39.9347305, 'longitude': -75.1709137},
#     'transactions': ['delivery', 'pickup'],
#     'price': '$',
#     'location': {'address1': '1601 Wharton St',
#      'address2': None,
#      'address3': None,
#      'city': 'Philadelphia',
#      'zip_code': '19146',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['1601 Wharton St', 'Philadelphia, PA 19146']},
#     'phone': '+12155518808',
#     'display_phone': '(215) 551-8808',
#     'distance': 2122.3901011785388},
#    {'id': 'XvV9B9Y4YfVVehSVkX6Ulg',
#     'alias': 'siu-kee-duck-house-philadelphia',
#     'name': 'Siu Kee Duck House',
#     'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/94uHvR24_CzuG0-HKGw_FA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/siu-kee-duck-house-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 95,
#     'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#      {'alias': 'bbq', 'title': 'Barbeque'}],
#     'rating': 4.0,
#     'coordinates': {'latitude': 39.9539, 'longitude': -75.15603},
#     'transactions': ['delivery', 'pickup'],
#     'price': '$',
#     'location': {'address1': '111 N 10th St',
#      'address2': '',
#      'address3': '',
#      'city': 'Philadelphia',
#      'zip_code': '19107',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['111 N 10th St', 'Philadelphia, PA 19107']},
#     'phone': '+12159223075',
#     'display_phone': '(215) 922-3075',
#     'distance': 1299.7324007445197},
#    {'id': 'OCR7S1ymLXezUwUB8N5TCg',
#     'alias': 'lees-kitchen-philadelphia',
#     'name': "Lee's Kitchen",
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/UjfRZDxXSMLSU4rDH21G0g/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/lees-kitchen-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 29,
#     'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#     'rating': 3.5,
#     'coordinates': {'latitude': 39.97408, 'longitude': -75.18382},
#     'transactions': ['delivery'],
#     'price': '$',
#     'location': {'address1': '930 N 29th St',
#      'address2': '',
#      'address3': '',
#      'city': 'Philadelphia',
#      'zip_code': '19130',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['930 N 29th St', 'Philadelphia, PA 19130']},
#     'phone': '+12157691282',
#     'display_phone': '(215) 769-1282',
#     'distance': 2500.890877130879},
#    {'id': 'l02jjfbmaLhHKCX39FOrBg',
#     'alias': 'the-chinese-noodle-factory-philadelphia',
#     'name': 'The Chinese Noodle Factory',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/mP7CLDblYXvB_lZbjIs5ew/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/the-chinese-noodle-factory-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 7,
#     'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#      {'alias': 'noodles', 'title': 'Noodles'}],
#     'rating': 4.5,
#     'coordinates': {'latitude': 39.95492, 'longitude': -75.15735},
#     'transactions': ['delivery'],
#     'price': '$',
#     'location': {'address1': '133 N 11th St',
#      'address2': '',
#      'address3': '',
#      'city': 'Philadelphia',
#      'zip_code': '19107',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['133 N 11th St', 'Philadelphia, PA 19107']},
#     'phone': '+12159221688',
#     'display_phone': '(215) 922-1688',
#     'distance': 1189.6719767274878},
#    {'id': 'PHyXrC_xG4wXCNmx1ACfmw',
#     'alias': 'kyodong-noodles-philadelphia',
#     'name': 'Kyodong Noodles',
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9jkRtvOuNh8o8QPkNgaVtQ/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/kyodong-noodles-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 4,
#     'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#      {'alias': 'seafood', 'title': 'Seafood'},
#      {'alias': 'noodles', 'title': 'Noodles'}],
#     'rating': 4.0,
#     'coordinates': {'latitude': 40.045019, 'longitude': -75.1175037},
#     'transactions': ['delivery', 'pickup'],
#     'location': {'address1': '6201 N Front St',
#      'address2': '124-B',
#      'address3': '',
#      'city': 'Philadelphia',
#      'zip_code': '19120',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['6201 N Front St',
#       '124-B',
#       'Philadelphia, PA 19120']},
#     'phone': '',
#     'display_phone': '',
#     'distance': 11128.602676293827},
#    {'id': 'gu7iuTiVwyPAI_S2fwVi9Q',
#     'alias': 'china-house-philadelphia-13',
#     'name': 'China House',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/KKjDy4WsFxQi5JTbekn_6w/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/china-house-philadelphia-13?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 39,
#     'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#     'rating': 3.5,
#     'coordinates': {'latitude': 39.9786643981934,
#      'longitude': -75.1593627929688},
#     'transactions': ['delivery', 'pickup'],
#     'price': '$',
#     'location': {'address1': '1430 Cecil B Moore Ave',
#      'address2': '',
#      'address3': '',
#      'city': 'Philadelphia',
#      'zip_code': '19121',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['1430 Cecil B Moore Ave', 'Philadelphia, PA 19121']},
#     'phone': '+12157699788',
#     'display_phone': '(215) 769-9788',
#     'distance': 2953.0678048609934},
#    {'id': '332MG0dFd8d2JUcszdRdYw',
#     'alias': 'delightful-garden-philadelphia',
#     'name': 'Delightful Garden',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/KIMtDeiLcC79Dnr8shRd8Q/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/delightful-garden-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 53,
#     'categories': [{'alias': 'szechuan', 'title': 'Szechuan'},
#      {'alias': 'desserts', 'title': 'Desserts'},
#      {'alias': 'karaoke', 'title': 'Karaoke'}],
#     'rating': 3.0,
#     'coordinates': {'latitude': 39.9532839, 'longitude': -75.1552661},
#     'transactions': ['delivery', 'pickup'],
#     'price': '$$',
#     'location': {'address1': '906 Arch St',
#      'address2': '',
#      'address3': '',
#      'city': 'Philadelphia',
#      'zip_code': '19107',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['906 Arch St', 'Philadelphia, PA 19107']},
#     'phone': '+12159225588',
#     'display_phone': '(215) 922-5588',
#     'distance': 1359.6123626488477},
#    {'id': 'DKXeB-JIou5XPI49CzITuQ',
#     'alias': 'china-house-philadelphia-11',
#     'name': 'China House',
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2WgbJpHnEbdworvSLiloiw/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/china-house-philadelphia-11?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 62,
#     'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#     'rating': 4.0,
#     'coordinates': {'latitude': 39.9185859, 'longitude': -75.1836863},
#     'transactions': ['delivery'],
#     'price': '$',
#     'location': {'address1': '2123 W Oregon Ave',
#      'address2': '',
#      'address3': '',
#      'city': 'Philadelphia',
#      'zip_code': '19145',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['2123 W Oregon Ave', 'Philadelphia, PA 19145']},
#     'phone': '+12152718840',
#     'display_phone': '(215) 271-8840',
#     'distance': 4007.6418628175006}],
#   'total': 413,
#   'region': {'center': {'longitude': -75.17120361328125,
#     'latitude': 39.95378209544653}},
#   'Ethnicity': 'chinese'},
#  {'businesses': [{'id': 'xYHDcds5WortjUJnfvh_wA',
#     'alias': 'chili-garden-philadelphia-4',
#     'name': 'Chili Garden',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/XJuHg9X1x-clfc2lCQsjqg/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/chili-garden-philadelphia-4?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 61,
#     'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#     'rating': 3.5,
#     'coordinates': {'latitude': 39.94852, 'longitude': -75.2163099},
#     'transactions': ['delivery', 'pickup'],
#     'price': '$',
#     'location': {'address1': '4626 Baltimore Ave',
#      'address2': '',
#      'address3': None,
#      'city': 'Philadelphia',
#      'zip_code': '19143',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['4626 Baltimore Ave', 'Philadelphia, PA 19143']},
#     'phone': '+12153861888',
#     'display_phone': '(215) 386-1888',
#     'distance': 3884.0566428458906},
#    {'id': '0cHDa2cXCF4PZzO2krXypg',
#     'alias': 'bo-sing-philadelphia',
#     'name': 'Bo Sing',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/KSH4i1xSY3RQ_foQgt4TRw/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/bo-sing-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 11,
#     'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#      {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#     'rating': 4.0,
#     'coordinates': {'latitude': 39.95696, 'longitude': -75.20237},
#     'transactions': ['delivery'],
#     'price': '$',
#     'location': {'address1': '4006 Market St',
#      'address2': '',
#      'address3': '',
#      'city': 'Philadelphia',
#      'zip_code': '19104',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['4006 Market St', 'Philadelphia, PA 19104']},
#     'phone': '+12153828888',
#     'display_phone': '(215) 382-8888',
#     'distance': 2681.309095623714},
#    {'id': '1FeB0RbAz9kdoZsTf05arw',
#     'alias': 'orient-express-philadelphia',
#     'name': 'Orient Express',
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BwleDpe5g-3KD_exvPj9Uw/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/orient-express-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 15,
#     'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#      {'alias': 'foodstands', 'title': 'Food Stands'}],
#     'rating': 3.5,
#     'coordinates': {'latitude': 39.98056, 'longitude': -75.15338},
#     'transactions': [],
#     'price': '$',
#     'location': {'address1': '1835 N 12th St',
#      'address2': 'Ste 7',
#      'address3': '',
#      'city': 'Philadelphia',
#      'zip_code': '19122',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['1835 N 12th St', 'Ste 7', 'Philadelphia, PA 19122']},
#     'phone': '+12152365191',
#     'display_phone': '(215) 236-5191',
#     'distance': 3381.592253558745},
#    {'id': '7hwH3wiWB17U9Nw4EjJo0A',
#     'alias': 'xian-sizzling-woks-philadelphia-7',
#     'name': "Xi'an Sizzling Woks",
#     'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UXfQS4KBTp4nOm8eH2UIhQ/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/xian-sizzling-woks-philadelphia-7?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 45,
#     'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#     'rating': 3.0,
#     'coordinates': {'latitude': 39.95537, 'longitude': -75.20247},
#     'transactions': ['delivery', 'pickup'],
#     'price': '$$',
#     'location': {'address1': '4000 Chestnut St',
#      'address2': None,
#      'address3': '',
#      'city': 'Philadelphia',
#      'zip_code': '19104',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['4000 Chestnut St', 'Philadelphia, PA 19104']},
#     'phone': '+12152229777',
#     'display_phone': '(215) 222-9777',
#     'distance': 2668.1219687362936},
#    {'id': 'qU_CC7nJ-rOfCusuapOW8g',
#     'alias': 'lucky-restaurant-philadelphia',
#     'name': 'Lucky Restaurant',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/OGYnGNIBOBVPPS4g2YnkVw/o.jpg',
# ...
#     'phone': '+12153388288',
#     'display_phone': '(215) 338-8288',
#     'distance': 14296.778075136708},
#    {'id': 'LF0xly7JIplsQjT_9oW2QQ',
#     'alias': 'panda-house-philadelphia-3',
#     'name': 'Panda House',
#     'image_url': '',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/panda-house-philadelphia-3?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 1,
#     'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#     'rating': 2.0,
#     'coordinates': {'latitude': 40.0312538146973,
#      'longitude': -75.0897598266602},
#     'transactions': ['pickup', 'delivery'],
#     'location': {'address1': '977 Bridge St',
#      'address2': None,
#      'address3': None,
#      'city': 'Philadelphia',
#      'zip_code': '19124',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['977 Bridge St', 'Philadelphia, PA 19124']},
#     'phone': '+12155353788',
#     'display_phone': '(215) 535-3788',
#     'distance': 11062.878829546942},
#    {'id': '1SpXRNnRdhr9rCvf_6i5IA',
#     'alias': 'koi-asian-fusion-runnemede-3',
#     'name': 'Koi Asian Fusion',
#     'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/w-5B6L_q7OCliZ2Qeg2ADQ/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/koi-asian-fusion-runnemede-3?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 2,
#     'categories': [{'alias': 'cantonese', 'title': 'Cantonese'},
#      {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#      {'alias': 'gluten_free', 'title': 'Gluten-Free'}],
#     'rating': 2.0,
#     'coordinates': {'latitude': 39.8570594787598,
#      'longitude': -75.0639877319336},
#     'transactions': ['pickup', 'delivery'],
#     'price': '$',
#     'location': {'address1': '835 E Clements Bridge Rd',
#      'address2': 'Ste 6',
#      'address3': None,
#      'city': 'Runnemede',
#      'zip_code': '08078',
#      'country': 'US',
#      'state': 'NJ',
#      'display_address': ['835 E Clements Bridge Rd',
#       'Ste 6',
#       'Runnemede, NJ 08078']},
#     'phone': '+18569398868',
#     'display_phone': '(856) 939-8868',
#     'distance': 14121.092315316257}],
#   'total': 413,
#   'region': {'center': {'longitude': -75.17120361328125,
#     'latitude': 39.95378209544653}},
#   'Ethnicity': 'chinese'},
#  {'businesses': [{'id': 'J2z_Yvh0jSTkLAe6SePUXg',
#     'alias': 'hot-wok-philadelphia',
#     'name': 'Hot Wok',
#     'image_url': '',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/hot-wok-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 4,
#     'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#     'rating': 2.5,
#     'coordinates': {'latitude': 40.04273, 'longitude': -75.12883},
#     'transactions': ['delivery'],
#     'location': {'address1': '6005 N 5th St',
#      'address2': '',
#      'address3': '',
#      'city': 'Philadelphia',
#      'zip_code': '19120',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['6005 N 5th St', 'Philadelphia, PA 19120']},
#     'phone': '+12159278000',
#     'display_phone': '(215) 927-8000',
#     'distance': 10527.544983934315},
#    {'id': 'E-GajYuzihh0A1VNQImrkA',
#     'alias': 'great-wall-restaurant-philadelphia-4',
#     'name': 'Great Wall Restaurant',
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/MzkHbA49ltU5hNoUsAL6nQ/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/great-wall-restaurant-philadelphia-4?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 4,
#     'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#     'rating': 3.0,
#     'coordinates': {'latitude': 40.0241814, 'longitude': -75.0461426},
#     'transactions': ['delivery'],
#     'location': {'address1': '6705 Torresdale Ave',
#      'address2': '',
#      'address3': '',
#      'city': 'Philadelphia',
#      'zip_code': '19135',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['6705 Torresdale Ave', 'Philadelphia, PA 19135']},
#     'phone': '+12153318883',
#     'display_phone': '(215) 331-8883',
#     'distance': 13224.548409541154},
#    {'id': '7Ct4QuWaY63DkAOXqEiVGA',
#     'alias': 'hong-kong-chinese-restaurant-glenolden',
#     'name': 'Hong Kong Chinese Restaurant',
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XjKaVBxfiMLfZ0HuwpkB-g/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/hong-kong-chinese-restaurant-glenolden?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 18,
#     'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#     'rating': 3.0,
#     'coordinates': {'latitude': 39.90347, 'longitude': -75.28426},
#     'transactions': ['delivery'],
#     'price': '$',
#     'location': {'address1': '326 N Chester Pike',
#      'address2': '',
#      'address3': '',
#      'city': 'Glenolden',
#      'zip_code': '19036',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['326 N Chester Pike', 'Glenolden, PA 19036']},
#     'phone': '+16104615370',
#     'display_phone': '(610) 461-5370',
#     'distance': 11165.406581567395},
#    {'id': 'TWJHKT9TvktOl5sCj8PxQw',
#     'alias': 'happy-garden-philadelphia-6',
#     'name': 'Happy Garden',
#     'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/H-5Fy9nsNtGRpKfPs5i9zg/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/happy-garden-philadelphia-6?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 1,
#     'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#     'rating': 3.0,
#     'coordinates': {'latitude': 40.0406456, 'longitude': -75.1441879},
#     'transactions': [],
#     'location': {'address1': '5723 N Broad St',
#      'address2': '',
#      'address3': '',
#      'city': 'Philadelphia',
#      'zip_code': '19141',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['5723 N Broad St', 'Philadelphia, PA 19141']},
#     'phone': '+12155486258',
#     'display_phone': '(215) 548-6258',
#     'distance': 9902.081745084488},
#    {'id': '-CW326s4UVLaZhy5BE4qiA',
#     'alias': 'tai-won-chinese-restaurant-philadelphia',
#     'name': 'Tai Won Chinese Restaurant',
#     'image_url': '',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/tai-won-chinese-restaurant-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 2,
#     'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#     'rating': 3.0,
#     'coordinates': {'latitude': 40.00906, 'longitude': -75.10019},
#     'transactions': [],
#     'price': '$',
#     'location': {'address1': '1401 E Lycoming St',
#      'address2': 'Ste 3',
#      'address3': '',
#      'city': 'Philadelphia',
#      'zip_code': '19124',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['1401 E Lycoming St',
#       'Ste 3',
#       'Philadelphia, PA 19124']},
#     'phone': '+12152899628',
#     'display_phone': '(215) 289-9628',
#     'distance': 8626.649118772604},
#    {'id': '6ozWnjKn9336r-HWpl9p3w',
#     'alias': 'asia-express-philadelphia',
#     'name': 'Asia Express',
#     'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/oumgJVXWtp86Gej0-P2zDQ/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/asia-express-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 3,
#     'categories': [{'alias': 'cantonese', 'title': 'Cantonese'},
#      {'alias': 'szechuan', 'title': 'Szechuan'}],
#     'rating': 3.0,
#     'coordinates': {'latitude': 40.05096, 'longitude': -75.06677},
#     'transactions': ['delivery', 'pickup'],
#     'price': '$',
#     'location': {'address1': '7246 Castor Ave',
#      'address2': '',
#      'address3': '',
#      'city': 'Philadelphia',
#      'zip_code': '19149',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['7246 Castor Ave', 'Philadelphia, PA 19149']},
#     'phone': '+12157257601',
#     'display_phone': '(215) 725-7601',
#     'distance': 13993.799076799483},
#    {'id': 'pZGUnFYoXr2ccOxWr-F9Cw',
#     'alias': 'fresh-garden-philadelphia',
#     'name': 'Fresh Garden',
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Rt6LqKQKO20G6YrJl2vZDw/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/fresh-garden-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 19,
#     'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#      {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#      {'alias': 'chinese', 'title': 'Chinese'}],
#     'rating': 1.5,
#     'coordinates': {'latitude': 40.0438271, 'longitude': -75.0534515},
#     'transactions': ['delivery', 'pickup'],
#     'price': '$$',
#     'location': {'address1': '2812 Cottman Ave',
#      'address2': '',
#      'address3': '',
#      'city': 'Philadelphia',
#      'zip_code': '19149',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['2812 Cottman Ave', 'Philadelphia, PA 19149']},
#     'phone': '+12153388808',
#     'display_phone': '(215) 338-8808',
#     'distance': 14156.489767761885},
#    {'id': 'pqpWW-wiEBWhPTgqtlTFsA',
#     'alias': 'chows-chinese-restaurant-collingswood-2',
#     'name': "Chow's Chinese Restaurant",
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/rhcd90okZWygbQ8aoUaD5Q/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/chows-chinese-restaurant-collingswood-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 52,
#     'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#      {'alias': 'japanese', 'title': 'Japanese'},
#      {'alias': 'sushi', 'title': 'Sushi Bars'}],
#     'rating': 3.0,
#     'coordinates': {'latitude': 39.916815, 'longitude': -75.070022},
#     'transactions': ['delivery'],
#     'price': '$',
#     'location': {'address1': '657 Haddon Ave',
#      'address2': '',
#      'address3': '',
#      'city': 'Collingswood',
#      'zip_code': '08108',
#      'country': 'US',
#      'state': 'NJ',
#      'display_address': ['657 Haddon Ave', 'Collingswood, NJ 08108']},
#     'phone': '+18568582882',
#     'display_phone': '(856) 858-2882',
#     'distance': 9556.084219961613},
#    {'id': 'xhn7l8vk2GlIY2ErkAE5jw',
#     'alias': 'no-1-china-folcroft-2',
#     'name': 'No 1 China',
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YsT8-wRj2cO9j_J56v6RrQ/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/no-1-china-folcroft-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 8,
#     'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#     'rating': 1.5,
#     'coordinates': {'latitude': 39.8926801, 'longitude': -75.28238},
#     'transactions': ['delivery', 'pickup'],
#     'price': '$',
#     'location': {'address1': '1844 Delmar Dr',
#      'address2': '',
#      'address3': '',
#      'city': 'Folcroft',
#      'zip_code': '19032',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['1844 Delmar Dr', 'Folcroft, PA 19032']},
#     'phone': '+16102378982',
#     'display_phone': '(610) 237-8982',
#     'distance': 11735.992913712393},
#    {'id': 'jM_9HiTXoZQWOTo49zdf2g',
#     'alias': 'no-1-chinese-kitchen-haddonfield',
#     'name': 'No 1 Chinese Kitchen',
#     'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/uOdKyIsFPPSfMHYusGrdmA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/no-1-chinese-kitchen-haddonfield?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 18,
#     'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#     'rating': 3.0,
#     'coordinates': {'latitude': 39.900891, 'longitude': -75.053177},
#     'transactions': ['delivery'],
#     'price': '$$',
#     'location': {'address1': '413 W Crystal Lake Ave',
#      'address2': 'Ste 5',
#      'address3': '',
#      'city': 'Haddonfield',
#      'zip_code': '08033',
#      'country': 'US',
#      'state': 'NJ',
#      'display_address': ['413 W Crystal Lake Ave',
#       'Ste 5',
#       'Haddonfield, NJ 08033']},
#     'phone': '+18568540316',
#     'display_phone': '(856) 854-0316',
#     'distance': 11656.633491429006},
#    {'id': 'n5tFiNbFgwNQugDLLG96QQ',
#     'alias': 'lansdowne-chinese-restaurant-lansdowne',
#     'name': 'Lansdowne Chinese Restaurant',
#     'image_url': '',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/lansdowne-chinese-restaurant-lansdowne?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 1,
#     'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#     'rating': 1.0,
#     'coordinates': {'latitude': 39.9384548658733,
#      'longitude': -75.2723349339402},
#     'transactions': [],
#     'price': '$',
#     'location': {'address1': '10 N Lansdowne Ave',
#      'address2': '',
#      'address3': '',
#      'city': 'Lansdowne',
#      'zip_code': '19050',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['10 N Lansdowne Ave', 'Lansdowne, PA 19050']},
#     'phone': '+16102593739',
#     'display_phone': '(610) 259-3739',
#     'distance': 8793.767777334275},
#    {'id': 'Ii_rSNFmaXnHCMWuyy-iOA',
#     'alias': 'no-1-china-clifton-heights',
#     'name': 'No 1 China',
#     'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_eR2TY1jaVjfRJ9AuTcxWA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/no-1-china-clifton-heights?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 10,
#     'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#      {'alias': 'seafood', 'title': 'Seafood'}],
#     'rating': 2.5,
#     'coordinates': {'latitude': 39.930172, 'longitude': -75.2952009},
#     'transactions': ['delivery', 'pickup'],
#     'price': '$',
#     'location': {'address1': '107 E Baltimore Ave',
#      'address2': None,
#      'address3': None,
#      'city': 'Clifton Heights',
#      'zip_code': '19018',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['107 E Baltimore Ave', 'Clifton Heights, PA 19018']},
#     'phone': '+16103949973',
#     'display_phone': '(610) 394-9973',
#     'distance': 10911.319793898978},
#    {'id': 'zLbDAJyWh5dFFqKj27rmDA',
#     'alias': 'new-china-collingdale',
#     'name': 'New China',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qCbdhA4ELcBXiQa8-JVaLA/o.jpg',
#     'is_closed': False,
#     'url': 'https://www.yelp.com/biz/new-china-collingdale?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#     'review_count': 14,
#     'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#     'rating': 2.5,
#     'coordinates': {'latitude': 39.9088565, 'longitude': -75.2841067},
#     'transactions': ['pickup'],
#     'price': '$',
#     'location': {'address1': '1207 Macdade Blvd',
#      'address2': None,
#      'address3': '',
#      'city': 'Collingdale',
#      'zip_code': '19036',
#      'country': 'US',
#      'state': 'PA',
#      'display_address': ['1207 Macdade Blvd', 'Collingdale, PA 19036']},
#     'phone': '+16105866770',
#     'display_phone': '(610) 586-6770',
#     'distance': 10959.829118510568}],
#   'total': 413,
#   'region': {'center': {'longitude': -75.17120361328125,
#     'latitude': 39.95378209544653}},
#   'Ethnicity': 'chinese'}]

# %%
chinese_name = []
chinese_city = []
chinese_latitude = []
chinese_longitude = []
chinese_zipcode = []
chinese_ethnicity = []
chinese_price = []
chinese_rating = []

# %%
for i in range(len(philadelphia_total_chinese)):
    for j in range(len(philadelphia_total_chinese[i]['businesses'])):
        chinese_name.append(philadelphia_total_chinese[i]["businesses"][j]["name"])
        chinese_city.append("Philadelphia")
        chinese_latitude.append(philadelphia_total_chinese[i]["businesses"][j]["coordinates"]["latitude"])
        chinese_longitude.append(philadelphia_total_chinese[i]["businesses"][j]["coordinates"]["longitude"])
        chinese_zipcode.append(philadelphia_total_chinese[i]["businesses"][j]["location"]["zip_code"])
        chinese_ethnicity.append((philadelphia_total_chinese[i]['Ethnicity']))
        try:
            chinese_price.append(philadelphia_total_chinese[i]["businesses"][j]["price"])
        except KeyError:
            chinese_price.append("N/A")
        chinese_rating.append(philadelphia_total_chinese[i]["businesses"][j]["rating"])

# %%
print(len(chinese_name))
print(len(chinese_city))
print(len(chinese_latitude))
print(len(chinese_longitude))
print(len(chinese_zipcode))
print(len(chinese_rating))
# Out:
# 346
# 346
# 346
# 346
# 346
# 346

# %%
chinese_dict = {
    "name": name,
    "city": city,
    "latitude": latitude,
    "longitude": longitude,
    "zipcode": zipcode,
    "ethnicity": ethnicity,
    "price": price,
    "rating": rating}

chinese_df = pd.DataFrame(chinese_dict)
chinese_df
# Out:
#                                  name          city   latitude  longitude  \
# 0                       Chubby Cattle  Philadelphia  39.954980 -75.156220
# 1    Nan Zhou Hand Drawn Noodle House  Philadelphia  39.955401 -75.156901
# 2                      Dim Sum Garden  Philadelphia  39.955399 -75.156727
# 3                       Dim Sum House  Philadelphia  39.951885 -75.172466
# 4                             Dan Dan  Philadelphia  39.950249 -75.167595
# ..                                ...           ...        ...        ...
# 341                        No 1 China  Philadelphia  39.892680 -75.282380
# 342              No 1 Chinese Kitchen  Philadelphia  39.900891 -75.053177
# 343      Lansdowne Chinese Restaurant  Philadelphia  39.938455 -75.272335
# 344                        No 1 China  Philadelphia  39.930172 -75.295201
# 345                         New China  Philadelphia  39.908856 -75.284107
#
#     zipcode ethnicity price  rating
# 0     19107   chinese   N/A     4.5
# 1     19107   chinese     $     4.0
# 2     19107   chinese     $     4.0
# 3     19103   chinese    $$     4.0
# 4     19102   chinese    $$     4.0
# ..      ...       ...   ...     ...
# 341   19032   chinese     $     1.5
# 342   08033   chinese    $$     3.0
# 343   19050   chinese     $     1.0
# 344   19018   chinese     $     2.5
# 345   19036   chinese     $     2.5
#
# [346 rows x 8 columns]

# %%
#each of the next ethinicities for philly will be in separate cell
#french
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'Philadelphia', 'categories':'french' }
    
philadelphia_french = requests.get(API_HOST,headers=headers, params=params).json()

philly_ethnic_totals.loc[1, 'City'] = 'Philadelphia'
philly_ethnic_totals.loc[1, 'Ethnicity'] = 'French'
philly_ethnic_totals.loc[1, 'Total Restaurants'] = (philadelphia_french["total"])

philadelphia_french
# Out:
# {'businesses': [{'id': 'j-qtdD55OLfSqfsWuQTDJg',
#    'alias': 'parc-philadelphia-2',
#    'name': 'Parc',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/DNFDPj4vUDVRf7fx4JLI7A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/parc-philadelphia-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 2574,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.9491724, 'longitude': -75.1707273},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '227 S 18th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19103',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['227 S 18th St', 'Philadelphia, PA 19103']},
#    'phone': '+12155452262',
#    'display_phone': '(215) 545-2262',
#    'distance': 514.1796872022128},
#   {'id': 'ExRxjqOGmkWjArvM_qBORw',
#    'alias': 'the-wayward-philadelphia',
#    'name': 'The Wayward',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/A-72wiGpqRGbrcNAfivd3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-wayward-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 42,
#    'categories': [{'alias': 'brasseries', 'title': 'Brasseries'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.9509148952045,
#     'longitude': -75.1595963537693},
#    'transactions': ['delivery'],
#    'location': {'address1': '1170 Ludlow St',
#     'address2': '',
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19107',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1170 Ludlow St', 'Philadelphia, PA 19107']},
#    'phone': '+12152589430',
#    'display_phone': '(215) 258-9430',
#    'distance': 1039.4964729384938},
#   {'id': 'Oz7c0QA1C18Cb6tTdoehwQ',
#    'alias': 'gabi-philadelphia',
#    'name': 'Gabi',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/2ZpaflFSoA62ZGThLvbgtg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gabi-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 83,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.95925, 'longitude': -75.16151},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '339 N Broad St',
#     'address2': '',
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19102',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['339 N Broad St', 'Philadelphia, PA 19102']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1008.9369528057224},
#   {'id': 'NjD-V9pdH7_V8Y8PGl-csw',
#    'alias': 'townsend-philadelphia',
#    'name': 'Townsend',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/fD8Jja2I4CXBR_jn7-thwQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/townsend-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 243,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.951097, 'longitude': -75.176542},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '2121 Walnut St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19103',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['2121 Walnut St', 'Philadelphia, PA 19103']},
#    'phone': '+12676393203',
#    'display_phone': '(267) 639-3203',
#    'distance': 544.2478745192077},
#   {'id': 'p-MSh95si_sDdih94gyKuw',
#    'alias': 'forsythia-philadelphia',
#    'name': 'Forsythia',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Ll3BkQjNhpVR3uZkv0t0Fw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/forsythia-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 84,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.9487067926056,
#     'longitude': -75.1453940570354},
#    'transactions': ['delivery'],
#    'location': {'address1': '233 Chestnut St',
#     'address2': '',
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19106',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['233 Chestnut St', 'Philadelphia, PA 19106']},
#    'phone': '+12156449395',
#    'display_phone': '(215) 644-9395',
#    'distance': 2271.260618166633},
#   {'id': 'RBCtHLVvc230q8zkRWIoyQ',
#    'alias': 'creme-brulee-bistro-and-cafe-philadelphia-2',
#    'name': 'Creme Brulee Bistro & Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gge9Wkb_gTqa8drsPN6qvA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/creme-brulee-bistro-and-cafe-philadelphia-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 153,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.9259730399126,
#     'longitude': -75.1527614380684},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1800 S 4th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19148',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1800 S 4th St', 'Philadelphia, PA 19148']},
#    'phone': '+12153349000',
#    'display_phone': '(215) 334-9000',
#    'distance': 3468.996210306558},
#   {'id': 'fEqiXG_B-fn__w0aeF3nBQ',
#    'alias': 'laurel-philadelphia-2',
#    'name': 'Laurel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/GuZ23QCoj49nfOIZguPyyg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/laurel-philadelphia-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 317,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.9294204711914,
#     'longitude': -75.1637115478516},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '1617 E Passyunk Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19148',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1617 E Passyunk Ave', 'Philadelphia, PA 19148']},
#    'phone': '+12152718299',
#    'display_phone': '(215) 271-8299',
#    'distance': 2783.705144005874},
#   {'id': 'or_WcjWELDsssk2JruvJcg',
#    'alias': 'café-lutecia-philadelphia-2',
#    'name': 'Café Lutecia',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_XL4Ijbzh72q_wABeyyxgw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caf%C3%A9-lutecia-philadelphia-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 196,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.9465999, 'longitude': -75.17958},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '2301 Lombard St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19146',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['2301 Lombard St', 'Philadelphia, PA 19146']},
#    'phone': '+12157909557',
#    'display_phone': '(215) 790-9557',
#    'distance': 1075.79696751618},
#   {'id': 'N5xoEy9GLtHDvCLa8dMgyA',
#    'alias': 'felly-bistro-on-pass-philadelphia',
#    'name': 'Felly Bistro On Pass',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hdI676r3TRhYc_qiPrm-3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/felly-bistro-on-pass-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 41,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'puertorican', 'title': 'Puerto Rican'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.938816, 'longitude': -75.152367},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '769 E Passyunk Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19147',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['769 E Passyunk Ave', 'Philadelphia, PA 19147']},
#    'phone': '+12159232860',
#    'display_phone': '(215) 923-2860',
#    'distance': 2312.550400496896},
#   {'id': '4_-IcMpkF_sBRHomWZHNzA',
#    'alias': 'bistrot-la-minette-philadelphia-2',
#    'name': 'Bistrot La Minette',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/JVcztQRbDoZjtSr5SSvo4g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bistrot-la-minette-philadelphia-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 602,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.9414622968223,
#     'longitude': -75.1523852348328},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '623 S 6th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19147',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['623 S 6th St', 'Philadelphia, PA 19147']},
#    'phone': '+12159258000',
#    'display_phone': '(215) 925-8000',
#    'distance': 2109.5064347544767},
#   {'id': 'tBQcVd9c0EHKAXLZn_v54g',
#    'alias': 'bibou-philadelphia',
#    'name': 'Bibou',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9C9kBTbfclVmIDpzzXEdFw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bibou-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 365,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.936503156566,
#     'longitude': -75.1566941458726},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '1009 S 8th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19147',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1009 S 8th St', 'Philadelphia, PA 19147']},
#    'phone': '+12159658290',
#    'display_phone': '(215) 965-8290',
#    'distance': 2285.0494950988987},
#   {'id': 'L_Rwy6oSAnMUY3NCDspxmA',
#    'alias': 'the-good-king-tavern-philadelphia',
#    'name': 'The Good King Tavern',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rRZU7Knzy49e9Op5y9w_-g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-good-king-tavern-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 324,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.941969, 'longitude': -75.154207},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '614 S 7th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19147',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['614 S 7th St', 'Philadelphia, PA 19147']},
#    'phone': '+12156253700',
#    'display_phone': '(215) 625-3700',
#    'distance': 1955.6779238682743},
#   {'id': '2pLIQ0RHSmUbF0eIRT0LYg',
#    'alias': 'vintage-wine-bar-philadelphia',
#    'name': 'Vintage Wine Bar & Bistro',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/r_3lG3yIqNFEnjcgayeRow/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vintage-wine-bar-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 400,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.9495544433594,
#     'longitude': -75.1617584228516},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '129 S 13th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19107',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['129 S 13th St', 'Philadelphia, PA 19107']},
#    'phone': '+12159223095',
#    'display_phone': '(215) 922-3095',
#    'distance': 935.817753577725},
#   {'id': 'XYwx1tsEB3_G0tgS6l-0PQ',
#    'alias': 'amuse-philadelphia',
#    'name': 'Amuse',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/H_-jTYAN00_ZdDr-esD09w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/amuse-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 152,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.9546542, 'longitude': -75.1639365},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '1421 Arch St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19102',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1421 Arch St', 'Philadelphia, PA 19102']},
#    'phone': '+12154228222',
#    'display_phone': '(215) 422-8222',
#    'distance': 619.4689117798652},
#   {'id': '_Q3XmBesceFqn9Dk-w6tlA',
#    'alias': 'artisan-boulanger-patissier-philadelphia-2',
#    'name': 'Artisan Boulanger Patissier',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nLXZQ9l5OFGCUJR3tMHvJA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/artisan-boulanger-patissier-philadelphia-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 183,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.9264181, 'longitude': -75.1664513},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1218 Mifflin St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19148',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1218 Mifflin St', 'Philadelphia, PA 19148']},
#    'phone': '+12152714688',
#    'display_phone': '(215) 271-4688',
#    'distance': 3069.590119746793},
#   {'id': 'zaeNGZfmOiBzGVqGhRfX3w',
#    'alias': 'le-caveau-philadelphia',
#    'name': 'Le Caveau',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/yYuW84k6dEc4MFVfh_r7qA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-caveau-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 2,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.9417309202983,
#     'longitude': -75.1541846618056},
#    'transactions': ['delivery'],
#    'location': {'address1': '614 S 7th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19147',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['614 S 7th St', 'Philadelphia, PA 19147']},
#    'phone': '+12156253700',
#    'display_phone': '(215) 625-3700',
#    'distance': 1974.956699828193},
#   {'id': '0PTuPOOXkmoP0s5STUBY1w',
#    'alias': 'chez-ben-philadelphia',
#    'name': 'Chez Ben',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/mkjRLFQUfP6dWgLzZvWPqw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chez-ben-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 23,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.9490604639315,
#     'longitude': -75.1477326080203},
#    'transactions': ['delivery'],
#    'location': {'address1': '401 Chestnut St',
#     'address2': '',
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19106',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['401 Chestnut St', 'Philadelphia, PA 19106']},
#    'phone': '+12159314260',
#    'display_phone': '(215) 931-4260',
#    'distance': 2068.4269266820284},
#   {'id': 'Je10gqBQIqSvYNS8XGrYnw',
#    'alias': 'chez-colette-philadelphia',
#    'name': 'Chez Colette',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/SieXT-eyTeiX7suA-fokxA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chez-colette-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 29,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.9507208156525,
#     'longitude': -75.1689343926239},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '120 S 17th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19103',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['120 S 17th St', 'Philadelphia, PA 19103']},
#    'phone': '+12155698300',
#    'display_phone': '(215) 569-8300',
#    'distance': 391.51671886445627},
#   {'id': 'ONJBEPNFUv_uTglJOT8ctw',
#    'alias': 'liberté-lounge-philadelphia-2',
#    'name': 'Liberté Lounge',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wRK3ifllCmtzLvWZ3c2qbA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/libert%C3%A9-lounge-philadelphia-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 82,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 39.950802, 'longitude': -75.1690105},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '120 S 17th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19103',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['120 S 17th St', 'Philadelphia, PA 19103']},
#    'phone': '+12155698300',
#    'display_phone': '(215) 569-8300',
#    'distance': 380.46479720628736},
#   {'id': 'ppgoocYga1HPYL6lsIZvnw',
#    'alias': 'bistro-perrier-at-walnut-hill-college-philadelphia-4',
#    'name': 'Bistro Perrier at Walnut Hill College',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8-K4T56KkD3H_CqkrRkTRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bistro-perrier-at-walnut-hill-college-philadelphia-4?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 74,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.95512, 'longitude': -75.20747},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '4207 Walnut St',
#     'address2': '',
#     'address3': 'Walnut Hill College',
#     'city': 'Philadelphia',
#     'zip_code': '19104',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['4207 Walnut St',
#      'Walnut Hill College',
#      'Philadelphia, PA 19104']},
#    'phone': '+12672952302',
#    'display_phone': '(267) 295-2302',
#    'distance': 3095.1117270455834}],
#  'total': 24,
#  'region': {'center': {'longitude': -75.17120361328125,
#    'latitude': 39.95378209544653}}}

# %%
french_name = []
french_city = []
french_latitude = []
french_longitude = []
french_zipcode = []
french_ethnicity = []
french_price = []
french_rating = []

# %%
for i in philadelphia_french:
    for j in (philadelphia_french[i]['businesses']):
        french_name.append(philadelphia_french[i]["businesses"][j]["name"])
        french_city.append("Philadelphia")
        french_latitude.append(philadelphia_french[i]["businesses"][j]["coordinates"]["latitude"])
        french_longitude.append(philadelphia_french[i]["businesses"][j]["coordinates"]["longitude"])
        french_zipcode.append(philadelphia_french[i]["businesses"][j]["location"]["zip_code"])
        french_ethnicity.append((philadelphia_french[i]['Ethnicity']))
        try:
            french_price.append(philadelphia_french[i]["businesses"][j]["price"])
        except KeyError:
            french_price.append("N/A")
        french_rating.append(philadelphia_french[i]["businesses"][j]["rating"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-222-d78b5a7eb327> in <module>
#       1 for i in philadelphia_french:
# ----> 2     for j in (philadelphia_french[i]['businesses']):
#       3         french_name.append(philadelphia_french[i]["businesses"][j]["name"])
#       4         french_city.append("Philadelphia")
#       5         french_latitude.append(philadelphia_french[i]["businesses"][j]["coordinates"]["latitude"])
#
# TypeError: list indices must be integers or slices, not str

# %%
#greek
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'Philadelphia', 'categories':'greek' }
    
philadelphia_greek = requests.get(API_HOST,headers=headers, params=params).json()

philly_ethnic_totals.loc[2, 'City'] = 'Philadelphia'
philly_ethnic_totals.loc[2, 'Ethnicity'] = 'Greek'
philly_ethnic_totals.loc[2, 'Total Restaurants'] = (philadelphia_greek["total"])

philadelphia_greek
# Out:
# {'businesses': [{'id': '-OIUunijjcq_ZzyyQhPPFQ',
#    'alias': 'zorbas-taverna-philadelphia',
#    'name': "Zorba's Taverna",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/pe1aHSdpwHwJ3yBsOWBRuA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zorbas-taverna-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 476,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.96712, 'longitude': -75.1749},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2230 Fairmount Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19130',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['2230 Fairmount Ave', 'Philadelphia, PA 19130']},
#    'phone': '+12159785990',
#    'display_phone': '(215) 978-5990',
#    'distance': 1521.1833946237623},
#   {'id': 'y4VFp6qk_EFgNy9yKFlj3Q',
#    'alias': 'moustaki-authentic-gyros-philadelphia',
#    'name': 'Moustaki Authentic Gyros',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZWMPZZYY-FAfXZ0dfMod3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/moustaki-authentic-gyros-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 129,
#    'categories': [{'alias': 'greek', 'title': 'Greek'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.95755, 'longitude': -75.17403},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '161 N 21st St',
#     'address2': None,
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19103',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['161 N 21st St', 'Philadelphia, PA 19103']},
#    'phone': '+12159649151',
#    'display_phone': '(215) 964-9151',
#    'distance': 483.5840049469532},
#   {'id': 'AaTpjyw-EiODgi3tR4Xr-g',
#    'alias': 'estia-philadelphia',
#    'name': 'Estia',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/oY5WVK5fh1OOQZuuPwlFmg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/estia-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 717,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.9483920508164,
#     'longitude': -75.1653502257588},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '1405 Locust St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19102',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1405 Locust St', 'Philadelphia, PA 19102']},
#    'phone': '+12157357700',
#    'display_phone': '(215) 735-7700',
#    'distance': 779.8493084606342},
#   {'id': 'v72qGvd53IxhM2m8aatOpg',
#    'alias': 'kanella-grill-philadelphia',
#    'name': 'Kanella Grill',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gztbSsebmgt8umtiaz883w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kanella-grill-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 235,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mideastern', 'title': 'Middle Eastern'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.94631, 'longitude': -75.15798},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '1001 Spruce St',
#     'address2': '',
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19107',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1001 Spruce St', 'Philadelphia, PA 19107']},
#    'phone': '+12679282085',
#    'display_phone': '(267) 928-2085',
#    'distance': 1401.064835456016},
#   {'id': 'j58chGXdwNBjXYGCOHpxag',
#    'alias': 'yiro-yiro-philadelphia-2',
#    'name': 'Yiro Yiro',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/mD6T_C1w9b9PxEdvWuY1eg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yiro-yiro-philadelphia-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 65,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'greek', 'title': 'Greek'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.9617950000087,
#     'longitude': -75.1575049999638},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '125-29 S 40th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19104',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['125-29 S 40th St', 'Philadelphia, PA 19104']},
#    'phone': '+12677789476',
#    'display_phone': '(267) 778-9476',
#    'distance': 2642.5306547274163},
#   {'id': 'pqN11loWgNHqSWxESd4Uwg',
#    'alias': 'kostas-bar-restaurant-philadelphia',
#    'name': 'Kostas Bar Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/t8mCxo5BbE9rGDzez-fyaw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kostas-bar-restaurant-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 101,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'greek', 'title': 'Greek'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.9688263, 'longitude': -75.1351395},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '15 W Girard Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19123',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['15 W Girard Ave', 'Philadelphia, PA 19123']},
#    'phone': '+12676392417',
#    'display_phone': '(267) 639-2417',
#    'distance': 3522.804583097879},
#   {'id': 'fQbT2skNJPvNDIhLHmcYKA',
#    'alias': 'yeeroh-philadelphia',
#    'name': 'Yeeroh',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/j52c9JyAEm4Fk2uvXc6Mkw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yeeroh-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 145,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.9434878717641,
#     'longitude': -75.1661349087954},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1412 South St',
#     'address2': '',
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19146',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1412 South St', 'Philadelphia, PA 19146']},
#    'phone': '+12155458000',
#    'display_phone': '(215) 545-8000',
#    'distance': 1223.4979342929419},
#   {'id': 'ADe114o7Z4vb1O6HkM6YEA',
#    'alias': 'greek-lady-philadelphia',
#    'name': 'Greek Lady',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6E98nqrVKxehlEY_GBhZ7g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/greek-lady-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 449,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.9534811107114,
#     'longitude': -75.2029253183611},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '224 S 40th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19104',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['224 S 40th St', 'Philadelphia, PA 19104']},
#    'phone': '+12153822600',
#    'display_phone': '(215) 382-2600',
#    'distance': 2704.101053544662},
#   {'id': '17Y8circEnkMMXKfLo8Ztg',
#    'alias': 'bitars-philadelphia-6',
#    'name': "Bitar's",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/UnN1wBRrIBMflUVithsCVw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bitars-philadelphia-6?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 148,
#    'categories': [{'alias': 'mideastern', 'title': 'Middle Eastern'},
#     {'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'falafel', 'title': 'Falafel'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.93465, 'longitude': -75.16026},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '947 Federal St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19147',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['947 Federal St', 'Philadelphia, PA 19147']},
#    'phone': '+12157551121',
#    'display_phone': '(215) 755-1121',
#    'distance': 2322.370163037381},
#   {'id': 'KVFUBgmPEHGUaJNkpMGcLw',
#    'alias': 'opa-philadelphia',
#    'name': 'Opa',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pvVR2vsKelfxHPx0uNxiow/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/opa-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 447,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.9499818692831,
#     'longitude': -75.1624407578698},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '1311 Sansom St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19107',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1311 Sansom St', 'Philadelphia, PA 19107']},
#    'phone': '+12155450170',
#    'display_phone': '(215) 545-0170',
#    'distance': 858.1908825153077},
#   {'id': 'MKsCFQuzmgH2We9hwTQ8gw',
#    'alias': 'south-street-souvlaki-philadelphia',
#    'name': 'South Street Souvlaki',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pjk7zv6q9xAClmX-_QE3Hg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/south-street-souvlaki-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 214,
#    'categories': [{'alias': 'greek', 'title': 'Greek'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.9420319, 'longitude': -75.1511078},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '509 South St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19147',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['509 South St', 'Philadelphia, PA 19147']},
#    'phone': '+12159253026',
#    'display_phone': '(215) 925-3026',
#    'distance': 2165.2378127917777},
#   {'id': 'CuyQt_cUFS1i738GXTNciw',
#    'alias': 'effies-restaurant-philadelphia',
#    'name': "Effie's Restaurant",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5RC9Th66MCLfnVH4MmvxNg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/effies-restaurant-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 304,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.94517, 'longitude': -75.16061},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1127 Pine St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19107',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1127 Pine St', 'Philadelphia, PA 19107']},
#    'phone': '+12155928333',
#    'display_phone': '(215) 592-8333',
#    'distance': 1321.353128676097},
#   {'id': 'dgm6jrUZj-vAWa1OU5rbNQ',
#    'alias': 'yiro-yiro-philadelphia',
#    'name': 'Yiro Yiro',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Gfz21YO_lYYm0XbYl185-g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yiro-yiro-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 159,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'falafel', 'title': 'Falafel'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.0325946537825,
#     'longitude': -75.2143289330606},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '6024 Ridge Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19128',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['6024 Ridge Ave', 'Philadelphia, PA 19128']},
#    'phone': '+12673319476',
#    'display_phone': '(267) 331-9476',
#    'distance': 9502.44531070987},
#   {'id': 'PsyoQwBcxs98DP-2tBOv6A',
#    'alias': 'mad-greek-restaurant-and-pizza-philadelphia-2',
#    'name': 'Mad Greek Restaurant and Pizza',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/TlynIn4cCFqR79DoEymwTA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mad-greek-restaurant-and-pizza-philadelphia-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 56,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'greek', 'title': 'Greek'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.95854, 'longitude': -75.19297},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '3517 Lancaster Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19104',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['3517 Lancaster Ave', 'Philadelphia, PA 19104']},
#    'phone': '+12152222739',
#    'display_phone': '(215) 222-2739',
#    'distance': 1921.519673136954},
#   {'id': 'gKHxy8chDJCZb-Y12h229w',
#    'alias': 'paradise-diner-philadelphia',
#    'name': 'Paradise Diner',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dmjxpWu2ZltS1NDO9aCq5g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/paradise-diner-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 42,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.96871, 'longitude': -75.13649},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '104 W Girard Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19123',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['104 W Girard Ave', 'Philadelphia, PA 19123']},
#    'phone': '+12159250240',
#    'display_phone': '(215) 925-0240',
#    'distance': 3391.9935758005886},
#   {'id': 'gCcJTKC40CL0XtYYGfcXDw',
#    'alias': 'smileys-cafe-philadelphia',
#    'name': "Smiley's Cafe",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/8gCT9grSlbOI9QqBbYnVCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/smileys-cafe-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 402,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'greek', 'title': 'Greek'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.0248, 'longitude': -75.22145},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '4251 Main St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19127',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['4251 Main St', 'Philadelphia, PA 19127']},
#    'phone': '+12673232098',
#    'display_phone': '(267) 323-2098',
#    'distance': 8979.28738972411},
#   {'id': '6LYmMCltMzSMK-gMjqWTCw',
#    'alias': 'zestys-philadelphia',
#    'name': "Zesty's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Ye6lcQak9lCeWoa75MxrMg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zestys-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 156,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.02564, 'longitude': -75.22445},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '4382 Main St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19127',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['4382 Main St', 'Philadelphia, PA 19127']},
#    'phone': '+12154836226',
#    'display_phone': '(215) 483-6226',
#    'distance': 9200.227099004938},
#   {'id': 'CpFdqSw1R4BTz4SbMvD-PQ',
#    'alias': 'olympia-gyro-philadelphia-2',
#    'name': 'Olympia Gyro',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/olympia-gyro-philadelphia-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 1,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.9537588, 'longitude': -75.1588474},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '1136 Arch St',
#     'address2': '',
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19107',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1136 Arch St', 'Philadelphia, PA 19107']},
#    'phone': '+12156299775',
#    'display_phone': '(215) 629-9775',
#    'distance': 1045.0903452622838},
#   {'id': 'nEB2VbuOJ9CQFpddkDPaDQ',
#    'alias': 'st-georges-greek-festival-philadelphia',
#    'name': "St. George's Greek Festival",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/JfvY1yH1NMIIz9aBSFELQQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/st-georges-greek-festival-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 4,
#    'categories': [{'alias': 'festivals', 'title': 'Festivals'},
#     {'alias': 'greek', 'title': 'Greek'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 39.94618, 'longitude': -75.15465},
#    'transactions': [],
#    'location': {'address1': 'S 8th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19107',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['S 8th St', 'Philadelphia, PA 19107']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1640.6183454785382},
#   {'id': 'paxJoGgP8Pw79ODjPC1nUg',
#    'alias': 'angelos-pizza-house-philadelphia',
#    'name': "Angelo's Pizza House",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/--hIMD7zqVkoRFLum5jhmA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/angelos-pizza-house-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 10,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'greek', 'title': 'Greek'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.00374, 'longitude': -75.09401},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '3901 Frankford Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19124',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['3901 Frankford Ave', 'Philadelphia, PA 19124']},
#    'phone': '+12157439979',
#    'display_phone': '(215) 743-9979',
#    'distance': 8612.459892329587}],
#  'total': 21,
#  'region': {'center': {'longitude': -75.17120361328125,
#    'latitude': 39.95378209544653}}}

# %%
#indian
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'Philadelphia', 'categories':'indpak'}
    
philadelphia_indian1 = requests.get(API_HOST,headers=headers, params=params).json()

philly_ethnic_totals.loc[3, 'City'] = 'Philadelphia'
philly_ethnic_totals.loc[3, 'Ethnicity'] = 'Indian'
philly_ethnic_totals.loc[3, 'Total Restaurants'] = (philadelphia_indian1["total"])

# %%
#indian
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'Philadelphia', 'categories':'indpak', 'offset':50}
    
philadelphia_indian2 = requests.get(API_HOST,headers=headers, params=params).json()


philadelphia_indian2
# Out:
# {'businesses': [{'id': 'bi8cQT77t7hOlKbB7diCPg',
#    'alias': 'tiffin-mount-airy-philadelphia-2',
#    'name': 'Tiffin - Mount Airy',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/f-xOFCJd6-mXabOdX-U7pg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tiffin-mount-airy-philadelphia-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 174,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.05306, 'longitude': -75.19568},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '7105 Emlen St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19119',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['7105 Emlen St', 'Philadelphia, PA 19119']},
#    'phone': '+12152423656',
#    'display_phone': '(215) 242-3656',
#    'distance': 11231.258322028418},
#   {'id': 'WX1x4UaiDxl4o4LfpFG8TA',
#    'alias': 'samosa-deb-philadelphia-2',
#    'name': 'Samosa Deb',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/If4OZHL3tmTJGYc2gxlqlg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/samosa-deb-philadelphia-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 8,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'},
#     {'alias': 'foodtrucks', 'title': 'Food Trucks'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 39.9397277732718,
#     'longitude': -75.1577685373353},
#    'transactions': [],
#    'location': {'address1': '9TH And Catherine',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19147',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['9TH And Catherine', 'Philadelphia, PA 19147']},
#    'phone': '+16107454824',
#    'display_phone': '(610) 745-4824',
#    'distance': 1937.5088251954267},
#   {'id': 'q6xmmfmt8DzOhbIC0WVbvQ',
#    'alias': 'laxmi-indian-grille-manayunk-philadelphia-3',
#    'name': 'Laxmi Indian Grille - Manayunk',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/UpJa26XGyb7TwRlXDnaqzA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/laxmi-indian-grille-manayunk-philadelphia-3?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 201,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.02648, 'longitude': -75.22556},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '4425 Main St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19127',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['4425 Main St', 'Philadelphia, PA 19127']},
#    'phone': '+12155082120',
#    'display_phone': '(215) 508-2120',
#    'distance': 9314.179330389748},
#   {'id': 'CcHbzM4bTBCHXe1YiAwAYA',
#    'alias': 'azaad-foods-philadelphia',
#    'name': 'Azaad Foods',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/n2Ef-qGMMUg9qUUwKATlAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/azaad-foods-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 41,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.0402984619141,
#     'longitude': -75.0761642456055},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '6443 Castor Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19149',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['6443 Castor Ave', 'Philadelphia, PA 19149']},
#    'phone': '+12152885204',
#    'display_phone': '(215) 288-5204',
#    'distance': 12571.047361252648},
#   {'id': 'yy0n5-SHXZWgK8sy_0dHpA',
#    'alias': 'nanees-kitchen-philadelphia',
#    'name': "Nanee's Kitchen",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zpd8KIo-55j8qtYH7EZyIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nanees-kitchen-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 117,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'},
#     {'alias': 'pakistani', 'title': 'Pakistani'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 39.953162, 'longitude': -75.1591},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '51 N 12th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19107',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['51 N 12th St', 'Philadelphia, PA 19107']},
#    'phone': '+12156782789',
#    'display_phone': '(215) 678-2789',
#    'distance': 1033.9914711004226},
#   {'id': 'QLu7rGcJj1UNyrWvDmfc_w',
#    'alias': 'desi-halal-corner-upper-darby',
#    'name': 'Desi Halal Corner',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/d1a4Bjok5zGyPqHhbDeh-w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/desi-halal-corner-upper-darby?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 2,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.95612317, 'longitude': -75.25767867},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '211 S 69th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Upper Darby',
#     'zip_code': '19082',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['211 S 69th St', 'Upper Darby, PA 19082']},
#    'phone': '+14844662571',
#    'display_phone': '(484) 466-2571',
#    'distance': 7384.838649799052},
#   {'id': 'XO4izkFhhtX8OjIqu_dULg',
#    'alias': 'indiya-collingswood',
#    'name': 'Indiya',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/FhOMdMIXS9oVza6CBqTqwg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/indiya-collingswood?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 211,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'buffets', 'title': 'Buffets'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.9166829, 'longitude': -75.0709433},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '608 Haddon Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Collingswood',
#     'zip_code': '08108',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['608 Haddon Ave', 'Collingswood, NJ 08108']},
#    'phone': '+18568580020',
#    'display_phone': '(856) 858-0020',
#    'distance': 9491.614357303095},
#   {'id': 'ur84JezPd2IN5PN4J-fEVw',
#    'alias': 'indian-food-truck-philadelphia',
#    'name': 'Indian Food Truck',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rWkDo-XAR2dNb1hoVQryRw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/indian-food-truck-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 14,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'},
#     {'alias': 'foodstands', 'title': 'Food Stands'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 39.9542337656021,
#     'longitude': -75.1978024095297},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '3746 Sansom St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19104',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['3746 Sansom St', 'Philadelphia, PA 19104']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2251.006205737153},
#   {'id': '1kLcMmcDDoGJpYG5VdWMrA',
#    'alias': 'dana-mandi-2-upper-darby-2',
#    'name': 'Dana Mandi 2',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FdQ8VhbkErULDXTGiSweXg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dana-mandi-2-upper-darby-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 4,
#    'categories': [{'alias': 'intlgrocery', 'title': 'International Grocery'},
#     {'alias': 'indpak', 'title': 'Indian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.95406, 'longitude': -75.25841},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '325 S 69th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Upper Darby',
#     'zip_code': '19082',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['325 S 69th St', 'Upper Darby, PA 19082']},
#    'phone': '+16103523236',
#    'display_phone': '(610) 352-3236',
#    'distance': 7429.195661568107},
#   {'id': '6rYratsrQNh6_cPWjlMopw',
#    'alias': 'tiffin-wynnewood-wynnewood-2',
#    'name': 'Tiffin Wynnewood',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/30klokmr-rSEIHbV8zRBeA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tiffin-wynnewood-wynnewood-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 123,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.0017065835458,
#     'longitude': -75.2742501819091},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '50 E Wynnewood Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Wynnewood',
#     'zip_code': '19096',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['50 E Wynnewood Rd', 'Wynnewood, PA 19096']},
#    'phone': '+16106423344',
#    'display_phone': '(610) 642-3344',
#    'distance': 10270.97191503896},
#   {'id': 'uKRvE6K2Syi-iydl7FN9WA',
#    'alias': 'desi-food-junction-merchantville',
#    'name': 'Desi Food Junction',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/iVUcC3mxoMHYMSMmn5_SoQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/desi-food-junction-merchantville?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 3,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 39.95352, 'longitude': -75.04435},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '134 E Park Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Merchantville',
#     'zip_code': '08109',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['134 E Park Ave', 'Merchantville, NJ 08109']},
#    'phone': '+14437602066',
#    'display_phone': '(443) 760-2066',
#    'distance': 10803.5257780737},
#   {'id': 'jDimrBbKQe_1Uxbx2fhb7w',
#    'alias': 'new-delhi-dhabba-upper-darby',
#    'name': 'New Delhi Dhabba',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/new-delhi-dhabba-upper-darby?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 2,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#    'rating': 1.5,
#    'coordinates': {'latitude': 39.9615037, 'longitude': -75.2587603},
#    'transactions': ['delivery'],
#    'location': {'address1': '3 S 69th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Upper Darby',
#     'zip_code': '19142',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['3 S 69th St', 'Upper Darby, PA 19142']},
#    'phone': '+16103520800',
#    'display_phone': '(610) 352-0800',
#    'distance': 7509.0311521980475}],
#  'total': 62,
#  'region': {'center': {'longitude': -75.17120361328125,
#    'latitude': 39.95378209544653}}}

# %%
#italian
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'Philadelphia', 'categories':'italian' }
    
philadelphia_italian = requests.get(API_HOST,headers=headers, params=params).json()

philly_ethnic_totals.loc[4, 'City'] = 'Philadelphia'
philly_ethnic_totals.loc[4, 'Ethnicity'] = 'Italian'
philly_ethnic_totals.loc[4, 'Total Restaurants'] = (philadelphia_italian["total"])

philadelphia_italian
# Out:
# {'businesses': [{'id': '6ajnOk0GcY9xbb5Ocaw8Gw',
#    'alias': 'barbuzzo-philadelphia',
#    'name': 'Barbuzzo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/88mJSIDPi3JUsCK2FsVJqg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barbuzzo-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 2754,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.94999, 'longitude': -75.16216},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '110 S 13th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19107',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['110 S 13th St', 'Philadelphia, PA 19107']},
#    'phone': '+12155469300',
#    'display_phone': '(215) 546-9300',
#    'distance': 877.931789849032},
#   {'id': 'lKU_kljhbEQKIPaM1Zbqiw',
#    'alias': 'little-nonnas-philadelphia',
#    'name': "Little Nonna's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uFvTQzlZF6nd23Y8z72hWQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/little-nonnas-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 1059,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.9477864380196,
#     'longitude': -75.1618928090843},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1234 Locust St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19107',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1234 Locust St', 'Philadelphia, PA 19107']},
#    'phone': '+12155462100',
#    'display_phone': '(215) 546-2100',
#    'distance': 1036.521920338534},
#   {'id': '-cEFKAznWmI0cledNOIQ7w',
#    'alias': 'gran-caffe-l-aquila-philadelphia',
#    'name': "Gran Caffe L'Aquila",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/m1s25bq9yvsOcFqP4n9cpg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gran-caffe-l-aquila-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 986,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'gelato', 'title': 'Gelato'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.95127, 'longitude': -75.1695},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1716 Chestnut St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19103',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1716 Chestnut St', 'Philadelphia, PA 19103']},
#    'phone': '+12155685600',
#    'display_phone': '(215) 568-5600',
#    'distance': 313.23491060398817},
#   {'id': 'eLbKuFpCtHEjCkoWkDDk7g',
#    'alias': 'trattoria-carina-philadelphia-2',
#    'name': 'Trattoria Carina',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Q3N-1ybrVfhx9wz-SbJm_Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/trattoria-carina-philadelphia-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 166,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.94878, 'longitude': -75.17803},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '2201 Spruce St',
#     'address2': '',
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19103',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['2201 Spruce St', 'Philadelphia, PA 19103']},
#    'phone': '+12157325818',
#    'display_phone': '(215) 732-5818',
#    'distance': 798.3251533170863},
#   {'id': 'oVwEPg-BADIFl2SlGma6jg',
#    'alias': 'burrata-philadelphia',
#    'name': 'Burrata',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3nyuvfFb7qb2PMTLzlKZPg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/burrata-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 127,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.9339252433408,
#     'longitude': -75.1652430742979},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '1247 S 13th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19147',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1247 S 13th St', 'Philadelphia, PA 19147']},
#    'phone': '+12154652200',
#    'display_phone': '(215) 465-2200',
#    'distance': 2265.694889728396},
#   {'id': 'xdc0TbKkHMZN3N82oeq2XA',
#    'alias': 'via-locusta-philadelphia',
#    'name': 'Via Locusta',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NTsYCL-dEKDKGAmQ2k7d0Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/via-locusta-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 83,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.9490553, 'longitude': -75.1704201},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '1723 Locust St',
#     'address2': '',
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19103',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1723 Locust St', 'Philadelphia, PA 19103']},
#    'phone': '+12156420020',
#    'display_phone': '(215) 642-0020',
#    'distance': 531.1826745046026},
#   {'id': '5yeL75bFLZlGB6dUfwCIQw',
#    'alias': 'cotoletta-fitler-square-philadelphia',
#    'name': 'Cotoletta Fitler Square',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/v6VxB-qWbjDVhCXYiCTG4Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cotoletta-fitler-square-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 57,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.94749, 'longitude': -75.17915},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '2227 Pine St',
#     'address2': None,
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19103',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['2227 Pine St', 'Philadelphia, PA 19103']},
#    'phone': '+12675199697',
#    'display_phone': '(267) 519-9697',
#    'distance': 977.2038987512966},
#   {'id': 'dQZlvOEVNke30MY5iTiy1g',
#    'alias': 'davios-philadelphia-2',
#    'name': 'Davios',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/HerNkPllTnrSfUX-SqJvog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/davios-philadelphia-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 608,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.9508994, 'longitude': -75.1687058},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '111 S 17th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19103',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['111 S 17th St', 'Philadelphia, PA 19103']},
#    'phone': '+12155634810',
#    'display_phone': '(215) 563-4810',
#    'distance': 373.80514704657116},
#   {'id': '-Ti5pwj6mA99khsxxur8aQ',
#    'alias': 'ambrosia-ristorante-byob-philadelphia',
#    'name': 'Ambrosia Ristorante BYOB',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/5MvB6dQ0eI0k16A-nB2YaQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ambrosia-ristorante-byob-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 88,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.94997, 'longitude': -75.1796},
#    'transactions': ['delivery'],
#    'location': {'address1': '231 S 24th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19103',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['231 S 24th St', 'Philadelphia, PA 19103']},
#    'phone': '+12157032010',
#    'display_phone': '(215) 703-2010',
#    'distance': 835.1688975605975},
#   {'id': 'u3aN2A8Lo9odMCYjaphjLA',
#    'alias': 'a-mano-philadelphia',
#    'name': 'A Mano',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RamyAA4nU2a6liLbcaftlw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/a-mano-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 198,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.9671153197102,
#     'longitude': -75.1753409206867},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '2244 Fairmount Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19130',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['2244 Fairmount Ave', 'Philadelphia, PA 19130']},
#    'phone': '+12152361114',
#    'display_phone': '(215) 236-1114',
#    'distance': 1523.9423475282654},
#   {'id': '-nIXhxPvxST6bTuj9jo1UQ',
#    'alias': 'damò-pasta-lab-philadelphia',
#    'name': 'DaMò Pasta Lab',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/mzGMlz6wQzfBXkO1UXffsg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dam%C3%B2-pasta-lab-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 142,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pastashops', 'title': 'Pasta Shops'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.95022, 'longitude': -75.16006},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '105 S 12th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19107',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['105 S 12th St', 'Philadelphia, PA 19107']},
#    'phone': '+12676871410',
#    'display_phone': '(267) 687-1410',
#    'distance': 1027.7154945344666},
#   {'id': 'hUmHwBQtGg0iH-PZakQJDw',
#    'alias': 'wm-mulherins-sons-philadelphia',
#    'name': "Wm Mulherin's Sons",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7dFVMibLMMG6_oOQH5XpSA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wm-mulherins-sons-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 558,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.9717102050781,
#     'longitude': -75.1350631713867},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '1355 N Front St',
#     'address2': None,
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19122',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1355 N Front St', 'Philadelphia, PA 19122']},
#    'phone': '+12152911355',
#    'display_phone': '(215) 291-1355',
#    'distance': 3668.972471094318},
#   {'id': 'nmeGoVi_U-bbnojJsi52Aw',
#    'alias': 'the-angelo-pizza-philadelphia',
#    'name': 'The Angelo Pizza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/GojR4Std-jPkPxUTDkKkwA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-angelo-pizza-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 35,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.950276, 'longitude': -75.144696},
#    'transactions': [],
#    'location': {'address1': '229 Market St',
#     'address2': None,
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19106',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['229 Market St', 'Philadelphia, PA 19106']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2292.4181140527903},
#   {'id': 'u7_3L1NBWgxhBM_B-cmmnA',
#    'alias': 'pizzeria-vetri-philadelphia-5',
#    'name': 'Pizzeria Vetri',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/tou0OkHDr2aAWp29vlq80Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pizzeria-vetri-philadelphia-5?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 615,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.960888, 'longitude': -75.171213},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '1939 Callowhill St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19130',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1939 Callowhill St', 'Philadelphia, PA 19130']},
#    'phone': '+12156002629',
#    'display_phone': '(215) 600-2629',
#    'distance': 790.14006427496},
#   {'id': '05ev984NYfimRN0UiFrxaA',
#    'alias': 'osteria-philadelphia-2',
#    'name': 'Osteria',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/uWqLyxl18HI-4KhAjfaF4w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/osteria-philadelphia-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 821,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.965015, 'longitude': -75.161076},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '640 N Broad St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19130',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['640 N Broad St', 'Philadelphia, PA 19130']},
#    'phone': '+12157630920',
#    'display_phone': '(215) 763-0920',
#    'distance': 1518.2851742594885},
#   {'id': 'wUnLSg_GKfEIQ5CQQ770_g',
#    'alias': 'vetri-cucina-philadelphia',
#    'name': 'Vetri Cucina',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/69kBHoWw-fyiJrkF25XYBQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vetri-cucina-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 467,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.94659, 'longitude': -75.16319},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '1312 Spruce St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19107',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1312 Spruce St', 'Philadelphia, PA 19107']},
#    'phone': '+12157323478',
#    'display_phone': '(215) 732-3478',
#    'distance': 1047.3681729688217},
#   {'id': 'Z9QsWMsrvOyvF77k5YYuzg',
#    'alias': 'benny-casanovas-philadelphia',
#    'name': "Benny Casanova's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZYq88rXxwa2jSMhvqIU3CA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/benny-casanovas-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 10,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.9661484, 'longitude': -75.1910025},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '3300 Fairmount Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19104',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['3300 Fairmount Ave', 'Philadelphia, PA 19104']},
#    'phone': '+12156678559',
#    'display_phone': '(215) 667-8559',
#    'distance': 2181.31521624195},
#   {'id': 'sVZb87xjhbCWHQ2UXOGLrA',
#    'alias': 'giorgio-on-pine-philadelphia',
#    'name': 'Giorgio On Pine',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/EwboUhG7DpIma12RtidNVw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/giorgio-on-pine-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 896,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.945339381185, 'longitude': -75.164454458833},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1328 Pine St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19107',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1328 Pine St', 'Philadelphia, PA 19107']},
#    'phone': '+12155456265',
#    'display_phone': '(215) 545-6265',
#    'distance': 1101.0497017058951},
#   {'id': 'dYinIkKBspHV5hSaukklFg',
#    'alias': 'l-angolo-ristorante-philadelphia-3',
#    'name': "L'Angolo Ristorante",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_-xeA0QZVW6p3SGTGu_6bw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-angolo-ristorante-philadelphia-3?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 358,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.9196243286133,
#     'longitude': -75.1713714599609},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1415 W Porter St',
#     'address2': None,
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19145',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1415 W Porter St', 'Philadelphia, PA 19145']},
#    'phone': '+12153894252',
#    'display_phone': '(215) 389-4252',
#    'distance': 3797.786431732342},
#   {'id': 'qnprJxrjwuEivitA8V2aEQ',
#    'alias': 'fiorella-philadelphia-2',
#    'name': 'Fiorella',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gtwow1MTQaZ5QKmHNLsxFw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fiorella-philadelphia-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 59,
#    'categories': [{'alias': 'pastashops', 'title': 'Pasta Shops'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.9388677767588, 'longitude': -75.156939},
#    'transactions': [],
#    'location': {'address1': '817 Christian St',
#     'address2': '',
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19147',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['817 Christian St', 'Philadelphia, PA 19147']},
#    'phone': '+12153059222',
#    'display_phone': '(215) 305-9222',
#    'distance': 2056.4458574328987}],
#  'total': 284,
#  'region': {'center': {'longitude': -75.17120361328125,
#    'latitude': 39.95378209544653}}}

# %%
#italian
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'Philadelphia', 'categories':'italian', 'offset':50 }
    
philadelphia_italian2 = requests.get(API_HOST,headers=headers, params=params).json()

philadelphia_italian2
# Out:
# {'businesses': [{'id': 'arKiXax3ScSM_z3O-0CIyw',
#    'alias': 'spasso-italian-grill-philadelphia-2',
#    'name': 'Spasso Italian Grill',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GA-KWYTS3SxCXEa1ikCEvQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/spasso-italian-grill-philadelphia-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 506,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.94868, 'longitude': -75.1428},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '34 S Front St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19106',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['34 S Front St', 'Philadelphia, PA 19106']},
#    'phone': '+12155927661',
#    'display_phone': '(215) 592-7661',
#    'distance': 2495.454777976287},
#   {'id': 'gO_W7JLMw2om3l1NUUlvjA',
#    'alias': 'bar-amis-philadelphia',
#    'name': 'Bar Amis',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/a9jKABr_vR592GyF4Hy98g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bar-amis-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 66,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.8965991, 'longitude': -75.1755436},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '4503 S Broad St',
#     'address2': '',
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19112',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['4503 S Broad St', 'Philadelphia, PA 19112']},
#    'phone': '+12152823184',
#    'display_phone': '(215) 282-3184',
#    'distance': 6365.517133418267},
#   {'id': 'y8gjlpJA89qDRCLC0JQaew',
#    'alias': 'giuseppe-and-sons-philadelphia-2',
#    'name': 'Giuseppe & Sons',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ZrcChjZY0iTFXEdihBB-yQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/giuseppe-and-sons-philadelphia-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 248,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.9504952, 'longitude': -75.1662081},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '1523 Sansom St',
#     'address2': '',
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19102',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1523 Sansom St', 'Philadelphia, PA 19102']},
#    'phone': '+12153999199',
#    'display_phone': '(215) 399-9199',
#    'distance': 511.86322036305614},
#   {'id': 'OqyaD0hEytrcfC_F-ugqMw',
#    'alias': 'noir-restaurant-and-bar-philadelphia',
#    'name': 'Noir Restaurant & Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/w8G55ooS626Zrse-tnBvdw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/noir-restaurant-and-bar-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 135,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.9263, 'longitude': -75.16741},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1909 E Passyunk Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19148',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1909 E Passyunk Ave', 'Philadelphia, PA 19148']},
#    'phone': '+12673191678',
#    'display_phone': '(267) 319-1678',
#    'distance': 3071.0036955826713},
#   {'id': '0-7N3z_cb3Z1xMGDrbez6w',
#    'alias': 'le-virtu-philadelphia',
#    'name': 'Le Virtu',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fKARobhkXeLVI9_lNZIFEw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-virtu-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 370,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.926032, 'longitude': -75.1678},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '1927 E Passyunk Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19148',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1927 E Passyunk Ave', 'Philadelphia, PA 19148']},
#    'phone': '+12152715626',
#    'display_phone': '(215) 271-5626',
#    'distance': 3099.2803800024303},
#   {'id': '4qG7aFq9-45830OfYt7gCA',
#    'alias': 'radicchio-cafe-philadelphia',
#    'name': 'Radicchio Cafe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/01beeSsXR7iGXHvAfqRhCg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/radicchio-cafe-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 305,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.9566441361025,
#     'longitude': -75.1462974538848},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '402 Wood St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19106',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['402 Wood St', 'Philadelphia, PA 19106']},
#    'phone': '+12156276850',
#    'display_phone': '(215) 627-6850',
#    'distance': 2149.078110447096},
#   {'id': 'rA1fEHzn_DTJ59Ca7ccUtQ',
#    'alias': 'modena-italian-kitchen-philadelphia-2',
#    'name': 'Modena Italian Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ceCX8SEAUWbzzovjUhNE5A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/modena-italian-kitchen-philadelphia-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 1,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'pastashops', 'title': 'Pasta Shops'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.966148393347815,
#     'longitude': -75.19100210205957},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '3300 Fairmount Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19104',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['3300 Fairmount Ave', 'Philadelphia, PA 19104']},
#    'phone': '+18482706962',
#    'display_phone': '(848) 270-6962',
#    'distance': 2176.7456080003235},
#   {'id': 'oZzN706lKoL4faaTK739xA',
#    'alias': 'restaurant-ambra-philadelphia',
#    'name': 'Restaurant Ambra',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/riF-9uD5g_ho_oiGtettJQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/restaurant-ambra-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 61,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.9402603, 'longitude': -75.1492843},
#    'transactions': ['delivery'],
#    'price': '$$$$',
#    'location': {'address1': '705 S 4th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19147',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['705 S 4th St', 'Philadelphia, PA 19147']},
#    'phone': '+12678589232',
#    'display_phone': '(267) 858-9232',
#    'distance': 2392.9172628839315},
#   {'id': 'l2TdZEPHrboWrMUnoFB1RQ',
#    'alias': 'mangia-macaroni-philadelphia',
#    'name': 'Mangia Macaroni',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0M1F-Uq7_0eh4DFZzWqmjQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mangia-macaroni-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 59,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pastashops', 'title': 'Pasta Shops'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.9630572, 'longitude': -75.1643311},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1543 Spring Garden St',
#     'address2': None,
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19130',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1543 Spring Garden St', 'Philadelphia, PA 19130']},
#    'phone': '+12155631690',
#    'display_phone': '(215) 563-1690',
#    'distance': 1186.0783398226133},
#   {'id': 'erz6oUEJdx787WyOlxMARw',
#    'alias': 'dante-and-luigis-philadelphia',
#    'name': "Dante & Luigi's",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/lsQDeSullaq8cYhIoWUFIw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dante-and-luigis-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 382,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.9400687844998,
#     'longitude': -75.159422962926},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '762 S 10th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19147',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['762 S 10th St', 'Philadelphia, PA 19147']},
#    'phone': '+12159229501',
#    'display_phone': '(215) 922-9501',
#    'distance': 1825.841398784789},
#   {'id': 'Vnagnur1os0ZduOpvDH27A',
#    'alias': 'villa-di-roma-philadelphia',
#    'name': 'Villa Di Roma',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/cL3GeIfXyN0toF-QUABH3w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/villa-di-roma-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 402,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.9379266053438,
#     'longitude': -75.1581204682589},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '936 S 9th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19147',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['936 S 9th St', 'Philadelphia, PA 19147']},
#    'phone': '+12155921295',
#    'display_phone': '(215) 592-1295',
#    'distance': 2078.5486977950327},
#   {'id': 'c0Ay-fVQFMgAaXVR3hhRGw',
#    'alias': 'alice-pizza-philadelphia-6',
#    'name': 'Alice Pizza',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/n2nw8hMQrZgcueHFOGe6Ig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/alice-pizza-philadelphia-6?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 5,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'gelato', 'title': 'Gelato'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.95181, 'longitude': -75.161165},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '1234 Market St',
#     'address2': None,
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19107',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1234 Market St', 'Philadelphia, PA 19107']},
#    'phone': '+12155452020',
#    'display_phone': '(215) 545-2020',
#    'distance': 885.806623426708},
#   {'id': 'vF_QwGltBpVesMMGclzB9Q',
#    'alias': 'pizzeria-stella-philadelphia',
#    'name': 'Pizzeria Stella',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hSw0rJZpHXknkmYrY4AhpA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pizzeria-stella-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 577,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.9424247094494,
#     'longitude': -75.1456823945045},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '420 S 2nd St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19147',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['420 S 2nd St', 'Philadelphia, PA 19147']},
#    'phone': '+12153208000',
#    'display_phone': '(215) 320-8000',
#    'distance': 2515.532129012572},
#   {'id': '0bvtIbpsqBJZpRKSPwIfNw',
#    'alias': 'panorama-philadelphia-2',
#    'name': 'Panorama',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/V1cmV3CgQumsBcmUZ_3tDg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/panorama-philadelphia-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 293,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.950218, 'longitude': -75.142308},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '14 N Front St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19106',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['14 N Front St', 'Philadelphia, PA 19106']},
#    'phone': '+12159227800',
#    'display_phone': '(215) 922-7800',
#    'distance': 2496.9785414970224},
#   {'id': 'ndVqbK8tlQSZM63rajPkBQ',
#    'alias': 'palizzi-filippo-social-club-philadelphia',
#    'name': 'Palizzi Filippo Social Club',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/hyy7Y2POfB24a9GCiLAH5A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/palizzi-filippo-social-club-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 10,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'social_clubs', 'title': 'Social Clubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.93215, 'longitude': -75.16442},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '1408 S 12th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19147',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1408 S 12th St', 'Philadelphia, PA 19147']},
#    'phone': '+12152710707',
#    'display_phone': '(215) 271-0707',
#    'distance': 2473.3016302124092},
#   {'id': 'BWITd9JUXP3gSi1z3Y-z8g',
#    'alias': 'in-riva-philadelphia',
#    'name': 'In Riva',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7ttNBBHs7KNoxF8dJk0wGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/in-riva-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 693,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.0079689, 'longitude': -75.1923599},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '4116 Ridge Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19129',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['4116 Ridge Ave', 'Philadelphia, PA 19129']},
#    'phone': '+12154384848',
#    'display_phone': '(215) 438-4848',
#    'distance': 6281.389653369319},
#   {'id': 'qjIN4UbE96Cq6JKwLIQ9VQ',
#    'alias': 'saloon-restaurant-philadelphia',
#    'name': 'Saloon Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/GXjerRfm_EnxTWDelyv5ug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/saloon-restaurant-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 167,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.93989, 'longitude': -75.1546},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '750 S 7th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19147',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['750 S 7th St', 'Philadelphia, PA 19147']},
#    'phone': '+12156271811',
#    'display_phone': '(215) 627-1811',
#    'distance': 2099.3101020244103},
#   {'id': 'L4kfcADLCU4T33i7Z0CkuA',
#    'alias': 'bistro-romano-philadelphia',
#    'name': 'Bistro Romano',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/itt8rlnREDAqbxcwGXPxbw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bistro-romano-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 506,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.9419372504695, 'longitude': -75.14468348843},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '120 Lombard St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19147',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['120 Lombard St', 'Philadelphia, PA 19147']},
#    'phone': '+12159258880',
#    'display_phone': '(215) 925-8880',
#    'distance': 2616.397237468588},
#   {'id': 'bmJgvpuf2GBXd62ELK0Q2w',
#    'alias': 'luigis-pizza-fresca-philadelphia',
#    'name': "Luigi's Pizza Fresca",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/x2OfXZ727sC8isMs9-aO_A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/luigis-pizza-fresca-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 241,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.96759, 'longitude': -75.17709},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '2401 Fairmount Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19130',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['2401 Fairmount Ave', 'Philadelphia, PA 19130']},
#    'phone': '+12157698888',
#    'display_phone': '(215) 769-8888',
#    'distance': 1613.5262943386779},
#   {'id': 'AAvoBxeUwDnD5ThE9Cz6Fg',
#    'alias': 'l-anima-philadelphia-2',
#    'name': "L'anima",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ARtqiIs57e1gElOYV91eTg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-anima-philadelphia-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 116,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.9394700802366,
#     'longitude': -75.1711999252439},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '1001 S 17th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19146',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1001 S 17th St', 'Philadelphia, PA 19146']},
#    'phone': '+12155952500',
#    'display_phone': '(215) 595-2500',
#    'distance': 1591.4217474096597}],
#  'total': 284,
#  'region': {'center': {'longitude': -75.17120361328125,
#    'latitude': 39.95378209544653}}}

# %%
#italian
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'Philadelphia', 'categories':'italian', 'offset':100 }
    
philadelphia_italian3 = requests.get(API_HOST,headers=headers, params=params).json()

philadelphia_italian3
# Out:
# {'businesses': [{'id': 'DKRssfE83bAnqHvwXK5DqA',
#    'alias': 'randazzos-pizzeria-philadelphia',
#    'name': "Randazzo's Pizzeria",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/rfsPZDTd3qA2aVyRnqBaCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/randazzos-pizzeria-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 138,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.9444927907103,
#     'longitude': -75.1726122757187},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '1826 S St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19146',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1826 S St', 'Philadelphia, PA 19146']},
#    'phone': '+12155461566',
#    'display_phone': '(215) 546-1566',
#    'distance': 1039.8787331729657},
#   {'id': '18790ccUVHejWqCmkoSJjA',
#    'alias': 'casta-diva-philadelphia',
#    'name': 'Casta Diva',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/xjPE66a4-OXMo7Cl6sweXg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/casta-diva-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 145,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.94968, 'longitude': -75.17375},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '227 S 20th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19103',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['227 S 20th St', 'Philadelphia, PA 19103']},
#    'phone': '+12154969677',
#    'display_phone': '(215) 496-9677',
#    'distance': 508.6869615801459},
#   {'id': '8JcdN89xv4AqAVRSDLLUHw',
#    'alias': 'd-angelos-ristorante-italiano-philadelphia',
#    'name': "D'angelo's Ristorante Italiano",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fvf4r5Tfz0OKQp2pBuLkpA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/d-angelos-ristorante-italiano-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 158,
#    'categories': [{'alias': 'danceclubs', 'title': 'Dance Clubs'},
#     {'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.94871, 'longitude': -75.17442},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '256 S 20th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19103',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['256 S 20th St', 'Philadelphia, PA 19103']},
#    'phone': '+12155463935',
#    'display_phone': '(215) 546-3935',
#    'distance': 625.6128435407933},
#   {'id': '6085NRg7QH3vXpc50F4UHQ',
#    'alias': 'chiquitas-pizzeria-and-mexican-grill-philadelphia',
#    'name': "Chiquita's Pizzeria & Mexican Grill",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/PKDc3m857xiH7FNpmvghYw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chiquitas-pizzeria-and-mexican-grill-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 36,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.92288, 'longitude': -75.1596},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '746 Snyder Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19148',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['746 Snyder Ave', 'Philadelphia, PA 19148']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3572.3927158057654},
#   {'id': 'EI2_OgANt1Mb_83cNnpPwg',
#    'alias': 'marras-philadelphia-2',
#    'name': "Marra's",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/y88VM7SV6jUvh_Q1nUuqaw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/marras-philadelphia-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 281,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 39.92798, 'longitude': -75.16596},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1734 E Passyunk Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19148',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1734 E Passyunk Ave', 'Philadelphia, PA 19148']},
#    'phone': '+12154639249',
#    'display_phone': '(215) 463-9249',
#    'distance': 2903.977649234351},
#   {'id': '68YMbUXLeDo28HmBbFJ1Wg',
#    'alias': 'pescatore-bala-cynwyd',
#    'name': 'Pescatore',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/JgHosawpGwvRbYS7QpIeQg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pescatore-bala-cynwyd?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 155,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.0047799, 'longitude': -75.2324},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '134 Bala Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Bala Cynwyd',
#     'zip_code': '19004',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['134 Bala Ave', 'Bala Cynwyd, PA 19004']},
#    'phone': '+16106609400',
#    'display_phone': '(610) 660-9400',
#    'distance': 7703.814559425265},
#   {'id': '3lBooCffgkW7tVSG5kILBA',
#    'alias': 'porcini-philadelphia',
#    'name': 'Porcini',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/nbhX2UvR00NT5o510-rC2A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/porcini-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 300,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.951348, 'longitude': -75.1751139},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2048 Sansom St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19103',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['2048 Sansom St', 'Philadelphia, PA 19103']},
#    'phone': '+12157511175',
#    'display_phone': '(215) 751-1175',
#    'distance': 429.36209167200354},
#   {'id': 'Zjg5nixJ-sTr9B6tsDzClw',
#    'alias': 'mr-martinos-trattoria-philadelphia-2',
#    'name': "Mr Martino's Trattoria",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/KCmgLHyNN2Olte4sRevdEA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mr-martinos-trattoria-philadelphia-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 148,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.929019, 'longitude': -75.164705},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1646 E Passyunk Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19148',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1646 E Passyunk Ave', 'Philadelphia, PA 19148']},
#    'phone': '+12157550663',
#    'display_phone': '(215) 755-0663',
#    'distance': 2808.7115398955525},
#   {'id': 'I1H5s9cVCGh1nH-4bhsSDA',
#    'alias': 'santuccis-original-square-pizza-philadelphia-2',
#    'name': "Santucci's Original Square Pizza",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DKxERXRoqQKlPNVgKlNlRw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/santuccis-original-square-pizza-philadelphia-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 454,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.9390394, 'longitude': -75.159227},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '901 S 10th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19147',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['901 S 10th St', 'Philadelphia, PA 19147']},
#    'phone': '+12158255304',
#    'display_phone': '(215) 825-5304',
#    'distance': 1931.2485014627969},
#   {'id': 'P9HxiR4Zd2Nf5aQw-88oZA',
#    'alias': 'ristorante-mamma-marias-philadelphia',
#    'name': "Ristorante Mamma Maria's",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/s1P-vpLRFF_0ST97F-p_0g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ristorante-mamma-marias-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 99,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.92909, 'longitude': -75.16406},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1637 E Passyunk Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19148',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1637 E Passyunk Ave', 'Philadelphia, PA 19148']},
#    'phone': '+12154636884',
#    'display_phone': '(215) 463-6884',
#    'distance': 2811.596799067792},
#   {'id': 'u5_y_iOUMjbvqSwWXIx-5A',
#    'alias': 'la-famiglia-ristorante-philadelphia',
#    'name': 'La Famiglia Ristorante',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/uGP6zngFoMo6cpVGy_oF2A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-famiglia-ristorante-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 127,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.94934, 'longitude': -75.1425},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '8 S Front St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19106',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['8 S Front St', 'Philadelphia, PA 19106']},
#    'phone': '+12159222803',
#    'display_phone': '(215) 922-2803',
#    'distance': 2501.525016882382},
#   {'id': 'qg6TJc2izTA52XFHAxdVjQ',
#    'alias': 'di-bruno-bros-philadelphia-6',
#    'name': 'Di Bruno Bros.',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/o6V2st6fze-qrwnlQki1hg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/di-bruno-bros-philadelphia-6?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 59,
#    'categories': [{'alias': 'cheese', 'title': 'Cheese Shops'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.954251, 'longitude': -75.168476},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1701 Jfk Blvd',
#     'address2': '',
#     'address3': 'Comcast Ctr',
#     'city': 'Philadelphia',
#     'zip_code': '19103',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1701 Jfk Blvd',
#      'Comcast Ctr',
#      'Philadelphia, PA 19103']},
#    'phone': '+12155315666',
#    'display_phone': '(215) 531-5666',
#    'distance': 238.2696895549727},
#   {'id': 'XX3Fiyd1Bw4-aBoEKuXMZw',
#    'alias': 'il-bar-philadelphia',
#    'name': 'Il Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/sw_thQsfz757fLsnEMjLgg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/il-bar-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 3,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.95024, 'longitude': -75.14231},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '14 N Front St',
#     'address2': '',
#     'address3': "Penn's View Hotel",
#     'city': 'Philadelphia',
#     'zip_code': '19106',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['14 N Front St',
#      "Penn's View Hotel",
#      'Philadelphia, PA 19106']},
#    'phone': '+12159227800',
#    'display_phone': '(215) 922-7800',
#    'distance': 2496.9785414970224},
#   {'id': 'M-5Zl-Dbxk4UHvzaHwKAew',
#    'alias': 'ms-molly-s-kitchen-philadelphia',
#    'name': 'Ms Molly’s Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/EViPsl4UmaGJmSA5IegNgQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ms-molly-s-kitchen-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 3,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'hotdog', 'title': 'Hot Dogs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.996073, 'longitude': -75.172931},
#    'transactions': [],
#    'location': {'address1': '2514 W Lehigh Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19132',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['2514 W Lehigh Ave', 'Philadelphia, PA 19132']},
#    'phone': '+12154034242',
#    'display_phone': '(215) 403-4242',
#    'distance': 4704.048571386026},
#   {'id': 'B6Lvq3sOYwhKxPzadDka9g',
#    'alias': 'zeppoli-collingswood',
#    'name': 'Zeppoli',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hNh57N8WG5LDq5BbkJ8tYg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zeppoli-collingswood?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 275,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.910702, 'longitude': -75.084456},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '618 Collings Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Collingswood',
#     'zip_code': '08107',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['618 Collings Ave', 'Collingswood, NJ 08107']},
#    'phone': '+18568542670',
#    'display_phone': '(856) 854-2670',
#    'distance': 8809.735430794155},
#   {'id': 'cVV8GWVIe9BwyCOKwrFgPA',
#    'alias': 'castellinos-philadelphia',
#    'name': "Castellino's",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/QNbOvotVpDMmkR4ufBfMlA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/castellinos-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 66,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'intlgrocery', 'title': 'International Grocery'},
#     {'alias': 'delis', 'title': 'Delis'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.97235, 'longitude': -75.12885},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '1255 E Palmer St',
#     'address2': None,
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19125',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1255 E Palmer St', 'Philadelphia, PA 19125']},
#    'phone': '+12154161187',
#    'display_phone': '(215) 416-1187',
#    'distance': 4139.286364662525},
#   {'id': '2kXBqCeNyW3Oe9QOVUjOpA',
#    'alias': 'la-scala-s-philadelphia',
#    'name': 'La Scala’s',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/H6yFf8aTD0xbqL_JbtSnNw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-scala-s-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 8,
#    'categories': [{'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 39.95425, 'longitude': -75.16835},
#    'transactions': ['delivery'],
#    'location': {'address1': '1701 John F Kennedy Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19103',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1701 John F Kennedy Blvd', 'Philadelphia, PA 19103']},
#    'phone': '+12159639399',
#    'display_phone': '(215) 963-9399',
#    'distance': 252.47099821685669},
#   {'id': 't5n5IBvXYG55xXrq6hga3Q',
#    'alias': 'caffe-ida-philadelphia-3',
#    'name': 'Caffe Ida',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/nNswcDisGorh9JQfgr_sBg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caffe-ida-philadelphia-3?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 32,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.924223, 'longitude': -75.175689},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '1732 W Passyunk Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19145',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1732 W Passyunk Ave', 'Philadelphia, PA 19145']},
#    'phone': '+12152180100',
#    'display_phone': '(215) 218-0100',
#    'distance': 3308.9887310128825},
#   {'id': 'LtLbT776NOAjva1ttA2h3w',
#    'alias': 'the-quick-fixx-philadelphia',
#    'name': 'The QUICK FIXX',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/eKU3Qg8N4aOWBDwNUaqtfg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-quick-fixx-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 321,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.944064, 'longitude': -75.1676029},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '1511 South St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19146',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1511 South St', 'Philadelphia, PA 19146']},
#    'phone': '+12672731066',
#    'display_phone': '(267) 273-1066',
#    'distance': 1123.3482936000896},
#   {'id': 'Bih0eT_lbbCUwKmGYpX0hw',
#    'alias': 'riccis-hoagies-philadelphia-3',
#    'name': "Ricci's Hoagies",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/QNnq-LCIUr8APaL-YA3hGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/riccis-hoagies-philadelphia-3?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 62,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.93535, 'longitude': -75.16156},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '1165 S 11th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19147',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1165 S 11th St', 'Philadelphia, PA 19147']},
#    'phone': '+12153346910',
#    'display_phone': '(215) 334-6910',
#    'distance': 2206.4969084642385}],
#  'total': 284,
#  'region': {'center': {'longitude': -75.17120361328125,
#    'latitude': 39.95378209544653}}}

# %%
#italian
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'Philadelphia', 'categories':'italian', 'offset':150 }
    
philadelphia_italian4 = requests.get(API_HOST,headers=headers, params=params).json()

philadelphia_italian4
# Out:
# {'businesses': [{'id': '7QfRLE_ti1yA0NqTWKLjdw',
#    'alias': 'la-viola-ovest-philadelphia',
#    'name': 'La Viola Ovest',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/CZzS-Usy65Kvx_GFQdIEuA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-viola-ovest-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 202,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.9479728192091,
#     'longitude': -75.1679581403732},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '252 S 16th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19102',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['252 S 16th St', 'Philadelphia, PA 19102']},
#    'phone': '+12157358631',
#    'display_phone': '(215) 735-8631',
#    'distance': 696.5001581957713},
#   {'id': 'hQY2yKi9OUGLgVApsK4h1Q',
#    'alias': 'cacias-bakery-philadelphia',
#    'name': "Cacia's Bakery",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/LN4CS-kaKJe0bbQ-deS4Fg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cacias-bakery-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 75,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.9209373, 'longitude': -75.1731796},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '1526 W Ritner St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19145',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1526 W Ritner St', 'Philadelphia, PA 19145']},
#    'phone': '+12153341340',
#    'display_phone': '(215) 334-1340',
#    'distance': 3656.054120260308},
#   {'id': 'nKK8tgjteduOIxALbfJNgg',
#    'alias': 'ristorante-la-buca-philadelphia',
#    'name': 'Ristorante La Buca',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MG96Kui4EuZCpJKSkeBvqA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ristorante-la-buca-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 111,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.947079, 'longitude': -75.154165},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '711 Locust St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19106',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['711 Locust St', 'Philadelphia, PA 19106']},
#    'phone': '+12159280556',
#    'display_phone': '(215) 928-0556',
#    'distance': 1632.490624866319},
#   {'id': 'bSWL0YxfawjS03_g2kgujA',
#    'alias': 'allegro-pizza-philadelphia',
#    'name': 'Allegro Pizza',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/mp82EWPoYMi8iqdqP6W2kg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/allegro-pizza-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 217,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 39.95139, 'longitude': -75.20295},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '3942 Spruce St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19104',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['3942 Spruce St', 'Philadelphia, PA 19104']},
#    'phone': '+12153828158',
#    'display_phone': '(215) 382-8158',
#    'distance': 2715.591228768233},
#   {'id': 'pTy5tFm9y8uzMjXhjWweFA',
#    'alias': 'mr-joes-cafe-philadelphia',
#    'name': "Mr Joe's Cafe",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/sin8tQcYINmvPZoikBKqDg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mr-joes-cafe-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 66,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.9299201965332,
#     'longitude': -75.1584320068359},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '1514 S 8th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19147',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1514 S 8th St', 'Philadelphia, PA 19147']},
#    'phone': '+12153341414',
#    'display_phone': '(215) 334-1414',
#    'distance': 2865.2528902273266},
#   {'id': 'ABxoFuzZy5mqQ8C5FJJajQ',
#    'alias': 'core-de-roma-bala-cynwyd',
#    'name': 'Core de Roma',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/core-de-roma-bala-cynwyd?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 2,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.028416, 'longitude': -75.238071},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '201 Jefferson St',
#     'address2': '',
#     'address3': None,
#     'city': 'Bala Cynwyd',
#     'zip_code': '19004',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['201 Jefferson St', 'Bala Cynwyd, PA 19004']},
#    'phone': '+14842784567',
#    'display_phone': '(484) 278-4567',
#    'distance': 10061.15755252944},
#   {'id': 'LSUa7rauZg6UNErHfuBDKg',
#    'alias': 'slice-philadelphia-4',
#    'name': 'Slice',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/WCXgH67X11whsdKxxwMAVA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/slice-philadelphia-4?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 87,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.9707126659431,
#     'longitude': -75.1297071576118},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '431 E Girard Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19125',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['431 E Girard Ave', 'Philadelphia, PA 19125']},
#    'phone': '+12154251555',
#    'display_phone': '(215) 425-1555',
#    'distance': 4006.4809749123033},
#   {'id': 'O2Ne4Eb3dTf8VIztA9qI5A',
#    'alias': 'uncle-oogies-philadelphia-3',
#    'name': "Uncle Oogie's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TADMJ0y3B0jth8CRshgkXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/uncle-oogies-philadelphia-3?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 63,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.9212723, 'longitude': -75.1466446},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '36 Snyder Ave',
#     'address2': '',
#     'address3': 'Next To Rite Aid',
#     'city': 'Philadelphia',
#     'zip_code': '19148',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['36 Snyder Ave',
#      'Next To Rite Aid',
#      'Philadelphia, PA 19148']},
#    'phone': '+12157559999',
#    'display_phone': '(215) 755-9999',
#    'distance': 4214.000267231619},
#   {'id': 'muu6xdNuHlNA9iShXFvjcA',
#    'alias': 'j-and-j-south-philly-pizza-philadelphia-3',
#    'name': 'J&J South Philly Pizza',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ITkhgM9AwhEX2gpZwoVB1Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/j-and-j-south-philly-pizza-philadelphia-3?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 142,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 39.9345041066408,
#     'longitude': -75.1587527990341},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1177 S 9th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19147',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1177 S 9th St', 'Philadelphia, PA 19147']},
#    'phone': '+12155511233',
#    'display_phone': '(215) 551-1233',
#    'distance': 2392.008685010523},
#   {'id': 'QKVX66UREuD6aQ0x_F17wA',
#    'alias': 'slice-philadelphia',
#    'name': 'Slice',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/fnRry0O2WM_6XfiCcAdrHg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/slice-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 298,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.934678, 'longitude': -75.160539},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1180 S 10th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19147',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1180 S 10th St', 'Philadelphia, PA 19147']},
#    'phone': '+12154630868',
#    'display_phone': '(215) 463-0868',
#    'distance': 2310.651831528272},
#   {'id': 's5K7M7BBFDbFkvv14XwkgA',
#    'alias': 'bronze-table-philadelphia',
#    'name': 'Bronze Table',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/DlwcE3BBNCD4QTWOBmqUiw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bronze-table-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 15,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pastashops', 'title': 'Pasta Shops'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.949747, 'longitude': -75.148196},
#    'transactions': ['delivery'],
#    'location': {'address1': '111 S Independence Mall E',
#     'address2': '',
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19106',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['111 S Independence Mall E',
#      'Philadelphia, PA 19106']},
#    'phone': '+12155608055',
#    'display_phone': '(215) 560-8055',
#    'distance': 2022.7284201176892},
#   {'id': 'lXVJLzBNEd5qWuoX1d1okQ',
#    'alias': 'eds-buffalo-wings-and-pizza-philadelphia',
#    'name': 'Eds Buffalo Wings and Pizza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/3EZGC-xrpbVpapN1u8PNSg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/eds-buffalo-wings-and-pizza-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 183,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 39.9584, 'longitude': -75.19281},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '3513 Lancaster Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19104',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['3513 Lancaster Ave', 'Philadelphia, PA 19104']},
#    'phone': '+12152224000',
#    'display_phone': '(215) 222-4000',
#    'distance': 1914.6670365923467},
#   {'id': 'AL0DVOgo8ZZvtrr0CDbxSA',
#    'alias': 'little-italy-philadelphia-philadelphia',
#    'name': 'Little Italy Philadelphia',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/little-italy-philadelphia-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 1,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.9559288, 'longitude': -75.1574567},
#    'transactions': [],
#    'location': {'address1': '6TH -10th Fitzwater St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19107',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['6TH -10th Fitzwater St', 'Philadelphia, PA 19107']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1195.8047530798306},
#   {'id': '_jM0lxArSLUdq6ogkRhzbA',
#    'alias': 'anthonys-coal-fired-pizza-wynnewood-2',
#    'name': "Anthony's Coal Fired Pizza",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-Y_dmx2rQo4n5Mg54e7SzA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/anthonys-coal-fired-pizza-wynnewood-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 88,
#    'categories': [{'alias': 'chicken_wings', 'title': 'Chicken Wings'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.000879, 'longitude': -75.272832},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '50 East Wynnewood Rd',
#     'address2': None,
#     'address3': '',
#     'city': 'Wynnewood',
#     'zip_code': '19096',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['50 East Wynnewood Rd', 'Wynnewood, PA 19096']},
#    'phone': '+16106455453',
#    'display_phone': '(610) 645-5453',
#    'distance': 10119.981359617599},
#   {'id': 'XIR6VBtBm5L9CzNqzEPKng',
#    'alias': 'three-countries-pizzeria-philadelphia',
#    'name': 'Three Countries Pizzeria',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/K5A-u4rO4keaAJctiknCnA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/three-countries-pizzeria-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 32,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 39.9321, 'longitude': -75.1723},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '1626 Dickinson St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19146',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1626 Dickinson St', 'Philadelphia, PA 19146']},
#    'phone': '+12152716590',
#    'display_phone': '(215) 271-6590',
#    'distance': 2409.949122856089},
#   {'id': 'd5fAUl4lKaNxGfiXj4Kygg',
#    'alias': 'little-italy-pizza-philadelphia',
#    'name': 'Little Italy Pizza',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/xwAkzUC--AkPwPg9kQzFGw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/little-italy-pizza-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 240,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.942855, 'longitude': -75.157207},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '901 South St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19147',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['901 South St', 'Philadelphia, PA 19147']},
#    'phone': '+12159221440',
#    'display_phone': '(215) 922-1440',
#    'distance': 1702.9050874822162},
#   {'id': 'mJ_itjZYQ_OA71q2NaWE4Q',
#    'alias': 'carangi-baking-philadelphia',
#    'name': 'Carangi Baking',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/WD-o6T--oYeDOm4E6gfBKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/carangi-baking-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 32,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.91664, 'longitude': -75.16848},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '2655 S Iseminger St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19148',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['2655 S Iseminger St', 'Philadelphia, PA 19148']},
#    'phone': '+12154626991',
#    'display_phone': '(215) 462-6991',
#    'distance': 4137.327287644825},
#   {'id': 'zAxWNkDWBvgNfIwTAyCBMw',
#    'alias': 'zios-brick-oven-pizzeria-philadelphia-11',
#    'name': "Zio's Brick Oven Pizzeria",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/azKgeQfEbTrwW1GQB4L7cA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zios-brick-oven-pizzeria-philadelphia-11?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 190,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.95008, 'longitude': -75.16167},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '111 S 13th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19107',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['111 S 13th St', 'Philadelphia, PA 19107']},
#    'phone': '+12156271615',
#    'display_phone': '(215) 627-1615',
#    'distance': 904.3462760924475},
#   {'id': 'gJvHJcDBnrcIKDGo9_-v5Q',
#    'alias': 'la-collina-bala-cynwyd',
#    'name': 'La Collina',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bHT0RfPaPuR836Ozt5W3og/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-collina-bala-cynwyd?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 137,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.0263432817004,
#     'longitude': -75.2319431177216},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '37-41 Ashland Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Bala Cynwyd',
#     'zip_code': '19004',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['37-41 Ashland Ave', 'Bala Cynwyd, PA 19004']},
#    'phone': '+16106681780',
#    'display_phone': '(610) 668-1780',
#    'distance': 9585.171096683242},
#   {'id': 'f37jqHSmSARVyrBOFnVD2w',
#    'alias': 'franco-and-giuseppe-cucina-italiana-upper-darby',
#    'name': 'Franco & Giuseppe Cucina Italiana',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4Eb8hZ_K7S2XqwjLRC7STw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/franco-and-giuseppe-cucina-italiana-upper-darby?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 2,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.96792011389167,
#     'longitude': -75.28958994895218},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '8921 W Chester Pike',
#     'address2': '',
#     'address3': None,
#     'city': 'Upper Darby',
#     'zip_code': '19082',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['8921 W Chester Pike', 'Upper Darby, PA 19082']},
#    'phone': '+14844557132',
#    'display_phone': '(484) 455-7132',
#    'distance': 10211.680551565963}],
#  'total': 284,
#  'region': {'center': {'longitude': -75.17120361328125,
#    'latitude': 39.95378209544653}}}

# %%
#italian
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'Philadelphia', 'categories':'italian', 'offset':200 }
    
philadelphia_italian5 = requests.get(API_HOST,headers=headers, params=params).json()

philadelphia_italian5
# Out:
# {'businesses': [{'id': 'UaRtzHAyTf19bMxkxZk7bw',
#    'alias': 'trieste-italian-restaurant-prospect-park-3',
#    'name': 'Trieste Italian Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/JaEqVEiyxK4BwY3fYkSi0w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/trieste-italian-restaurant-prospect-park-3?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 108,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.884827, 'longitude': -75.303595},
#    'transactions': ['pickup'],
#    'price': '$$',
#    'location': {'address1': '641 Chester Pike',
#     'address2': '',
#     'address3': '',
#     'city': 'Prospect Park',
#     'zip_code': '19076',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['641 Chester Pike', 'Prospect Park, PA 19076']},
#    'phone': '+16105348191',
#    'display_phone': '(610) 534-8191',
#    'distance': 13647.843387273062},
#   {'id': 'v7ibuvyZutqZ7pjMCH1exg',
#    'alias': 'franks-spaghetti-house-philadelphia',
#    'name': "Frank's Spaghetti House",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Mbt74ID_4PXpltyXF8xcHg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/franks-spaghetti-house-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 40,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.05618, 'longitude': -75.06185},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '7602 Castor Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19152',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['7602 Castor Ave', 'Philadelphia, PA 19152']},
#    'phone': '+12157456020',
#    'display_phone': '(215) 745-6020',
#    'distance': 14710.303371823524},
#   {'id': '8hKi4SyepMGe2W1L4aQ_JQ',
#    'alias': 'italian-kitchen-philadelphia',
#    'name': 'Italian Kitchen',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Xe3Blyp98wIRQ9eF32Xgdg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/italian-kitchen-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 22,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 39.9864213427882,
#     'longitude': -75.2479510009289},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '2035 N 63rd St',
#     'address2': None,
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19151',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['2035 N 63rd St', 'Philadelphia, PA 19151']},
#    'phone': '+12154776800',
#    'display_phone': '(215) 477-6800',
#    'distance': 7479.729251537559},
#   {'id': 'VoIX90UM5jwD7FSMAMCwrw',
#    'alias': 'johnnies-italian-restaurant-philadelphia-2',
#    'name': "Johnnie's Italian Restaurant",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-63bclziXSTvQ3jXcF1JgA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/johnnies-italian-restaurant-philadelphia-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 15,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.0227546691895,
#     'longitude': -75.0634384155273},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '4201 Comly St',
#     'address2': None,
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19135',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['4201 Comly St', 'Philadelphia, PA 19135']},
#    'phone': '+12155339920',
#    'display_phone': '(215) 533-9920',
#    'distance': 11962.222260448498},
#   {'id': 'zBT8l6b3wE_H541Msvg4Wg',
#    'alias': 'mamas-pizzeria-bala-cynwyd',
#    'name': "Mama's Pizzeria",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1_1T4_Yk7lwsU1SVDMmuRA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mamas-pizzeria-bala-cynwyd?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 200,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cheesesteaks', 'title': 'Cheesesteaks'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.0154, 'longitude': -75.22872},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '426 Belmont Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Bala Cynwyd',
#     'zip_code': '19004',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['426 Belmont Ave', 'Bala Cynwyd, PA 19004']},
#    'phone': '+16106644757',
#    'display_phone': '(610) 664-4757',
#    'distance': 8428.577434853582},
#   {'id': 'P9YxV-82uF3Z-yHVtoAPgA',
#    'alias': 'ozzys-pizza-shop-philadelphia',
#    'name': "Ozzy's Pizza Shop",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4jNdj18P2-g1AZN6e7nfrw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ozzys-pizza-shop-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 3,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.00021, 'longitude': -75.12467},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '3321 B St',
#     'address2': '',
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19134',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['3321 B St', 'Philadelphia, PA 19134']},
#    'phone': '+12157394600',
#    'display_phone': '(215) 739-4600',
#    'distance': 6506.269294271669},
#   {'id': 'WN8wJ8PiBcfSPVWtZZhZfA',
#    'alias': 'daivas-grille-philadelphia',
#    'name': "Daiva's Grille",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1qow46c7eZsolzTn0j_nLw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/daivas-grille-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 87,
#    'categories': [{'alias': 'diners', 'title': 'Diners'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.04137, 'longitude': -75.22615},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '6750 Ridge Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19128',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['6750 Ridge Ave', 'Philadelphia, PA 19128']},
#    'phone': '+12155084400',
#    'display_phone': '(215) 508-4400',
#    'distance': 10780.248757644038},
#   {'id': 'tZZvnDlhktteSfnkwho4FQ',
#    'alias': 'romarcos-clifton-heights',
#    'name': "Romarco's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SpT7KcCR7TVJCcNaKSELkQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/romarcos-clifton-heights?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 49,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.9325825219426,
#     'longitude': -75.2891798012581},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '451 E  Baltimore Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Clifton Heights',
#     'zip_code': '19018',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['451 E  Baltimore Ave', 'Clifton Heights, PA 19018']},
#    'phone': '+16106267414',
#    'display_phone': '(610) 626-7414',
#    'distance': 10330.141943785553},
#   {'id': 'RUfWgnSSQKjRNBpK0wSxfg',
#    'alias': 'isabella-pizza-philadelphia',
#    'name': 'Isabella Pizza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/GJX3cy5zTg7YwNXa5VFZPg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/isabella-pizza-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 142,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 39.9271608, 'longitude': -75.1668506},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1824 E Passyunk Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19148',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1824 E Passyunk Ave', 'Philadelphia, PA 19148']},
#    'phone': '+12155511212',
#    'display_phone': '(215) 551-1212',
#    'distance': 2983.3222221626056},
#   {'id': '_VQbAFHvYi50fJbfxlY6Yw',
#    'alias': 'cucina-italiana-philadelphia',
#    'name': 'Cucina Italiana',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/u7PTDDUmMUldPiS8_CRVVw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cucina-italiana-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 5,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 39.9552741947547,
#     'longitude': -75.1821326658617},
#    'transactions': [],
#    'location': {'address1': '2955 Market St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19104',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['2955 Market St', 'Philadelphia, PA 19104']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 946.2176657654708},
#   {'id': 'tDxZHakdC1C67XVC2QUVKQ',
#    'alias': 'zaccones-restaurant-philadelphia',
#    'name': "Zaccone's Restaurant",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/IEj6AreAwwnaBTgS_l5B4g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zaccones-restaurant-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 46,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.040781, 'longitude': -75.0478131},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3151 Cottman Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19149',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['3151 Cottman Ave', 'Philadelphia, PA 19149']},
#    'phone': '+12153352435',
#    'display_phone': '(215) 335-2435',
#    'distance': 14284.97924033196},
#   {'id': 'BFyfkA4u8tmSIvoZmEN00Q',
#    'alias': 'bentoulis-pizza-philadelphia',
#    'name': 'Bentoulis Pizza',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VQ7dPQqwVpbrq22zcpnFmQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bentoulis-pizza-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 35,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.01063, 'longitude': -75.10297},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '1226 E Hunting Park Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19124',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1226 E Hunting Park Ave', 'Philadelphia, PA 19124']},
#    'phone': '+12152893660',
#    'display_phone': '(215) 289-3660',
#    'distance': 8587.327936222677},
#   {'id': '9RiIQA4M2Y0AU3TkASJn3A',
#    'alias': 'nunzio-ristorante-rustico-collingswood',
#    'name': 'Nunzio',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2q0YMi4Ly9wrEmCEuozeGg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nunzio-ristorante-rustico-collingswood?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 220,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.91578, 'longitude': -75.06887},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '706 Haddon Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Collingswood',
#     'zip_code': '08108',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['706 Haddon Ave', 'Collingswood, NJ 08108']},
#    'phone': '+18568589840',
#    'display_phone': '(856) 858-9840',
#    'distance': 9693.418687056259},
#   {'id': 'xdqIB-PWPv6JUhrGHyKdOg',
#    'alias': 'not-just-pizza-philadelphia',
#    'name': 'Not Just Pizza',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GS_j2oUz9tUaXpOAiMsRBQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/not-just-pizza-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 91,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 39.92135, 'longitude': -75.16517},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '2240 S 11th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19148',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['2240 S 11th St', 'Philadelphia, PA 19148']},
#    'phone': '+12157555159',
#    'display_phone': '(215) 755-5159',
#    'distance': 3642.013000775523},
#   {'id': 'Qp_ESDGTLy0-YNSeVtJ_gA',
#    'alias': 'mediterranio-pizza-philadelphia',
#    'name': 'Mediterranio pizza',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/NoQlGuyJCK7Qtk-yUNfJvA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mediterranio-pizza-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 3,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 39.92562, 'longitude': -75.16843},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '1941 E Passyunk Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19148',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1941 E Passyunk Ave', 'Philadelphia, PA 19148']},
#    'phone': '+12155519900',
#    'display_phone': '(215) 551-9900',
#    'distance': 3141.3378994197765},
#   {'id': 'O0TrhNOPX8mokn6K4IPG2w',
#    'alias': 'green-leafs-bananas-philadelphia',
#    'name': "GREEN LEAF'S BANANAS",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ewUztqu9ihQ320txsICm8w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/green-leafs-bananas-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 5,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.8754077174871,
#     'longitude': -75.2382391131602},
#    'transactions': [],
#    'location': {'address1': '8500 Essington Ave',
#     'address2': 'Ste D9',
#     'address3': 'Terminal D',
#     'city': 'Philadelphia',
#     'zip_code': '19153',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['8500 Essington Ave',
#      'Ste D9',
#      'Terminal D',
#      'Philadelphia, PA 19153']},
#    'phone': '+12153653351',
#    'display_phone': '(215) 365-3351',
#    'distance': 10422.804537947339},
#   {'id': '5Kn1o2ryylzHMQVNFy5pyA',
#    'alias': 'anthonys-creative-italian-cuisine-haddon-heights-2',
#    'name': "Anthony's Creative Italian Cuisine",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/OmJINRfEgQnQh58I_SJLMA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/anthonys-creative-italian-cuisine-haddon-heights-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 60,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.8827133178711,
#     'longitude': -75.0574645996094},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '512 Station Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Haddon Heights',
#     'zip_code': '08035',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['512 Station Ave', 'Haddon Heights, NJ 08035']},
#    'phone': '+18563107766',
#    'display_phone': '(856) 310-7766',
#    'distance': 12505.790318244057},
#   {'id': '4BWK_TegPTxcLj9PV4GVhQ',
#    'alias': 'montegrillo-pizza-and-restaurant-pennsauken',
#    'name': 'Montegrillo Pizza & Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/t7qUYMq6NQlOAU98qvFfmA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/montegrillo-pizza-and-restaurant-pennsauken?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 37,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.96174, 'longitude': -75.06099},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '5825 Westfield Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Pennsauken',
#     'zip_code': '08110',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['5825 Westfield Ave', 'Pennsauken, NJ 08110']},
#    'phone': '+18569109000',
#    'display_phone': '(856) 910-9000',
#    'distance': 9425.576898862348},
#   {'id': 'bKF3GZfucAfdh5-B9jAqqA',
#    'alias': 'trios-fresh-italian-philadelphia-3',
#    'name': 'Trios Fresh Italian',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/PoI9ozV2xG8myrF-HMUgrQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/trios-fresh-italian-philadelphia-3?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 1,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 1.0,
#    'coordinates': {'latitude': 39.9708036, 'longitude': -75.157756},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '1308 W Girard Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19123',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1308 W Girard Ave', 'Philadelphia, PA 19123']},
#    'phone': '+12156271000',
#    'display_phone': '(215) 627-1000',
#    'distance': 2205.839434862847},
#   {'id': '8-1vYscR7TNGF7LcJeNZBQ',
#    'alias': 'tony-ronis-pizza-roxborough-philadelphia-6',
#    'name': "Tony Roni's Pizza Roxborough",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_nx1q1PAnL2eVtpN1G5BZg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tony-ronis-pizza-roxborough-philadelphia-6?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 87,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.0454066, 'longitude': -75.2327285},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '499 Domino Ln',
#     'address2': 'Ste 4350',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19128',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['499 Domino Ln',
#      'Ste 4350',
#      'Philadelphia, PA 19128']},
#    'phone': '+12154833335',
#    'display_phone': '(215) 483-3335',
#    'distance': 11457.05127061461}],
#  'total': 284,
#  'region': {'center': {'longitude': -75.17120361328125,
#    'latitude': 39.95378209544653}}}

# %%
#italian
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'Philadelphia', 'categories':'italian', 'offset':250 }
    
philadelphia_italian6 = requests.get(API_HOST,headers=headers, params=params).json()

philadelphia_italian6
# Out:
# {'businesses': [{'id': '9U454aiscZzLytBdFXLMBg',
#    'alias': 'fiesta-pizza-ii-philadelphia',
#    'name': 'Fiesta Pizza II',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/h6Q6ZSMMw4Xc5hBKkXEliw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fiesta-pizza-ii-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 78,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.030046608268, 'longitude': -75.206349503462},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '600 E Jamestown St',
#     'address2': None,
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19128',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['600 E Jamestown St', 'Philadelphia, PA 19128']},
#    'phone': '+12154821500',
#    'display_phone': '(215) 482-1500',
#    'distance': 8993.25536221902},
#   {'id': 'VN_ZawWxoiKLSCsMpSbVnw',
#    'alias': 'finizios-italian-eatery-and-pizzeria-westmont',
#    'name': "Finizio's Italian Eatery & Pizzeria",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rBv8LBTRUnS-XftLDbyZrw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/finizios-italian-eatery-and-pizzeria-westmont?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 46,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.9118713623432,
#     'longitude': -75.0541532106102},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '40 Haddon Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Westmont',
#     'zip_code': '08108',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['40 Haddon Ave', 'Westmont, NJ 08108']},
#    'phone': '+18568541222',
#    'display_phone': '(856) 854-1222',
#    'distance': 11014.618602329589},
#   {'id': 'kHzcw3U192T4GFIxFRU6Xg',
#    'alias': 'allenciass-italian-sausage-and-grill-lawnside',
#    'name': "Allencias's Italian Sausage & Grill",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/MvFJJUHu21ioWjsnkCX1_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/allenciass-italian-sausage-and-grill-lawnside?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 4,
#    'categories': [{'alias': 'hotdog', 'title': 'Hot Dogs'},
#     {'alias': 'cheesesteaks', 'title': 'Cheesesteaks'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.869602, 'longitude': -75.0446},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '310 Whitehorse Pike',
#     'address2': '',
#     'address3': '',
#     'city': 'Lawnside',
#     'zip_code': '08045',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['310 Whitehorse Pike', 'Lawnside, NJ 08045']},
#    'phone': '+18566567066',
#    'display_phone': '(856) 656-7066',
#    'distance': 14211.863330146261},
#   {'id': 'ArNDRug3p5zngNHiLivnFA',
#    'alias': 'cibo-bistro-wine-bar-philadelphia',
#    'name': 'CIBO Bistro Wine Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_7yKMNyF01KNDQ6Gy7kD-w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cibo-bistro-wine-bar-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 128,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 39.875016, 'longitude': -75.243913},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '8000 Essington Ave',
#     'address2': 'Level 2',
#     'address3': 'Terminal B',
#     'city': 'Philadelphia',
#     'zip_code': '19153',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['8000 Essington Ave',
#      'Level 2',
#      'Terminal B',
#      'Philadelphia, PA 19153']},
#    'phone': '+18665083558',
#    'display_phone': '(866) 508-3558',
#    'distance': 10731.427037463372},
#   {'id': 'mprtNLSD_AQ7pTb1vzbSdw',
#    'alias': 'mezzogiorno-philadelphia-3',
#    'name': 'Mezzogiorno',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Z_KaCUNNfSV_tDxuEjkyMA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mezzogiorno-philadelphia-3?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 41,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 39.8739945618154,
#     'longitude': -75.2439700294304},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '8000 Essington Ave',
#     'address2': 'Level 2',
#     'address3': 'Terminal B',
#     'city': 'Philadelphia',
#     'zip_code': '19153',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['8000 Essington Ave',
#      'Level 2',
#      'Terminal B',
#      'Philadelphia, PA 19153']},
#    'phone': '+12676845003',
#    'display_phone': '(267) 684-5003',
#    'distance': 10827.136116937443},
#   {'id': 'kKzKpNLm74kGC9UP4lVRdg',
#    'alias': 'baby-boss-pizza-and-grill-philadelphia',
#    'name': 'Baby Boss Pizza and Grill',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/m3NeIrp-l-6O_yoVrnlxnA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/baby-boss-pizza-and-grill-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 16,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.02877, 'longitude': -75.03912},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '4625 Princeton Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19135',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['4625 Princeton Ave', 'Philadelphia, PA 19135']},
#    'phone': '+12153389200',
#    'display_phone': '(215) 338-9200',
#    'distance': 14005.92329390946},
#   {'id': '10Bq-D7cUzwvY5pUJPWhmw',
#    'alias': 'ralphs-pizza-and-francescas-room-haddon-heights',
#    'name': "Ralph's Pizza & Francesca's Room",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/TMxXxp8esPKDL0-W3WOXAg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ralphs-pizza-and-francescas-room-haddon-heights?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 39,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.88254, 'longitude': -75.05772},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '520 Station Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Haddon Heights',
#     'zip_code': '08035',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['520 Station Ave', 'Haddon Heights, NJ 08035']},
#    'phone': '+18565470030',
#    'display_phone': '(856) 547-0030',
#    'distance': 12500.200589340182},
#   {'id': 'QgtYYJdJjSjfPJODkJNi7w',
#    'alias': 'daves-pizza-and-pasta-glenolden',
#    'name': "Dave's Pizza & Pasta",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tJ4xN13_36-i_AUtvplcEA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/daves-pizza-and-pasta-glenolden?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 25,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.904617, 'longitude': -75.29355},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '36 S MacDade Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Glenolden',
#     'zip_code': '19036',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['36 S MacDade Blvd', 'Glenolden, PA 19036']},
#    'phone': '+16104617223',
#    'display_phone': '(610) 461-7223',
#    'distance': 11777.92493582234},
#   {'id': '6bpaAOtlkp4eXRztuMzZxg',
#    'alias': 'slices-and-more-upper-darby',
#    'name': 'Slices and More',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/aIq_aIGW229Q3XlJ-R038g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/slices-and-more-upper-darby?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 12,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.9617719, 'longitude': -75.2604101},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '6932 Market St',
#     'address2': '',
#     'address3': '',
#     'city': 'Upper Darby',
#     'zip_code': '19082',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['6932 Market St', 'Upper Darby, PA 19082']},
#    'phone': '+16107343430',
#    'display_phone': '(610) 734-3430',
#    'distance': 7655.048085771517},
#   {'id': 'SdzgdLRLPXb240bFxMgz5g',
#    'alias': 'romans-pizza-philadelphia',
#    'name': "Roman's Pizza",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/aMmgkJVBAq3Fit0KnuTzfQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/romans-pizza-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 36,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.039176, 'longitude': -75.223424},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '6613 Ridge Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19128',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['6613 Ridge Ave', 'Philadelphia, PA 19128']},
#    'phone': '+12154822323',
#    'display_phone': '(215) 482-2323',
#    'distance': 10485.695878338194},
#   {'id': 'tFUgRbZiFkq2-XwYzeqNzw',
#    'alias': 'time-out-sports-restaurant-and-entertainment-barrington',
#    'name': 'Time Out Sports Restaurant & Entertainment',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/time-out-sports-restaurant-and-entertainment-barrington?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 5,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.8728561401367,
#     'longitude': -75.0453720092773},
#    'transactions': ['delivery'],
#    'location': {'address1': '241 White Horse Pike',
#     'address2': None,
#     'address3': '',
#     'city': 'Barrington',
#     'zip_code': '08007',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['241 White Horse Pike', 'Barrington, NJ 08007']},
#    'phone': '+18566724186',
#    'display_phone': '(856) 672-4186',
#    'distance': 14004.42830234122},
#   {'id': 'brvQyLy-T9_tcVk7XRJhcA',
#    'alias': 'genova-pizzeria-audubon',
#    'name': 'Genova Pizzeria',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Du8wjqi5dKkJAiYLZIiXDg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/genova-pizzeria-audubon?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 26,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'cheesesteaks', 'title': 'Cheesesteaks'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.899692, 'longitude': -75.069429},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '132 Cuthbert Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Audubon',
#     'zip_code': '08106',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['132 Cuthbert Blvd', 'Audubon, NJ 08106']},
#    'phone': '+18565468727',
#    'display_phone': '(856) 546-8727',
#    'distance': 10557.22896553016},
#   {'id': 'ulcTp2lgks7oQWMcJJa1eg',
#    'alias': 'randazzos-pizzeria-collingswood',
#    'name': "Randazzo's Pizzeria",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/i_mPpDIFPfn0VBkdeDCLrQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/randazzos-pizzeria-collingswood?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 17,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 39.9109116, 'longitude': -75.0841522},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '602 Collings Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Collingswood',
#     'zip_code': '08107',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['602 Collings Ave', 'Collingswood, NJ 08107']},
#    'phone': '+18568542920',
#    'display_phone': '(856) 854-2920',
#    'distance': 8836.596551453385},
#   {'id': 'NtJU9h4fDhe_fSoE1Gibbg',
#    'alias': 'bravo-pizza-ii-philadelphia',
#    'name': 'Bravo Pizza II',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/SsInlix6sGUwY2VWBN3mkA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bravo-pizza-ii-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 11,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.0303798, 'longitude': -75.1456348},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '1323 Lindley Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19141',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1323 Lindley Ave', 'Philadelphia, PA 19141']},
#    'phone': '+12153249411',
#    'display_phone': '(215) 324-9411',
#    'distance': 8795.630276712796},
#   {'id': 'LyV2VIBVyF2EUd3GEiD17A',
#    'alias': 'nick-and-joes-pizzeria-haddon-township',
#    'name': "Nick & Joe's Pizzeria",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hDUCykf7r51W648Gz6av-g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nick-and-joes-pizzeria-haddon-township?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 30,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.90194, 'longitude': -75.06376},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '668 W Cuthbert Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Haddon Township',
#     'zip_code': '08108',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['668 W Cuthbert Blvd', 'Haddon Township, NJ 08108']},
#    'phone': '+18568580077',
#    'display_phone': '(856) 858-0077',
#    'distance': 10921.190202930029},
#   {'id': 'C-HeyK5U6QabMutj6GaG0w',
#    'alias': 'boston-style-pizza-wynnewood-2',
#    'name': 'Boston Style Pizza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FIWlDEFqb9TViBxx5ypTXw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boston-style-pizza-wynnewood-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 53,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 39.98416, 'longitude': -75.27562},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1432 Manoa Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Wynnewood',
#     'zip_code': '19096',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1432 Manoa Rd', 'Wynnewood, PA 19096']},
#    'phone': '+16106496060',
#    'display_phone': '(610) 649-6060',
#    'distance': 9518.508923830901},
#   {'id': 'SjS7bdnS3KAkhq5bWut9XQ',
#    'alias': 'toscanini-grill-and-pizza-philadelphia-3',
#    'name': 'Toscanini Grill and Pizza',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lM9VUVKgi2X9pINuq8_ruA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/toscanini-grill-and-pizza-philadelphia-3?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 8,
#    'categories': [{'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 39.98391, 'longitude': -75.11989},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '2200 E Lehigh Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19125',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['2200 E Lehigh Ave', 'Philadelphia, PA 19125']},
#    'phone': '+12152282888',
#    'display_phone': '(215) 228-2888',
#    'distance': 5509.434973290707},
#   {'id': '9gtdKU9FLOXFW741VuxdDQ',
#    'alias': 'vero-pizzeria-bellmawr',
#    'name': 'Vero Pizzeria',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fDTffN7XJQeLJjBTzxHJyA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vero-pizzeria-bellmawr?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 18,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.86507, 'longitude': -75.07989},
#    'transactions': ['delivery'],
#    'location': {'address1': '108 S Black Horse Pike',
#     'address2': '',
#     'address3': None,
#     'city': 'Bellmawr',
#     'zip_code': '08031',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['108 S Black Horse Pike', 'Bellmawr, NJ 08031']},
#    'phone': '+18569314436',
#    'display_phone': '(856) 931-4436',
#    'distance': 12594.90653131272},
#   {'id': 'fQtFa0ppH1cmI_IUpsmu-Q',
#    'alias': 'centrellas-deli-havertown',
#    'name': "Centrella's Deli",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/u3zHNCfLhMHXIn_6VCmpYA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/centrellas-deli-havertown?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 50,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'catering', 'title': 'Caterers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.97913, 'longitude': -75.30395},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '10 Brookline Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Havertown',
#     'zip_code': '19083',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['10 Brookline Blvd', 'Havertown, PA 19083']},
#    'phone': '+16108532466',
#    'display_phone': '(610) 853-2466',
#    'distance': 11659.866636637593},
#   {'id': 'X0hWkMBvDTPz2oJwkHajmg',
#    'alias': 'carosello-pizza-and-pasta-runnemede',
#    'name': 'Carosello Pizza & Pasta',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/iiCsZcr6wMIFg922uxWdnw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/carosello-pizza-and-pasta-runnemede?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 14,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.85706, 'longitude': -75.06399},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '835 E Clements Bridge Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Runnemede',
#     'zip_code': '08078',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['835 E Clements Bridge Rd', 'Runnemede, NJ 08078']},
#    'phone': '+18569395277',
#    'display_phone': '(856) 939-5277',
#    'distance': 14121.092315316257}],
#  'total': 284,
#  'region': {'center': {'longitude': -75.17120361328125,
#    'latitude': 39.95378209544653}}}

# %%
#japanese
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'Philadelphia', 'categories':'japanese' }
    
philadelphia_japanese1 = requests.get(API_HOST,headers=headers, params=params).json()

philly_ethnic_totals.loc[5, 'City'] = 'Philadelphia'
philly_ethnic_totals.loc[5, 'Ethnicity'] = 'Japanese'
philly_ethnic_totals.loc[5, 'Total Restaurants'] = (philadelphia_japanese["total"])
philly_ethnic_totals
# Out:
#            City Ethnicity Total Restaurants
# 0  Philadelphia   Chinese               414
# 1  Philadelphia    French                25
# 2  Philadelphia     Greek                21
# 3  Philadelphia    Indian              4500
# 4  Philadelphia   Italian               283
# 5  Philadelphia  Japanese               124

# %%
#japanese
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'Philadelphia', 'categories':'japanese', 'offset':50 }
    
philadelphia_japanese2 = requests.get(API_HOST,headers=headers, params=params).json()

# %%
#japanese
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'Philadelphia', 'categories':'japanese', 'offset':100 }
    
philadelphia_japanese3 = requests.get(API_HOST,headers=headers, params=params).json()

philadelphia_japanese3
# Out:
# {'businesses': [{'id': '-iSTJj5oyS6kzvaiw5T0Fg',
#    'alias': 'dragon-house-collingswood',
#    'name': 'Dragon House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vQaIFuv-GRStSGw74X6kTw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dragon-house-collingswood?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 50,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.9203199, 'longitude': -75.08026},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '329 Haddon Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Collingswood',
#     'zip_code': '08108',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['329 Haddon Ave', 'Collingswood, NJ 08108']},
#    'phone': '+18568546688',
#    'display_phone': '(856) 854-6688',
#    'distance': 8596.384451052636},
#   {'id': 'Nre140uX7xbHK2W80kzO6A',
#    'alias': 'gachi-sushi-and-noodle-philadelphia-6',
#    'name': 'Gachi Sushi and Noodle',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/dK84qqSr4HVOxX-xJ6r3oA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gachi-sushi-and-noodle-philadelphia-6?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 43,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.874253, 'longitude': -75.251319},
#    'transactions': [],
#    'location': {'address1': '8000 Essington Ave',
#     'address2': 'Terminal E',
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19153',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['8000 Essington Ave',
#      'Terminal E',
#      'Philadelphia, PA 19153']},
#    'phone': '+12154921290',
#    'display_phone': '(215) 492-1290',
#    'distance': 11175.422899658963},
#   {'id': 'ZRS0jT6vkyiNuhMbpjUahQ',
#    'alias': 'pearl-chinese-and-japanese-cuisine-lansdowne',
#    'name': 'Pearl Chinese & Japanese Cuisine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7qAHdZB2duNRMGAjVOVIVQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pearl-chinese-and-japanese-cuisine-lansdowne?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 53,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 39.95059, 'longitude': -75.28068},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '339 N Lansdowne Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Lansdowne',
#     'zip_code': '19050',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['339 N Lansdowne Ave', 'Lansdowne, PA 19050']},
#    'phone': '+16106233227',
#    'display_phone': '(610) 623-3227',
#    'distance': 9332.522070430437},
#   {'id': 'ymhBjthyws3lyVF_84OiyA',
#    'alias': 'sea-soul-philadelphia',
#    'name': 'Sea Soul',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/xta2C8YUZ828Nj3G0t-3cQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sea-soul-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 4,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 40.03724, 'longitude': -75.118674},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '5675 N Front St',
#     'address2': None,
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19120',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['5675 N Front St', 'Philadelphia, PA 19120']},
#    'phone': '+12673889888',
#    'display_phone': '(267) 388-9888',
#    'distance': 10302.60079631652},
#   {'id': 'kimOwpoIWzJJx7NHTAj74Q',
#    'alias': 'little-kitchen-philadelphia',
#    'name': 'Little Kitchen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/g7_iLdxrgwp2BRGzQo6eMQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/little-kitchen-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 49,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'thai', 'title': 'Thai'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.0000840440678,
#     'longitude': -75.2284179915604},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '5000 City Line Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19131',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['5000 City Line Ave', 'Philadelphia, PA 19131']},
#    'phone': '+12154737147',
#    'display_phone': '(215) 473-7147',
#    'distance': 7090.469600158949},
#   {'id': 'fei9rruZ08-jy2pRz_0fNw',
#    'alias': 'herosame-ardmore-2',
#    'name': 'Herosame',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dikTVLeGFf6AIDz_9C58sw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/herosame-ardmore-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 178,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.9937355183032,
#     'longitude': -75.2978800121183},
#    'transactions': ['pickup'],
#    'price': '$$',
#    'location': {'address1': '2371 Haverford Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Ardmore',
#     'zip_code': '19003',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['2371 Haverford Rd', 'Ardmore, PA 19003']},
#    'phone': '+16106497192',
#    'display_phone': '(610) 649-7192',
#    'distance': 11672.925053273959},
#   {'id': 'XOkXEpWdgsqORIwyb_hwdQ',
#    'alias': 'ginza-sushi-hibachi-steak-house-drexel-hill',
#    'name': 'Ginza Sushi Hibachi Steak House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/szfcchwYNX6wjvpAL8ZXGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ginza-sushi-hibachi-steak-house-drexel-hill?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 13,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'fooddeliveryservices', 'title': 'Food Delivery Services'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.944738, 'longitude': -75.296639},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '3703 Garrett Rd',
#     'address2': '',
#     'address3': None,
#     'city': 'Drexel Hill',
#     'zip_code': '19026',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['3703 Garrett Rd', 'Drexel Hill, PA 19026']},
#    'phone': '+14844612383',
#    'display_phone': '(484) 461-2383',
#    'distance': 10727.872618968408},
#   {'id': 'tPbiFHmQ9SWfPpT23Ck7bw',
#    'alias': 'sakura-teriyaki-upper-darby-3',
#    'name': 'Sakura Teriyaki',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/k4Vc4Rn8NRyobU9l3JgTVA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sakura-teriyaki-upper-darby-3?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 16,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 39.96396, 'longitude': -75.26823},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '7335 Westchester Pike',
#     'address2': None,
#     'address3': '',
#     'city': 'Upper Darby',
#     'zip_code': '19082',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['7335 Westchester Pike', 'Upper Darby, PA 19082']},
#    'phone': '+14844694823',
#    'display_phone': '(484) 469-4823',
#    'distance': 8362.071828600285},
#   {'id': '6NWNBToJeEzgkT1ZxeFt-Q',
#    'alias': 'sakana-ardmore',
#    'name': 'Sakana',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0XIpEY0VikX9-cSPV9gA2Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sakana-ardmore?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 6,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.0063349258845,
#     'longitude': -75.2906735613942},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '40 Rittenhouse Pl',
#     'address2': '',
#     'address3': None,
#     'city': 'Ardmore',
#     'zip_code': '19003',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['40 Rittenhouse Pl', 'Ardmore, PA 19003']},
#    'phone': '+16105155355',
#    'display_phone': '(610) 515-5355',
#    'distance': 11737.489385254434},
#   {'id': 'gHwjEvz_Q53vPG1RqKbqTA',
#    'alias': 'benihana-pennsauken',
#    'name': 'Benihana',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/T10p_7r_0iviQkyl7etOHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/benihana-pennsauken?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 202,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 39.933835, 'longitude': -75.066791},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '5255 Marlton Pike',
#     'address2': '',
#     'address3': '',
#     'city': 'Pennsauken',
#     'zip_code': '08109',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['5255 Marlton Pike', 'Pennsauken, NJ 08109']},
#    'phone': '+18566656320',
#    'display_phone': '(856) 665-6320',
#    'distance': 9173.3797985371},
#   {'id': 'ANmX99M5KtNWi5g39TFIKw',
#    'alias': 'noobar-philadelphia-2',
#    'name': 'Noobar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qrFJa-R1vNBPvT0EcPyIBw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/noobar-philadelphia-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 44,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 39.875104, 'longitude': -75.243642},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '8500 Essington Ave',
#     'address2': 'Level 2',
#     'address3': 'Terminal B, Gate B3',
#     'city': 'Philadelphia',
#     'zip_code': '19153',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['8500 Essington Ave',
#      'Level 2',
#      'Terminal B, Gate B3',
#      'Philadelphia, PA 19153']},
#    'phone': '+18665083558',
#    'display_phone': '(866) 508-3558',
#    'distance': 10710.091132667858},
#   {'id': 'StlMQ9_9Vk5vH2BHKaQRaA',
#    'alias': 'oishi-sushi-japanese-and-chinese-food-runnemede-3',
#    'name': 'Oishi Sushi Japanese & Chinese Food',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/FBC4277uGo80b8BTXpttFA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oishi-sushi-japanese-and-chinese-food-runnemede-3?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 12,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.85706, 'longitude': -75.06399},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '835 E Clements Bridge Rd',
#     'address2': 'Ste 6',
#     'address3': None,
#     'city': 'Runnemede',
#     'zip_code': '08078',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['835 E Clements Bridge Rd',
#      'Ste 6',
#      'Runnemede, NJ 08078']},
#    'phone': '+18563120888',
#    'display_phone': '(856) 312-0888',
#    'distance': 14121.092315316257},
#   {'id': 'p7skNVy_2fV6RCAJK0yO5g',
#    'alias': 'mikado-thai-pepper-restaurant-ardmore',
#    'name': 'Mikado Thai Pepper Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/IJybTBU1Z-1G-jpXAI1Kdg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mikado-thai-pepper-restaurant-ardmore?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 174,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.00655, 'longitude': -75.28888},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '64-66 E Lancaster Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Ardmore',
#     'zip_code': '19003',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['64-66 E Lancaster Ave', 'Ardmore, PA 19003']},
#    'phone': '+16106425951',
#    'display_phone': '(610) 642-5951',
#    'distance': 11614.334312281091},
#   {'id': 'lTkkSkvVhJIbHqVJKv6w9w',
#    'alias': 'classic-asia-haddon-heights',
#    'name': 'Classic Asia',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/EF672_cGDE2uDjGXIf7esg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/classic-asia-haddon-heights?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 50,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.88215, 'longitude': -75.05934},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '611 Station Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Haddon Heights',
#     'zip_code': '08035',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['611 Station Ave', 'Haddon Heights, NJ 08035']},
#    'phone': '+18563238207',
#    'display_phone': '(856) 323-8207',
#    'distance': 12427.316225363791},
#   {'id': 'BOUmrR6yo4cjeDJn-l_zFg',
#    'alias': 'dream-house-asian-bistro-philadelphia',
#    'name': 'Dream House Asian Bistro',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_j5ENhH23b680aR9VVSaAg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dream-house-asian-bistro-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 133,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.03438505088, 'longitude': -75.216117126152},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '6127 Ridge Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19128',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['6127 Ridge Ave', 'Philadelphia, PA 19128']},
#    'phone': '+12154827375',
#    'display_phone': '(215) 482-7375',
#    'distance': 9745.129531361472},
#   {'id': 'oGl-gsxNk0z15ucwlB3RcA',
#    'alias': 'o-bento-sushi-and-catering-philadelphia',
#    'name': "O'Bento Sushi & Catering",
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/o-bento-sushi-and-catering-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 7,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 39.9533805847168,
#     'longitude': -75.1715774536133},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '18 Market St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19103',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['18 Market St', 'Philadelphia, PA 19103']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 726.7335026071797},
#   {'id': 'HwO0dgp-2mv8EZqI4eWi9w',
#    'alias': 'ginza-japanese-and-asian-restaurant-runnemede',
#    'name': 'Ginza Japanese & Asian Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9RZd8BCjHxRBvVjGGpgQQQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ginza-japanese-and-asian-restaurant-runnemede?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 59,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.8517756, 'longitude': -75.0738671},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '327 N Black Horse Pike',
#     'address2': '',
#     'address3': '',
#     'city': 'Runnemede',
#     'zip_code': '08078',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['327 N Black Horse Pike', 'Runnemede, NJ 08078']},
#    'phone': '+18569393688',
#    'display_phone': '(856) 939-3688',
#    'distance': 14056.778793923613},
#   {'id': 'y8qe5iBIYuSWdVqqWscRtg',
#    'alias': 'watami-sushi-barrington',
#    'name': 'Watami Sushi',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/oiUIHmfeRe2JwfAHn-LF9g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/watami-sushi-barrington?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 24,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.8651098, 'longitude': -75.0550157},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '657 Clements Bridge Rd',
#     'address2': None,
#     'address3': '',
#     'city': 'Barrington',
#     'zip_code': '08007',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['657 Clements Bridge Rd', 'Barrington, NJ 08007']},
#    'phone': '+18566879001',
#    'display_phone': '(856) 687-9001',
#    'distance': 13950.136670916234},
#   {'id': '7YFRk0jPdApzMu55U7_yrA',
#    'alias': 'woksabi-collingswood',
#    'name': 'Woksabi',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6gsJm7Wds6t5J3NCgd6a8Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/woksabi-collingswood?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 124,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.9167802, 'longitude': -75.0707158},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '608 Haddon Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Collingswood',
#     'zip_code': '08108',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['608 Haddon Ave', 'Collingswood, NJ 08108']},
#    'phone': '+18568586688',
#    'display_phone': '(856) 858-6688',
#    'distance': 9504.393072097066},
#   {'id': 'NMrp7FFmZqV45i4TZ-DVkg',
#    'alias': 'oriental-palace-lawnside',
#    'name': 'Oriental Palace',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_Fyko5V6P2MjM5bq0sg6gw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oriental-palace-lawnside?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 35,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.86815, 'longitude': -75.0410001},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '200 White Horse Pike N',
#     'address2': '',
#     'address3': '',
#     'city': 'Lawnside',
#     'zip_code': '08045',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['200 White Horse Pike N', 'Lawnside, NJ 08045']},
#    'phone': '+18565468888',
#    'display_phone': '(856) 546-8888',
#    'distance': 14600.470431311016}],
#  'total': 124,
#  'region': {'center': {'longitude': -75.17120361328125,
#    'latitude': 39.95378209544653}}}

# %%
#brazilian
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'Philadelphia', 'categories':'brazilian' }
    
philadelphia_brazilian = requests.get(API_HOST,headers=headers, params=params).json()

philly_ethnic_totals.loc[6, 'City'] = 'Philadelphia'
philly_ethnic_totals.loc[6, 'Ethnicity'] = 'Brazilian'
philly_ethnic_totals.loc[6, 'Total Restaurants'] = (philadelphia_brazilian["total"])

philadelphia_brazilian
# Out:
# {'businesses': [{'id': 'kXmscD-bp90t4QAh0H7Dig',
#    'alias': 'picanha-brazilian-steakhouse-philadelphia',
#    'name': 'Picanha Brazilian Steakhouse',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/S0KICPjNZrO5pGZnWR2lpQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/picanha-brazilian-steakhouse-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 56,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'brazilian', 'title': 'Brazilian'},
#     {'alias': 'buffets', 'title': 'Buffets'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.94750233, 'longitude': -75.159641},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '1111 Locust St',
#     'address2': None,
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19107',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1111 Locust St', 'Philadelphia, PA 19107']},
#    'phone': '+12156088870',
#    'display_phone': '(215) 608-8870',
#    'distance': 1199.4722633705096},
#   {'id': 'cGX-1IUwXOjkUqZbkKYcjw',
#    'alias': 'fogo-de-chao-brazilian-steakhouse-philadelphia-8',
#    'name': 'Fogo de Chao Brazilian Steakhouse',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2w6chNoq4WFg63JMBo3m7A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fogo-de-chao-brazilian-steakhouse-philadelphia-8?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 1359,
#    'categories': [{'alias': 'brazilian', 'title': 'Brazilian'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.9509166, 'longitude': -75.1629711},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '1337 Chestnut St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19107',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1337 Chestnut St', 'Philadelphia, PA 19107']},
#    'phone': '+12156369700',
#    'display_phone': '(215) 636-9700',
#    'distance': 770.6862160862655},
#   {'id': 'gjFUrbSMo1rA1jgG5IhA2A',
#    'alias': 'chima-steakhouse-philadelphia-3',
#    'name': 'Chima Steakhouse',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TW1xII0oKSKQTI6--xLcPA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chima-steakhouse-philadelphia-3?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 670,
#    'categories': [{'alias': 'brazilian', 'title': 'Brazilian'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.954773, 'longitude': -75.172639},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '1901 John F Kennedy Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19103',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1901 John F Kennedy Blvd', 'Philadelphia, PA 19103']},
#    'phone': '+12155253233',
#    'display_phone': '(215) 525-3233',
#    'distance': 164.64961946302728},
#   {'id': 'cDj-eJ9VODmTKczeOWNq8A',
#    'alias': 'the-taste-of-brazil-philadelphia-philadelphia',
#    'name': 'The Taste of Brazil - Philadelphia',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/12lW5OMZqz2kQ3cuH0vRWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-taste-of-brazil-philadelphia-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 143,
#    'categories': [{'alias': 'brazilian', 'title': 'Brazilian'},
#     {'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.0334647, 'longitude': -75.0720322},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '6222 Bustleton Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19149',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['6222 Bustleton Ave', 'Philadelphia, PA 19149']},
#    'phone': '+12157446206',
#    'display_phone': '(215) 744-6206',
#    'distance': 12256.372727081995},
#   {'id': '5Qz7TJFXhm8Mjc8xzoSV5Q',
#    'alias': 'picanha-brazilian-steakhouse-philadelphia-3',
#    'name': 'Picanha Brazilian Steakhouse',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GPQ9xEbd4vv8-mbPaPsgOg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/picanha-brazilian-steakhouse-philadelphia-3?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 231,
#    'categories': [{'alias': 'brazilian', 'title': 'Brazilian'},
#     {'alias': 'buffets', 'title': 'Buffets'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.040622, 'longitude': -75.075808},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '6501 Castor Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19149',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['6501 Castor Ave', 'Philadelphia, PA 19149']},
#    'phone': '+12157434647',
#    'display_phone': '(215) 743-4647',
#    'distance': 12623.31101689693},
#   {'id': '5M3AWxHBAJn6ET3AtBzmDw',
#    'alias': 'brazilian-pizza-philly-philadelphia',
#    'name': 'Brazilian Pizza Philly',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gzvofJWae-91jXP54i-zLw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brazilian-pizza-philly-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 4,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'brazilian', 'title': 'Brazilian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.05501, 'longitude': -75.06299},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '7518 Castor Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19152',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['7518 Castor Ave', 'Philadelphia, PA 19152']},
#    'phone': '+12157423100',
#    'display_phone': '(215) 742-3100',
#    'distance': 14552.0045504615},
#   {'id': 'MRYNW6VJstNHaCny4OAF0w',
#    'alias': 'tropicana-restaurant-philadelphia',
#    'name': 'Tropicana Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/V0lvIEf9zjDWQD4IreDqyA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tropicana-restaurant-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 2,
#    'categories': [{'alias': 'brazilian', 'title': 'Brazilian'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.0394172668457,
#     'longitude': -75.0778961181641},
#    'transactions': ['delivery'],
#    'location': {'address1': '6394 Castor Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19149',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['6394 Castor Ave', 'Philadelphia, PA 19149']},
#    'phone': '+12155356625',
#    'display_phone': '(215) 535-6625',
#    'distance': 12401.71900911639},
#   {'id': 'B4R8fqq5Q4L7I7YFmouDSQ',
#    'alias': 'ipanema-sports-bar-and-grill-philadelphia',
#    'name': 'Ipanema Sports Bar and Grill',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gDmiahVDmkYg2aYzFd8HQw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ipanema-sports-bar-and-grill-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 3,
#    'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#     {'alias': 'brazilian', 'title': 'Brazilian'},
#     {'alias': 'portuguese', 'title': 'Portuguese'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 40.05549, 'longitude': -75.06254},
#    'transactions': [],
#    'location': {'address1': '7540 Castor Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19152',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['7540 Castor Ave', 'Philadelphia, PA 19152']},
#    'phone': '+12157421542',
#    'display_phone': '(215) 742-1542',
#    'distance': 14613.639867925596},
#   {'id': '-KncfNxXHo2DA46fR39K5w',
#    'alias': 'cantinho-brasileiro-restaurante-philadelphia',
#    'name': 'Cantinho Brasileiro Restaurante',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/CQxIbxU_m-gi6pMHV7w2SA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cantinho-brasileiro-restaurante-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 11,
#    'categories': [{'alias': 'brazilian', 'title': 'Brazilian'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.0554008483887,
#     'longitude': -75.062629699707},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '7536 Castor Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19152',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['7536 Castor Ave', 'Philadelphia, PA 19152']},
#    'phone': '+12157451381',
#    'display_phone': '(215) 745-1381',
#    'distance': 14602.91888004194},
#   {'id': 'YQqPCA52lXYt-Jd5YsIc_A',
#    'alias': 'supreme-pizzeria-and-bakery-philadelphia-2',
#    'name': 'Supreme Pizzeria & Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/SL_rg_uXMsdwHcizk7oSBg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/supreme-pizzeria-and-bakery-philadelphia-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 3,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'brazilian', 'title': 'Brazilian'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 40.05492, 'longitude': -75.06308},
#    'transactions': ['delivery'],
#    'location': {'address1': '7514 Castor Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19152',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['7514 Castor Ave', 'Philadelphia, PA 19152']},
#    'phone': '+12157227464',
#    'display_phone': '(215) 722-7464',
#    'distance': 14533.979599326787}],
#  'total': 10,
#  'region': {'center': {'longitude': -75.17120361328125,
#    'latitude': 39.95378209544653}}}

# %%
#mexican
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'Philadelphia', 'categories':'mexican' }
    
philadelphia_mexican1 = requests.get(API_HOST,headers=headers, params=params).json()

philly_ethnic_totals.loc[7, 'City'] = 'Philadelphia'
philly_ethnic_totals.loc[7, 'Ethnicity'] = 'Mexican'
philly_ethnic_totals.loc[7, 'Total Restaurants'] = (philadelphia_mexican["total"])
philly_ethnic_totals
# Out:
#            City  Ethnicity Total Restaurants
# 0  Philadelphia    Chinese               414
# 1  Philadelphia     French                25
# 2  Philadelphia      Greek                21
# 3  Philadelphia     Indian              4500
# 4  Philadelphia    Italian               283
# 5  Philadelphia   Japanese               124
# 6  Philadelphia  Brazilian                10
# 7  Philadelphia    Mexican               247

# %%
#mexican
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'Philadelphia', 'categories':'mexican', 'offset':50 }
    
philadelphia_mexican2 = requests.get(API_HOST,headers=headers, params=params).json()

philadelphia_mexican2
# Out:
# {'businesses': [{'id': 'pORvWLJb_ioqIrNo-yacfw',
#    'alias': 'panchos-cafe-philadelphia-2',
#    'name': "Pancho's Cafe",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/z1_FjV7ud3DSX0JaQ5qlVw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/panchos-cafe-philadelphia-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 82,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.969089, 'longitude': -75.138192},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '152 West Girard Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19123',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['152 West Girard Ave', 'Philadelphia, PA 19123']},
#    'phone': '+12156271495',
#    'display_phone': '(215) 627-1495',
#    'distance': 3287.014189722443},
#   {'id': 'venWfi69QVylbyrvaPt0nQ',
#    'alias': 'cafe-ynez-philadelphia',
#    'name': 'Cafe Ynez',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7de_Dlmt7yXZT5YJ8sFKZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-ynez-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 258,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.9394117528025,
#     'longitude': -75.177328118915},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2025 Washington Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19146',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['2025 Washington Ave', 'Philadelphia, PA 19146']},
#    'phone': '+12152787579',
#    'display_phone': '(215) 278-7579',
#    'distance': 1681.0385001934364},
#   {'id': '5R3-eCIk4dRBtXo0A5MAzQ',
#    'alias': 'añejo-philadelphia-philadelphia',
#    'name': 'Añejo Philadelphia',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HxI-vUUtosU8MN6frZdz5Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/a%C3%B1ejo-philadelphia-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 45,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.966564, 'longitude': -75.139991},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '1001 N 2nd St',
#     'address2': '',
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19123',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1001 N 2nd St', 'Philadelphia, PA 19123']},
#    'phone': '+12675345746',
#    'display_phone': '(267) 534-5746',
#    'distance': 3016.1145156504986},
#   {'id': 'asbEI02GRGFPSPM97hrIaA',
#    'alias': 'nemi-restaurant-philadelphia-2',
#    'name': 'Nemi Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/4a4b0NITpVNgX4-1MHpfmQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nemi-restaurant-philadelphia-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 96,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.9816738971912,
#     'longitude': -75.1090306788683},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2636 E Ann St',
#     'address2': '',
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19134',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['2636 E Ann St', 'Philadelphia, PA 19134']},
#    'phone': '+12675190713',
#    'display_phone': '(267) 519-0713',
#    'distance': 6139.372572502366},
#   {'id': 'wqpTOjsmogJy7syELpUE0g',
#    'alias': 'la-virgen-de-las-nieves-philadelphia-3',
#    'name': 'La Virgen De Las Nieves',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2Emj_ZcaKS57L-IFyZe_yw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-virgen-de-las-nieves-philadelphia-3?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 37,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.9255887618641,
#     'longitude': -75.1592664420605},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '1839 S 8th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19148',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1839 S 8th St', 'Philadelphia, PA 19148']},
#    'phone': '+12154631059',
#    'display_phone': '(215) 463-1059',
#    'distance': 3296.005796870379},
#   {'id': '1N7RWvz2c_e640PsvnSc0A',
#    'alias': 'taco-riendo-philadelphia',
#    'name': 'Taco Riendo',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/tET2KN_-tcm5jDzM4y_TEA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taco-riendo-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 306,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.9715042114258,
#     'longitude': -75.1445083618164},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1301 N 5th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19122',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1301 N 5th St', 'Philadelphia, PA 19122']},
#    'phone': '+12152352294',
#    'display_phone': '(215) 235-2294',
#    'distance': 3010.051996241857},
#   {'id': 'CPnJ1-2f3gJk-bN2cH_u4Q',
#    'alias': 'restaurant-catracho-philadelphia',
#    'name': 'Restaurant Catracho',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/yas1-hFl40yCkpADgcFqMw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/restaurant-catracho-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 3,
#    'categories': [{'alias': 'honduran', 'title': 'Honduran'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.96191, 'longitude': -75.15493},
#    'transactions': ['delivery'],
#    'location': {'address1': '1011 Spring Garden St',
#     'address2': '',
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19123',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1011 Spring Garden St', 'Philadelphia, PA 19123']},
#    'phone': '+12675343758',
#    'display_phone': '(267) 534-3758',
#    'distance': 1657.9205585061527},
#   {'id': '1w40T5J6br425rMvpS1zgQ',
#    'alias': 'la-cocina-del-cafe-philadelphia',
#    'name': 'La Cocina del Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/BPQ5aa1G79z6qQO2iGPIPQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-cocina-del-cafe-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 24,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.931664, 'longitude': -75.168502},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '1500 S Broad St',
#     'address2': None,
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19146',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1500 S Broad St', 'Philadelphia, PA 19146']},
#    'phone': '+12152189899',
#    'display_phone': '(215) 218-9899',
#    'distance': 2469.4575959036792},
#   {'id': 'eXKblEHP3YJYU1Awz08hVw',
#    'alias': 'tacos-don-memo-philadelphia',
#    'name': 'Tacos Don Memo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hgNQXgp-aknGALG3h6LSXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tacos-don-memo-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 188,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'foodtrucks', 'title': 'Food Trucks'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.951988, 'longitude': -75.199123},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '270 S 38th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19104',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['270 S 38th St', 'Philadelphia, PA 19104']},
#    'phone': '+16105292039',
#    'display_phone': '(610) 529-2039',
#    'distance': 2388.1648948000675},
#   {'id': 'XQewVfTaosZ3U-4g_yH7Nw',
#    'alias': 'los-cuatro-soles-philadelphia',
#    'name': 'Los Cuatro Soles',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/dgXMRd4aGosR9bz8QguCkA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/los-cuatro-soles-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 33,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.9284853, 'longitude': -75.1730346679688},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1801 S Chadwick St',
#     'address2': '',
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19145',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1801 S Chadwick St', 'Philadelphia, PA 19145']},
#    'phone': '+12157551125',
#    'display_phone': '(215) 755-1125',
#    'distance': 2817.200456387998},
#   {'id': 'vf2dlfdopFlerxozUwgPDg',
#    'alias': 'dos-hermanos-tacos-philadelphia-2',
#    'name': 'Dos Hermanos Tacos',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/SWpIaGkyNOIAZkfUMAsKyA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dos-hermanos-tacos-philadelphia-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 65,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'foodtrucks', 'title': 'Food Trucks'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.9556116, 'longitude': -75.1904405},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '3342 Market St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19104',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['3342 Market St', 'Philadelphia, PA 19104']},
#    'phone': '+12676068356',
#    'display_phone': '(267) 606-8356',
#    'distance': 1667.2529533462882},
#   {'id': 'dvLSJwmlPAZioS3R5B3Wtw',
#    'alias': 'rosarios-pizzeria-philadelphia-5',
#    'name': 'Rosarios Pizzeria',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/cMR6ZIgQQ_XYrPrKH5qMyA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rosarios-pizzeria-philadelphia-5?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 201,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.93449, 'longitude': -75.16932},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1501 Wharton St',
#     'address2': None,
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19146',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1501 Wharton St', 'Philadelphia, PA 19146']},
#    'phone': '+12157552221',
#    'display_phone': '(215) 755-2221',
#    'distance': 2152.329017164707},
#   {'id': 'I5KZm-NnxYeEQsmp6nK5_w',
#    'alias': 'las-cazuelas-restaurant-byob-philadelphia',
#    'name': 'Las Cazuelas Restaurant BYOB',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/iPiC5nUKaLKOAcdfom0G-A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/las-cazuelas-restaurant-byob-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 330,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'latin', 'title': 'Latin American'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.9698623, 'longitude': -75.1439919},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '426 W Girard Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19123',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['426 W Girard Ave', 'Philadelphia, PA 19123']},
#    'phone': '+12155158785',
#    'display_phone': '(215) 515-8785',
#    'distance': 2928.4344854632477},
#   {'id': '42iv8H7NqN1f9fSz_NPf4g',
#    'alias': 'el-boom-catracho-philadelphia',
#    'name': 'El Boom Catracho',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/b0E3AHURJDcr5quTf4QNeg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-boom-catracho-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 3,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.935722, 'longitude': -75.168714},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '1438 Federal St',
#     'address2': None,
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19146',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1438 Federal St', 'Philadelphia, PA 19146']},
#    'phone': '+12676871650',
#    'display_phone': '(267) 687-1650',
#    'distance': 2008.831088311452},
#   {'id': '5S8GAXKwiu4K7gtd2z0Osw',
#    'alias': 'taqueria-la-prima-philadelphia',
#    'name': 'Taqueria La Prima',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-xRcSP7DBr7N4KUxR8FQLw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taqueria-la-prima-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 8,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.9360406750585,
#     'longitude': -75.1585772758083},
#    'transactions': [],
#    'location': {'address1': '1104 S 9th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19147',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1104 S 9th St', 'Philadelphia, PA 19147']},
#    'phone': '+12153395000',
#    'display_phone': '(215) 339-5000',
#    'distance': 2247.298969704482},
#   {'id': 'NBlB85ch_WCxYJ4fPWHxJA',
#    'alias': 'mexicali-philadelphia-2',
#    'name': 'MexiCali',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wjI9GiL1sZMKb-D41O1zCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mexicali-philadelphia-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 50,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'foodtrucks', 'title': 'Food Trucks'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.9549400729937,
#     'longitude': -75.2023024894409},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '38th & Walnut',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19104',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['38th & Walnut', 'Philadelphia, PA 19104']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2653.902417077355},
#   {'id': 'Duf-k9b1xpuK33BGCLWQ6w',
#    'alias': 'quetzally-philadelphia-3',
#    'name': 'Quetzally',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TvOPBBqENk0aoV2-XShccA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/quetzally-philadelphia-3?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 236,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.9416, 'longitude': -75.1631},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '1225 Fitzwater St',
#     'address2': None,
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19147',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1225 Fitzwater St', 'Philadelphia, PA 19147']},
#    'phone': '+12157352326',
#    'display_phone': '(215) 735-2326',
#    'distance': 1524.2739744093708},
#   {'id': 'baF2ZFEtsIo2A1k61x3QSw',
#    'alias': 'tio-flores-philadelphia',
#    'name': 'Tio Flores',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MK6UP0NV9CKTH1kY2dZCCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tio-flores-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 225,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.9440474063158,
#     'longitude': -75.1689760386944},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1600 South St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19146',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1600 South St', 'Philadelphia, PA 19146']},
#    'phone': '+12676872220',
#    'display_phone': '(267) 687-2220',
#    'distance': 1102.6570916264698},
#   {'id': '8aT-k89xn1eU-eJPgEBDlA',
#    'alias': 'taqueria-amor-philadelphia',
#    'name': 'Taqueria Amor',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/c-CD9yFqW58F0VkITYkd4Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taqueria-amor-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 17,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.025913, 'longitude': -75.225064},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '4410 Main St',
#     'address2': '',
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19127',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['4410 Main St', 'Philadelphia, PA 19127']},
#    'phone': '+12673315874',
#    'display_phone': '(267) 331-5874',
#    'distance': 9239.049898163861},
#   {'id': 'SVf23pjKERkedqCdWl6ECA',
#    'alias': 'teresas-mesa-philadelphia',
#    'name': "Teresa's Mesa",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_fJ1DAQpxliKxVmO5uDLpQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/teresas-mesa-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 67,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.93947, 'longitude': -75.14581},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '727 S 2nd St',
#     'address2': '',
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19147',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['727 S 2nd St', 'Philadelphia, PA 19147']},
#    'phone': '+12159821107',
#    'display_phone': '(215) 982-1107',
#    'distance': 2688.9654578107125}],
#  'total': 247,
#  'region': {'center': {'longitude': -75.17120361328125,
#    'latitude': 39.95378209544653}}}

# %%
#mexican
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'Philadelphia', 'categories':'mexican', 'offset':100 }
    
philadelphia_mexican3 = requests.get(API_HOST,headers=headers, params=params).json()

philadelphia_mexican3
# Out:
# {'businesses': [{'id': 'EhPoBZIeHCfrFPl3Rqcg-Q',
#    'alias': 'wrap-shack-philadelphia-2',
#    'name': 'Wrap Shack',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/d5DUtcrZgXKrJsiOdcFHTw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wrap-shack-philadelphia-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 77,
#    'categories': [{'alias': 'wraps', 'title': 'Wraps'},
#     {'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.9496367180907,
#     'longitude': -75.1587568223476},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '112 S 11th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19107',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['112 S 11th St', 'Philadelphia, PA 19107']},
#    'phone': '+12677582446',
#    'display_phone': '(267) 758-2446',
#    'distance': 1156.7735994493326},
#   {'id': '5ItgryJvadUrKVljjJ8l4g',
#    'alias': 'que-chula-es-puebla-philadelphia-2',
#    'name': 'Que Chula Es Puebla',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JQ4LfLdrJ5Js0itc_KzR-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/que-chula-es-puebla-philadelphia-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 244,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.9723663330078,
#     'longitude': -75.1391983032227},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1356 N 2nd St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19122',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1356 N 2nd St', 'Philadelphia, PA 19122']},
#    'phone': '+12152030404',
#    'display_phone': '(215) 203-0404',
#    'distance': 3422.376907942845},
#   {'id': '4HcQ-qSDjt1tgo6ZIAuoCw',
#    'alias': 'lorenzos-cabana-westville',
#    'name': 'Lorenzos Cabana',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/UogCzre4bYLSxuBXBjIGCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lorenzos-cabana-westville?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 29,
#    'categories': [{'alias': 'puertorican', 'title': 'Puerto Rican'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.8706901562271,
#     'longitude': -75.1267587017456},
#    'transactions': ['delivery'],
#    'location': {'address1': '191 Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'Westville',
#     'zip_code': '08093',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['191 Broadway', 'Westville, NJ 08093']},
#    'phone': '+18563492266',
#    'display_phone': '(856) 349-2266',
#    'distance': 9986.774030946211},
#   {'id': 'YOqnRHASr8ensibyqqFmSQ',
#    'alias': 'las-lomas-restaurant-philadelphia-2',
#    'name': 'Las Lomas Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/gAZbswYKHeJIycHmV9aCLg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/las-lomas-restaurant-philadelphia-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 10,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.934593, 'longitude': -75.158661},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '1167 S 9th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19147',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1167 S 9th St', 'Philadelphia, PA 19147']},
#    'phone': '+12155511808',
#    'display_phone': '(215) 551-1808',
#    'distance': 2388.430183171317},
#   {'id': 'qP954Yf1Qa5Ckkw4RU6w7A',
#    'alias': 'doho-taqueria-philadelphia',
#    'name': 'DOHO Taqueria',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/JaKz4pkpT1ugOCbC5K-ZYw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/doho-taqueria-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 10,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.04981, 'longitude': -75.184849},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '18 W Hortter',
#     'address2': None,
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19119',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['18 W Hortter', 'Philadelphia, PA 19119']},
#    'phone': '+12677850001',
#    'display_phone': '(267) 785-0001',
#    'distance': 10736.159171895179},
#   {'id': '-_0w82rV27l51N3ABkCI0A',
#    'alias': 'prima-pizza-taqueria-mexicana-philadelphia',
#    'name': 'Prima Pizza Taqueria Mexicana',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/PevlEnGeJNGPaob02kB2uA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/prima-pizza-taqueria-mexicana-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 118,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.93608, 'longitude': -75.15867},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '1104 S 9th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19147',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1104 S 9th St', 'Philadelphia, PA 19147']},
#    'phone': '+12153395000',
#    'display_phone': '(215) 339-5000',
#    'distance': 2240.002098768182},
#   {'id': 'gWV1k7XO9DSAodAlanESFA',
#    'alias': 'san-miguelito-mexican-cuisine-philadelphia',
#    'name': 'San Miguelito Mexican Cuisine',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/OE9xzK816mdxnCAjsPcEig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/san-miguelito-mexican-cuisine-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 58,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.9153366088867,
#     'longitude': -75.1584014892578},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '2654 S Sixth St',
#     'address2': None,
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19148',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['2654 S Sixth St', 'Philadelphia, PA 19148']},
#    'phone': '+12677738440',
#    'display_phone': '(267) 773-8440',
#    'distance': 4412.516751924709},
#   {'id': '6h7C53qLfwM7v3zKRqG0yA',
#    'alias': 'iztaccihuatl-philadelphia',
#    'name': 'Iztaccihuatl',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3ODxK7fkOQCGi4UJtOMZ6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/iztaccihuatl-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 126,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.9352, 'longitude': -75.15733},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '1122 S 8th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19147',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1122 S 8th St', 'Philadelphia, PA 19147']},
#    'phone': '+12154671005',
#    'display_phone': '(215) 467-1005',
#    'distance': 2383.6225220928277},
#   {'id': 'tIrRQBpPou-WfYc0XkLVfA',
#    'alias': 'sueno-philadelphia',
#    'name': 'Sueno',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BA4GQBbSdvNzlmzZzxksgA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sueno-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 14,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 39.9498246, 'longitude': -75.1604325},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '114 S 12th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19107',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['114 S 12th St', 'Philadelphia, PA 19107']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1018.142306330813},
#   {'id': 'Faog49Gh5vUudIhUqI9m2A',
#    'alias': 'la-canasta-mexican-food-philadelphia-3',
#    'name': 'La Canasta Mexican Food',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RV27M4zRFTcKr_TOaV4kZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-canasta-mexican-food-philadelphia-3?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 17,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.918652, 'longitude': -75.1539794},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '2341 S 4th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19148',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['2341 S 4th St', 'Philadelphia, PA 19148']},
#    'phone': '+12676394060',
#    'display_phone': '(267) 639-4060',
#    'distance': 4173.204728894522},
#   {'id': 'KZyyoQ_nxLMyzO4d_Ts-NQ',
#    'alias': 'tacos-el-rodeo-philadelphia',
#    'name': 'Tacos El Rodeo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8yBG2C47_i1Lv4n72jJN9Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tacos-el-rodeo-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 105,
#    'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.9368281572815,
#     'longitude': -75.1602197256065},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1000 Washington Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19147',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1000 Washington Ave', 'Philadelphia, PA 19147']},
#    'phone': '+12679973415',
#    'display_phone': '(267) 997-3415',
#    'distance': 2104.92459570983},
#   {'id': 'RAucBixPYsidSxjtl6VioQ',
#    'alias': 'mexican-post-express-philadelphia',
#    'name': 'Mexican Post Express',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/MlZmOURC1zVxfLMq9bRnXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mexican-post-express-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 50,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 39.956165986516, 'longitude': -75.166372970993},
#    'transactions': ['pickup'],
#    'price': '$$',
#    'location': {'address1': '1701 John F Kennedy Blvd',
#     'address2': None,
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19103',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1701 John F Kennedy Blvd', 'Philadelphia, PA 19103']},
#    'phone': '+12675193943',
#    'display_phone': '(267) 519-3943',
#    'distance': 489.69407556869095},
#   {'id': 'pBguunWb0Mu6hDxgZ6j1AQ',
#    'alias': 'guy-fieris-taco-joint-philadelphia-2',
#    'name': "Guy Fieri's Taco Joint",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kPcxBHJdZKYoud6vcVbPsw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/guy-fieris-taco-joint-philadelphia-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 1,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 39.909395, 'longitude': -75.164598},
#    'transactions': [],
#    'location': {'address1': '900 Packer Ave',
#     'address2': 'Live! Casino Hotel',
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19148',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['900 Packer Ave',
#      'Live! Casino Hotel',
#      'Philadelphia, PA 19148']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4989.553099737101},
#   {'id': 'tVxL-Ygzwp8NMuxwvNmWRA',
#    'alias': 'los-potrillos-philadelphia',
#    'name': 'Los Potrillos',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nSxvzcG8ev6LJRmo7nz0YQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/los-potrillos-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 17,
#    'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.012409, 'longitude': -75.112385},
#    'transactions': ['delivery'],
#    'location': {'address1': '4200 G St.',
#     'address2': '',
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19124',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['4200 G St.', 'Philadelphia, PA 19124']},
#    'phone': '+12675966092',
#    'display_phone': '(267) 596-6092',
#    'distance': 8222.796280681985},
#   {'id': 'kpx3OdkCgF0-xzYEDlj0ZA',
#    'alias': 'food-reyes-oaklyn',
#    'name': 'Food Reyes',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/food-reyes-oaklyn?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 1,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.9176017561626,
#     'longitude': -75.0967535376549},
#    'transactions': [],
#    'location': {'address1': '2021 Woodlynne Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Oaklyn',
#     'zip_code': '08107',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['2021 Woodlynne Ave', 'Oaklyn, NJ 08107']},
#    'phone': '+18562033877',
#    'display_phone': '(856) 203-3877',
#    'distance': 7515.155313893427},
#   {'id': '1UNorskttXSWuEcgzKzXcA',
#    'alias': 'xochitl-philadelphia',
#    'name': 'Xochitl',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/r5grV4VNp-MFZmxhQhqTow/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/xochitl-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 437,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.9428834, 'longitude': -75.1455958},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '408 S 2nd St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19147',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['408 S 2nd St', 'Philadelphia, PA 19147']},
#    'phone': '+12152387280',
#    'display_phone': '(215) 238-7280',
#    'distance': 2493.6009730344467},
#   {'id': 'XQ_wVhRayMJGQT9J_WANkw',
#    'alias': '4-seasons-grill-mexican-restaurant-philadelphia',
#    'name': '4 Seasons Grill Mexican Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/K4V56eQLqo4jb2IlWabMRA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/4-seasons-grill-mexican-restaurant-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 9,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.0027509, 'longitude': -75.1241868},
#    'transactions': ['delivery'],
#    'location': {'address1': '3503 B St',
#     'address2': 'Ste 4B',
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19134',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['3503 B St', 'Ste 4B', 'Philadelphia, PA 19134']},
#    'phone': '+12675190112',
#    'display_phone': '(267) 519-0112',
#    'distance': 6794.640867798149},
#   {'id': 'uoUZ8Wx7Aw7Nj6QIxaCjew',
#    'alias': 'the-avocado-mexican-grill-runnemede-2',
#    'name': 'The Avocado Mexican Grill',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zVd7T8FwNMpLyKbWlntjyA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-avocado-mexican-grill-runnemede-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 1,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.853926, 'longitude': -75.074964},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '603 N Black Horse Pike',
#     'address2': None,
#     'address3': '',
#     'city': 'Runnemede',
#     'zip_code': '08078',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['603 N Black Horse Pike', 'Runnemede, NJ 08078']},
#    'phone': '+18562193111',
#    'display_phone': '(856) 219-3111',
#    'distance': 13809.436859752035},
#   {'id': 'wOT99C7ZqRf8SIfd5sRVlQ',
#    'alias': 'taqueria-el-maguey-philadelphia',
#    'name': 'Taqueria El Maguey',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/42buYJxF0QqZuIvO8zIpcg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taqueria-el-maguey-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 73,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.9296999, 'longitude': -75.16168},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '1538 S 10th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19147',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1538 S 10th St', 'Philadelphia, PA 19147']},
#    'phone': '+12675283296',
#    'display_phone': '(267) 528-3296',
#    'distance': 2798.898915128437},
#   {'id': 'ehHQQflMgSUX5T3PFyjBWQ',
#    'alias': 'tortas-and-pizza-el-sabor-de-mi-tierra-philadelphia',
#    'name': 'Tortas & Pizza El Sabor De Mi Tierra',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/gcmzNppqv-6yjDdtdTttig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tortas-and-pizza-el-sabor-de-mi-tierra-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 33,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.9188, 'longitude': -75.15888},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '2413 S 7th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19148',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['2413 S 7th St', 'Philadelphia, PA 19148']},
#    'phone': '+12676871611',
#    'display_phone': '(267) 687-1611',
#    'distance': 4028.582176226137}],
#  'total': 247,
#  'region': {'center': {'longitude': -75.17120361328125,
#    'latitude': 39.95378209544653}}}

# %%
#mexican
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'Philadelphia', 'categories':'mexican', 'offset':150 }
    
philadelphia_mexican4 = requests.get(API_HOST,headers=headers, params=params).json()

philadelphia_mexican4
# Out:
# {'businesses': [{'id': 'qgF_Qvv6qzUd6OY2DgL-IA',
#    'alias': 'dimension-latin-grill-philadelphia',
#    'name': 'Dimension Latin Grill',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nVXueqWU0RECvHlFahrF2g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dimension-latin-grill-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 6,
#    'categories': [{'alias': 'puertorican', 'title': 'Puerto Rican'},
#     {'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'latin', 'title': 'Latin American'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.05262, 'longitude': -75.06522},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '7312 Castor Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19152',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['7312 Castor Ave', 'Philadelphia, PA 19152']},
#    'phone': '+12675382077',
#    'display_phone': '(267) 538-2077',
#    'distance': 14219.760729155569},
#   {'id': '7Y3RjSc99a88oTMEgvazoA',
#    'alias': 'qdoba-mexican-eats-philadelphia-2',
#    'name': 'QDOBA Mexican Eats',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/f1PTK-yLx66V4bBFmZgIPA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/qdoba-mexican-eats-philadelphia-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 88,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 39.9495796083864,
#     'longitude': -75.1672851247895},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '1528 Walnut St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19102',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1528 Walnut St', 'Philadelphia, PA 19102']},
#    'phone': '+12155468007',
#    'display_phone': '(215) 546-8007',
#    'distance': 574.3948228560486},
#   {'id': 'afsP-p_pr4ikrboB5MtUzQ',
#    'alias': 'los-compadres-philadelphia',
#    'name': 'Los Compadres',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/sc44-d4YcztvIihclNhryw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/los-compadres-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 12,
#    'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.9553865, 'longitude': -75.1910637},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '3300 Market St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19145',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['3300 Market St', 'Philadelphia, PA 19145']},
#    'phone': '+12675912084',
#    'display_phone': '(267) 591-2084',
#    'distance': 1702.184724260197},
#   {'id': 'YA6S248TPYRHmCkA77qcog',
#    'alias': 'jamaica-wings-upper-darby',
#    'name': 'Jamaica Wings',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GVSP-mS9QDOmsQ0RvNw3xw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jamaica-wings-upper-darby?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 26,
#    'categories': [{'alias': 'caribbean', 'title': 'Caribbean'},
#     {'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.96747, 'longitude': -75.29026},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '9000 W Chester Pike',
#     'address2': None,
#     'address3': '',
#     'city': 'Upper Darby',
#     'zip_code': '19082',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['9000 W Chester Pike', 'Upper Darby, PA 19082']},
#    'phone': '+16108397875',
#    'display_phone': '(610) 839-7875',
#    'distance': 10263.203982297102},
#   {'id': '6OmIGXQZPFbbWWlhxbRP8w',
#    'alias': 'el-buen-sazón-restaurante-guatemalan-and-mexican-grill-drexel-hill',
#    'name': 'El Buen sazón Restaurante guatemalan and Mexican grill',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/wrrhSWtxA1VcBUEa2YZaTA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-buen-saz%C3%B3n-restaurante-guatemalan-and-mexican-grill-drexel-hill?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 37,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.9445551302745,
#     'longitude': -75.2966022491455},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '3704 Garrett Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Drexel Hill',
#     'zip_code': '19026',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['3704 Garrett Rd', 'Drexel Hill, PA 19026']},
#    'phone': '+14844618841',
#    'display_phone': '(484) 461-8841',
#    'distance': 10738.54784373258},
#   {'id': 'SqR-SVD8otqLguw0rFUVvA',
#    'alias': 'la-tentacion-pizza-and-mexican-grill-westville',
#    'name': 'La Tentacion Pizza & Mexican Grill',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CpYM9B9vKhEyJI6lJ6VXBA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-tentacion-pizza-and-mexican-grill-westville?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 79,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'tex-mex', 'title': 'Tex-Mex'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.8638, 'longitude': -75.132076},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '831 Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'Westville',
#     'zip_code': '08093',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['831 Broadway', 'Westville, NJ 08093']},
#    'phone': '+18563492173',
#    'display_phone': '(856) 349-2173',
#    'distance': 10546.268782832296},
#   {'id': 'drLjIUWukR1O4A4S7h9FwQ',
#    'alias': 'los-chulos-pennsauken-township',
#    'name': 'Los Chulos',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hwzMNHW1THYTqFfDjbkZ3g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/los-chulos-pennsauken-township?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 21,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.9330688885964,
#     'longitude': -75.0652908906341},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '5245 Marlton Pike',
#     'address2': 'Unit D',
#     'address3': None,
#     'city': 'Pennsauken Township',
#     'zip_code': '08109',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['5245 Marlton Pike',
#      'Unit D',
#      'Pennsauken Township, NJ 08109']},
#    'phone': '+18569160001',
#    'display_phone': '(856) 916-0001',
#    'distance': 9318.259926503371},
#   {'id': 'QWNPbCTS2rPvF6uiTl4P-A',
#    'alias': 'el-toro-lounge-philadelphia',
#    'name': 'El Toro Lounge',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/56ocofwrIzX_EasQMkJgwg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-toro-lounge-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 2,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.9694999, 'longitude': -75.21182},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '898 Belmont Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19104',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['898 Belmont Ave', 'Philadelphia, PA 19104']},
#    'phone': '+12154771863',
#    'display_phone': '(215) 477-1863',
#    'distance': 3872.605302278425},
#   {'id': 'eOEjkrby-5R2cdYqzXiBNQ',
#    'alias': 'los-tacos-philadelphia',
#    'name': 'Los Tacos',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/LBdJqsHdf1VzExzix2vXRw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/los-tacos-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 34,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.029, 'longitude': -75.1324099},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '5104 N 5th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19120',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['5104 N 5th St', 'Philadelphia, PA 19120']},
#    'phone': '+12159105788',
#    'display_phone': '(215) 910-5788',
#    'distance': 8992.51097103209},
#   {'id': 'zBMVKdNxp8AQLIPnaIaDxw',
#    'alias': 'panadería-mexicana-el-trebol-philadelphia',
#    'name': 'Panadería Mexicana El Trebol',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ahTnHUEn6_V5Vfb3U_7ONw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/panader%C3%ADa-mexicana-el-trebol-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 4,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.02854, 'longitude': -75.1325899},
#    'transactions': [],
#    'location': {'address1': '5052 N 5th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19120',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['5052 N 5th St', 'Philadelphia, PA 19120']},
#    'phone': '+12677704212',
#    'display_phone': '(267) 770-4212',
#    'distance': 8942.25653769482},
#   {'id': '9YvxONmuEP-IXIFRrMCgSA',
#    'alias': 'sabor-puebla-taqueria-and-cafe-camden',
#    'name': 'Sabor Puebla Taqueria & Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fvrac7wAtaV6nXVCLa7enA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sabor-puebla-taqueria-and-cafe-camden?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 1,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.92304, 'longitude': -75.1056},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '1715 Mount Ephraim Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Camden',
#     'zip_code': '08104',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['1715 Mount Ephraim Ave', 'Camden, NJ 08104']},
#    'phone': '+18563794698',
#    'display_phone': '(856) 379-4698',
#    'distance': 6584.4773274605795},
#   {'id': '7YZvdYY9ql6cf3OBdxZvsw',
#    'alias': 'jalapeños-grill-and-bar-gloucester-city',
#    'name': "Jalapeños Grill &' Bar",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IcJMBxmZ1kinNdCh1zZ0OA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jalape%C3%B1os-grill-and-bar-gloucester-city?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 17,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.89393, 'longitude': -75.12715},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '314 Jersey Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'Gloucester City',
#     'zip_code': '08030',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['314 Jersey Ave', 'Gloucester City, NJ 08030']},
#    'phone': '+18564561624',
#    'display_phone': '(856) 456-1624',
#    'distance': 7617.083323343282},
#   {'id': 'ntacXTzkfdY4ptnVVsSYNg',
#    'alias': 'la-casa-del-buen-gusto-philadelphia-2',
#    'name': 'La Casa Del Buen Gusto',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-casa-del-buen-gusto-philadelphia-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 1,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 1.0,
#    'coordinates': {'latitude': 39.99729, 'longitude': -75.11746},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '657 E Allegheny Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19134',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['657 E Allegheny Ave', 'Philadelphia, PA 19134']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 6658.429509326676},
#   {'id': 'iaZavx63kGEoiqAmMuOSew',
#    'alias': 'las-rancheritas-philadelphia',
#    'name': 'Las Rancheritas',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/HeCdrWyuGcHrxMGnO1qUtQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/las-rancheritas-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 7,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.0118598937988,
#     'longitude': -75.1361312866211},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '3956 N 5th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19140',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['3956 N 5th St', 'Philadelphia, PA 19140']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 7115.8341618501},
#   {'id': '7k9qGQyytbGxpJTnwxK6Xg',
#    'alias': 'qdoba-mexican-eats-philadelphia',
#    'name': 'QDOBA Mexican Eats',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/LQez3BoH_uI7AQpUmpuX6Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/qdoba-mexican-eats-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 40,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 39.9785404, 'longitude': -75.158377},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1600 N Broad St',
#     'address2': 'Ste 12',
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19123',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1600 N Broad St',
#      'Ste 12',
#      'Philadelphia, PA 19123']},
#    'phone': '+12157634090',
#    'display_phone': '(215) 763-4090',
#    'distance': 2962.073443759394},
#   {'id': 'td_BI5T5qP01T5QfD4j3Sg',
#    'alias': 'el-bochinche-restaurante-philadelphia',
#    'name': 'El Bochinche Restaurante',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/f9kw2fZSJmm5Bo1FznAM4g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-bochinche-restaurante-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 14,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'colombian', 'title': 'Colombian'},
#     {'alias': 'empanadas', 'title': 'Empanadas'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.027, 'longitude': -75.13302},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '4940 N 5th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19120',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['4940 N 5th St', 'Philadelphia, PA 19120']},
#    'phone': '+12153290861',
#    'display_phone': '(215) 329-0861',
#    'distance': 8772.083044134488},
#   {'id': '6NEUgs0UGi-sHKYFH7T-bA',
#    'alias': 'taqueria-la-calpeña-camden-2',
#    'name': 'Taqueria La Calpeña',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3U7LbFetfKcZ0E_7jsuNoA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taqueria-la-calpe%C3%B1a-camden-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 11,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.948844909668, 'longitude': -75.088264465332},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '300 N 27th St',
#     'address2': None,
#     'address3': None,
#     'city': 'Camden',
#     'zip_code': '08105',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['300 N 27th St', 'Camden, NJ 08105']},
#    'phone': '+18569636285',
#    'display_phone': '(856) 963-6285',
#    'distance': 7093.073015519134},
#   {'id': 'dDFcdlDsBrXa_zZYBhUV9g',
#    'alias': 'agave-bellmawr',
#    'name': 'Agave',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3RGBKxjcap-x3roJtrJ63g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/agave-bellmawr?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 44,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.87547, 'longitude': -75.105686},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '831 W Browning Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Bellmawr',
#     'zip_code': '08031',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['831 W Browning Rd', 'Bellmawr, NJ 08031']},
#    'phone': '+18569337880',
#    'display_phone': '(856) 933-7880',
#    'distance': 10346.529468998977},
#   {'id': 'rU3wkbUX4YJfNn-tkmi2pQ',
#    'alias': 'ojalá-chicken-and-tacos-camden',
#    'name': 'Ojalá chicken & Tacos',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/coLH1w0aTWeUiC3lq_IcLw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ojal%C3%A1-chicken-and-tacos-camden?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 1,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 1.0,
#    'coordinates': {'latitude': 39.9235796487, 'longitude': -75.104958742},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '1701 Mt Ephraim Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Camden',
#     'zip_code': '08104',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['1701 Mt Ephraim Ave', 'Camden, NJ 08104']},
#    'phone': '+18567565252',
#    'display_phone': '(856) 756-5252',
#    'distance': 6570.870251351468},
#   {'id': 'DWVh69pl7bV3tBT0UV1stA',
#    'alias': 'central-taco-and-tequila-haddon-township',
#    'name': 'Central Taco And Tequila',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Ehne8UovtpG94md9auvY2A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/central-taco-and-tequila-haddon-township?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 225,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.90571856, 'longitude': -75.04368026},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '350 Haddon Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Haddon Township',
#     'zip_code': '08033',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['350 Haddon Ave', 'Haddon Township, NJ 08033']},
#    'phone': '+18568336800',
#    'display_phone': '(856) 833-6800',
#    'distance': 12116.04303310221}],
#  'total': 247,
#  'region': {'center': {'longitude': -75.17120361328125,
#    'latitude': 39.95378209544653}}}

# %%
#mexican
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'Philadelphia', 'categories':'mexican', 'offset':200 }
    
philadelphia_mexican5 = requests.get(API_HOST,headers=headers, params=params).json()

philadelphia_mexican5
# Out:
# {'businesses': [{'id': '0Lsuuvz1_qdspiwBehdszg',
#    'alias': 'las-cabanas-camden',
#    'name': 'Las Cabanas',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5U-mAB6dm1JbRulEu75CpA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/las-cabanas-camden?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 8,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.9470209170186,
#     'longitude': -75.0803300365806},
#    'transactions': ['delivery'],
#    'location': {'address1': '3038 Federal St',
#     'address2': '',
#     'address3': '',
#     'city': 'Camden',
#     'zip_code': '08105',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['3038 Federal St', 'Camden, NJ 08105']},
#    'phone': '+18563617302',
#    'display_phone': '(856) 361-7302',
#    'distance': 7782.642894768736},
#   {'id': 'dSKQunGYhaf7eCrskfrVzQ',
#    'alias': 'luckys-mexican-spot-food-truck-philadelphia',
#    'name': "Lucky's Mexican Spot Food Truck",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/oDAjlZ7FZGm2dDZnhIGyVQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/luckys-mexican-spot-food-truck-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 19,
#    'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 39.951048, 'longitude': -75.197272242022},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '37th And Spruce St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19104',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['37th And Spruce St', 'Philadelphia, PA 19104']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2242.7775665038225},
#   {'id': 'sdffBAE2Hn7Wn8e2hMMJyA',
#    'alias': 'los-jalapeños-bar-and-grill-oaklyn',
#    'name': 'Los Jalapeños Bar & Grill',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/FATXTjqoNV90S-kJr-zoTQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/los-jalape%C3%B1os-bar-and-grill-oaklyn?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 19,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.90007, 'longitude': -75.07567},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '900 White Horse Pike',
#     'address2': '',
#     'address3': None,
#     'city': 'Oaklyn',
#     'zip_code': '08107',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['900 White Horse Pike', 'Oaklyn, NJ 08107']},
#    'phone': '+18568331146',
#    'display_phone': '(856) 833-1146',
#    'distance': 10105.63267218618},
#   {'id': '3EXrZSNJd7RlEHYWP6Xsuw',
#    'alias': 'san-pedro-tierra-mexican-bellmawr',
#    'name': 'San Pedro Tierra Mexican',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/faMT3z0R9fhRbuquSjL3PA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/san-pedro-tierra-mexican-bellmawr?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 40,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.8652763366699,
#     'longitude': -75.0784683227539},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '115 S Black Horse Pike',
#     'address2': '',
#     'address3': '',
#     'city': 'Bellmawr',
#     'zip_code': '08031',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['115 S Black Horse Pike', 'Bellmawr, NJ 08031']},
#    'phone': '+18569312072',
#    'display_phone': '(856) 931-2072',
#    'distance': 12617.9817182414},
#   {'id': 'VgvLm66ssM_08FXVXup5jA',
#    'alias': 'la-tez-byob-havertown-2',
#    'name': 'La Tez BYOB',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-tez-byob-havertown-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 1,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.9786987304688,
#     'longitude': -75.3038635253906},
#    'transactions': [],
#    'location': {'address1': '5 Brookline Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Havertown',
#     'zip_code': '19083',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['5 Brookline Blvd', 'Havertown, PA 19083']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 11641.590671879558},
#   {'id': 'HoxAwFKunUzqscWtOnA9sg',
#    'alias': 'little-jalapeno-barrington-2',
#    'name': 'Little Jalapeno',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/vdZxq1vxkiH7U-xf_WGkvg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/little-jalapeno-barrington-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 13,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.872343, 'longitude': -75.050674},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '118 Clements Bridge Rd',
#     'address2': None,
#     'address3': None,
#     'city': 'Barrington',
#     'zip_code': '08007',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['118 Clements Bridge Rd', 'Barrington, NJ 08007']},
#    'phone': '+18565322270',
#    'display_phone': '(856) 532-2270',
#    'distance': 13696.887916037907},
#   {'id': 'DIGW-yEmaQeEq_SJKvbZyg',
#    'alias': 'fiesta-acapulco-philadelphia',
#    'name': 'Fiesta Acapulco',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/wH8OarsOeKQwn_Uxu4IJsQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fiesta-acapulco-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 50,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 39.93575, 'longitude': -75.15873},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '1122 S 9th St',
#     'address2': None,
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19147',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1122 S 9th St', 'Philadelphia, PA 19147']},
#    'phone': '+12155510850',
#    'display_phone': '(215) 551-0850',
#    'distance': 2269.8100090917987},
#   {'id': 'uATZa6GHTkqQ1a7CckHMFg',
#    'alias': 'guapos-tacos-philadelphia-3',
#    'name': 'Guapos Tacos',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qDuu8e7TbC2RNP6GR-yXLg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/guapos-tacos-philadelphia-3?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 1,
#    'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 39.9541859225867,
#     'longitude': -75.1664185523987},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19103',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['Philadelphia, PA 19103']},
#    'phone': '+16264823561',
#    'display_phone': '(626) 482-3561',
#    'distance': 410.33115033601274},
#   {'id': 'tIrKQRlAft3cytlm4khnKQ',
#    'alias': 'taco-bell-philadelphia-19',
#    'name': 'Taco Bell',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/mkzMTqUPOnmdcIYE-rq2Sg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taco-bell-philadelphia-19?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 9,
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 1.5,
#    'coordinates': {'latitude': 39.99957, 'longitude': -75.15348},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '3032 North Broad St.',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19132',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['3032 North Broad St.', 'Philadelphia, PA 19132']},
#    'phone': '+12152255553',
#    'display_phone': '(215) 225-5553',
#    'distance': 5310.6375830379875},
#   {'id': 'RYr5LkmPx9N1ZkiYkDe3Tw',
#    'alias': 'distrito-taco-truck-philadelphia-2',
#    'name': 'Distrito Taco Truck',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/OUPTnfz8TyB34IdBUPgOkg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/distrito-taco-truck-philadelphia-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 58,
#    'categories': [{'alias': 'foodstands', 'title': 'Food Stands'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 39.959695, 'longitude': -75.196819},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19104',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['Philadelphia, PA 19104']},
#    'phone': '+12672847979',
#    'display_phone': '(267) 284-7979',
#    'distance': 2280.154428729881},
#   {'id': 'YFZEUO2lipPqQdWGqPWUew',
#    'alias': 'taco-bell-philadelphia-17',
#    'name': 'Taco Bell',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/EXCMfGsG9AaEMUzaW27q_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taco-bell-philadelphia-17?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 15,
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.993535, 'longitude': -75.096423},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '3619 Aramingo Avenue',
#     'address2': None,
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19134',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['3619 Aramingo Avenue', 'Philadelphia, PA 19134']},
#    'phone': '+12159925440',
#    'display_phone': '(215) 992-5440',
#    'distance': 7755.330996894056},
#   {'id': 'tm8zmRk57XQNd8NyFvim_g',
#    'alias': 'annas-lunch-truck-philadelphia',
#    'name': "Anna's Lunch Truck",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/cL2pP2xttfDgSJWn0d7V0w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/annas-lunch-truck-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 1,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'mideastern', 'title': 'Middle Eastern'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 39.9775657653809,
#     'longitude': -75.1460571289062},
#    'transactions': [],
#    'location': {'address1': '12th & Berks',
#     'address2': '',
#     'address3': 'In Front Of Temple University Biology Dept',
#     'city': 'Philadelphia',
#     'zip_code': '19122',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['12th & Berks',
#      'In Front Of Temple University Biology Dept',
#      'Philadelphia, PA 19122']},
#    'phone': '+12157697469',
#    'display_phone': '(215) 769-7469',
#    'distance': 3420.976185204028},
#   {'id': 'dgGuvdysSuWOv2dKqZTbVA',
#    'alias': 'chipotle-mexican-grill-philadelphia-2',
#    'name': 'Chipotle Mexican Grill',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/aKgcOK2Rsf6BsZJILJTaTg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chipotle-mexican-grill-philadelphia-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 154,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.0075055544655,
#     'longitude': -75.2122489840441},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '4030 City Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19131',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['4030 City Ave', 'Philadelphia, PA 19131']},
#    'phone': '+12158780452',
#    'display_phone': '(215) 878-0452',
#    'distance': 6922.183287838643},
#   {'id': 'lBHZc-fGzL8fRWREy7VlZA',
#    'alias': 'taco-bell-philadelphia-26',
#    'name': 'Taco Bell',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/s3sSRto1zXhJtwEv6aFYBQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taco-bell-philadelphia-26?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 16,
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 1.0,
#    'coordinates': {'latitude': 39.9221, 'longitude': -75.18726},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '2422 W Passyunk Avenue',
#     'address2': None,
#     'address3': None,
#     'city': 'Philadelphia',
#     'zip_code': '19145',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['2422 W Passyunk Avenue', 'Philadelphia, PA 19145']},
#    'phone': '+12154658194',
#    'display_phone': '(215) 465-8194',
#    'distance': 3779.5075823906186},
#   {'id': 'y3etNrQwVBp3iw8wZR8JCQ',
#    'alias': 'tienda-y-taqueria-el-pueblito-upper-darby',
#    'name': 'Tienda Y Taqueria El Pueblito',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/3pRPjB0AYZfvR9GXEDhRmg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tienda-y-taqueria-el-pueblito-upper-darby?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 4,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.95496, 'longitude': -75.25877},
#    'transactions': ['delivery'],
#    'location': {'address1': '304 S 69th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Upper Darby',
#     'zip_code': '19082',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['304 S 69th St', 'Upper Darby, PA 19082']},
#    'phone': '+14844664629',
#    'display_phone': '(484) 466-4629',
#    'distance': 7452.85870289209},
#   {'id': 'tGzu2uZYz0Yqh5F0H9jmFQ',
#    'alias': 'currito-philadelphia-8',
#    'name': 'Currito',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ONI7lYsboCYD73tzTeWYGA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/currito-philadelphia-8?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 6,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.8766558821088,
#     'longitude': -75.2399649508957},
#    'transactions': [],
#    'location': {'address1': '8000 Essington Ave',
#     'address2': '',
#     'address3': 'Terminal A',
#     'city': 'Philadelphia',
#     'zip_code': '19153',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['8000 Essington Ave',
#      'Terminal A',
#      'Philadelphia, PA 19153']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 10389.376890374471},
#   {'id': '2bax-LSv7GZGzRDxVe7AmQ',
#    'alias': 'el-paraiso-restaurant-camden',
#    'name': 'El Paraiso Restaurant',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-paraiso-restaurant-camden?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 2,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 39.9124405, 'longitude': -75.1129356},
#    'transactions': ['delivery'],
#    'location': {'address1': '744 Morgan St',
#     'address2': '',
#     'address3': '',
#     'city': 'Camden',
#     'zip_code': '08104',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['744 Morgan St', 'Camden, NJ 08104']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 6788.1173777088925},
#   {'id': '69k7MF2-nXq-tNNHrJYONw',
#    'alias': 'chipotle-mexican-grill-philadelphia-8',
#    'name': 'Chipotle Mexican Grill',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ZMTLUCS6q0tMQQUN1PPCXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chipotle-mexican-grill-philadelphia-8?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 137,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 39.954101, 'longitude': -75.200795},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '3925 Walnut St',
#     'address2': 'Ste 128',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19104',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['3925 Walnut St',
#      'Ste 128',
#      'Philadelphia, PA 19104']},
#    'phone': '+12152220632',
#    'display_phone': '(215) 222-0632',
#    'distance': 2522.5477341062706},
#   {'id': 'YC5nBPPvrl2qF1vhrPHFhQ',
#    'alias': 'el-huarache-azteca-philadelphia',
#    'name': 'El Huarache Azteca',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/47Xuiwsv_YsJIm7Px_mNWQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-huarache-azteca-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 6,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 39.9352, 'longitude': -75.15733},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '1122-1124 S 8th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Philadelphia',
#     'zip_code': '19147',
#     'country': 'US',
#     'state': 'PA',
#     'display_address': ['1122-1124 S 8th St', 'Philadelphia, PA 19147']},
#    'phone': '+12157751176',
#    'display_phone': '(215) 775-1176',
#    'distance': 2383.6225220928277},
#   {'id': 'xtWIORPp-HG2LWtz5jQtiA',
#    'alias': 'tortilla-press-collingswood-2',
#    'name': 'Tortilla Press',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pl4BpV1aPjLsLcEcQFRRnw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tortilla-press-collingswood-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw',
#    'review_count': 310,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 39.91631, 'longitude': -75.0686},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '703 Haddon Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Collingswood',
#     'zip_code': '08108',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['703 Haddon Ave', 'Collingswood, NJ 08108']},
#    'phone': '+18568693345',
#    'display_phone': '(856) 869-3345',
#    'distance': 9692.135397380294}],
#  'total': 247,
#  'region': {'center': {'longitude': -75.17120361328125,
#    'latitude': 39.95378209544653}}}

# %%
#new american
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'Philadelphia', 'categories':'newamerican' }
    
philadelphia_new_american1 = requests.get(API_HOST,headers=headers, params=params).json()

philly_ethnic_totals.loc[8, 'City'] = 'Philadelphia'
philly_ethnic_totals.loc[8, 'Ethnicity'] = 'New American'
philly_ethnic_totals.loc[8, 'Total Restaurants'] = (philadelphia_new_american["total"])
philly_ethnic_totals
# Out:
#             City     Ethnicity Total Restaurants
# 0   Philadelphia       Chinese               414
# 1   Philadelphia        French                24
# 2   Philadelphia         Greek                21
# 3   Philadelphia        Indian                62
# 4   Philadelphia       Italian               284
# 5   Philadelphia      Japanese               124
# 6   Philadelphia     Brazilian                10
# 7   Philadelphia       Mexican               247
# 8   Philadelphia  New American               291
# 9   Philadelphia     Soul Food                63
# 10  Philadelphia          Thai                62

# %%
#new american
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'Philadelphia', 'categories':'newamerican', 'offset':50 }
    
philadelphia_new_american2 = requests.get(API_HOST,headers=headers, params=params).json()

# %%
#new american
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'Philadelphia', 'categories':'newamerican', 'offset':100 }
    
philadelphia_new_american3 = requests.get(API_HOST,headers=headers, params=params).json()

# %%
#new american
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'Philadelphia', 'categories':'newamerican', 'offset':150 }
    
philadelphia_new_american4 = requests.get(API_HOST,headers=headers, params=params).json()

# %%
#new american
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'Philadelphia', 'categories':'newamerican', 'offset':200 }
    
philadelphia_new_american5 = requests.get(API_HOST,headers=headers, params=params).json()

# %%
#new american
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'Philadelphia', 'categories':'newamerican', 'offset':250 }
    
philadelphia_new_american6 = requests.get(API_HOST,headers=headers, params=params).json()

# %%
#soul food
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'Philadelphia', 'categories':'soulfood' }
    
philadelphia_soul_food1 = requests.get(API_HOST,headers=headers, params=params).json()

philly_ethnic_totals.loc[9, 'City'] = 'Philadelphia'
philly_ethnic_totals.loc[9, 'Ethnicity'] = 'Soul Food'
philly_ethnic_totals.loc[9, 'Total Restaurants'] = (philadelphia_soul_food["total"])
philly_ethnic_totals
# Out:
#             City     Ethnicity Total Restaurants
# 0   Philadelphia       Chinese               414
# 1   Philadelphia        French                25
# 2   Philadelphia         Greek                21
# 3   Philadelphia        Indian                62
# 4   Philadelphia       Italian               283
# 5   Philadelphia      Japanese               124
# 6   Philadelphia     Brazilian                10
# 7   Philadelphia       Mexican               247
# 8   Philadelphia  New American               291
# 9   Philadelphia     Soul Food                63
# 10  Philadelphia          Thai                62

# %%
#soul food
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'Philadelphia', 'categories':'soulfood', 'offset':50 }
    
philadelphia_soul_food2 = requests.get(API_HOST,headers=headers, params=params).json()

# %%
#thai
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'Philadelphia', 'categories':'thai' }
    
philadelphia_thai1 = requests.get(API_HOST,headers=headers, params=params).json()

philly_ethnic_totals.loc[10, 'City'] = 'Philadelphia'
philly_ethnic_totals.loc[10, 'Ethnicity'] = 'Thai'
philly_ethnic_totals.loc[10, 'Total Restaurants'] = (philadelphia_thai["total"])
philly_ethnic_totals
# Out:
#             City     Ethnicity Total Restaurants
# 0   Philadelphia       Chinese               414
# 1   Philadelphia        French                24
# 2   Philadelphia         Greek                21
# 3   Philadelphia        Indian                62
# 4   Philadelphia       Italian               284
# 5   Philadelphia      Japanese               124
# 6   Philadelphia     Brazilian                10
# 7   Philadelphia       Mexican               247
# 8   Philadelphia  New American               291
# 9   Philadelphia     Soul Food                63
# 10  Philadelphia          Thai                62

# %%
#thai
API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'Philadelphia', 'categories':'thai', 'offset':50 }
    
philadelphia_thai2 = requests.get(API_HOST,headers=headers, params=params).json()

# %%
philly_responses = [philadelphia_chinese1, 
                    philadelphia_chinese2, 
                    philadelphia_chinese3, 
                    philadelphia_chinese4,
                    philadelphia_chinese5, 
                    philadelphia_chinese6,
                    philadelphia_chinese7,
                    philadelphia_chinese8,
                    philadelphia_chinese9,
                    philadelphia_french,
                    philadelphia_greek,
                    philadelphia_indian1
                   japanese1_response, 
                   japanese2_response, 
                   brazilian_response,
                   thai_response, 
                   soulfood_response, 
                   newamerican1_response,
                   newamerican2_response,
                   newamerican3_response, 
                   newamerican4_response,
                   mexican1_response,
                   mexican2_response,
                    mexican3_response,
               mexican4_response,
               mexican5_response, 
               mexican6_response,
               mexican7_response,
               mexican8_response,
               mexican9_response,
               mexican10_response, 
               mexican11_response]
#dallas_yelp

# %%
philly_ethnic_totals.to_csv('../Output/philly_extract_totals.csv')
