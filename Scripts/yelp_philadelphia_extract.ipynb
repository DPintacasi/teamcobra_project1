# %%
#import dependencies

import requests
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import gmaps
import os 
import pprint
import urllib

#import yelp_key
from config import yelp_key

# %%
#read in zipcode CSVs

philadelphia_zips = pd.read_csv("../Resources/philadelphia_zipcodes.csv")

atlanta_zips = pd.read_csv("../Resources/atlanta_zipcodes.csv")

dallas_zips = pd.read_csv("../Resources/dallas_zipcodes.csv")

indianapolis_zips = pd.read_csv("../Resources/indianapolis_zipcodes.csv")

seattle_zips = pd.read_csv("../Resources/seattle_zipcodes.csv")

# %%
#clean zip codes of url reference at bottom
philadelphia_zips.drop(philadelphia_zips.tail(1).index,inplace=True)
atlanta_zips.drop(atlanta_zips.tail(1).index,inplace=True)
dallas_zips.drop(dallas_zips.tail(1).index,inplace=True)
indianapolis_zips.drop(indianapolis_zips.tail(1).index,inplace=True)
seattle_zips.drop(seattle_zips.tail(1).index,inplace=True)


#check that this worked
philadelphia_zips.tail()
# Out:
#    Philadelphia
# 43        19150
# 44        19151
# 45        19152
# 46        19153
# 47        19154

# %%
# set up additional columns to hold information - philadelphia
philadelphia_zips['name'] = ""
philadelphia_zips['ethnicity'] = ""
philadelphia_zips['price level'] = ""
philadelphia_zips['service type'] = ""
philadelphia_zips['rating'] = ""


philly_zips = [zips for zips in philadelphia_zips['Philadelphia'] ]

# %%
#read in ethnicites csv
restaurant_ethnicities = pd.read_csv("../Resources/rest_enthinicity.csv")
restaurant_ethnicities.head()
# Out:
#   ethnicity
# 0   chinese
# 1    french
# 2     greek
# 3    indian
# 4   italian

# %%
#starting call for philadelphia

#query url needs to ultimately be GET https://api.yelp.com/v3/businesses/search?term=[ethnicity]&[latitude=37.786882&longitude=-122.399972]

philly_coords = "39.952583, -75.165222"
philly_zips = [zips for zips in philadelphia_zips['Philadelphia'] ]
restaurant_ethnic = [ethnicity for ethnicity in restaurant_ethnicities['ethnicity'] ]

API_HOST = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_key}
params={'term':'restaurants','location':'Philadelphia', 'alias':restaurant_ethnic}
    
response = requests.get(API_HOST, params=params, headers=headers).json()

print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "businesses": [
#         {
#             "alias": "barbuzzo-philadelphia",
#             "categories": [
#                 {
#                     "alias": "mediterranean",
#                     "title": "Mediterranean"
#                 },
#                 {
#                     "alias": "pizza",
#                     "title": "Pizza"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 39.94999,
#                 "longitude": -75.16216
#             },
#             "display_phone": "(215) 546-9300",
#             "distance": 877.931789849032,
#             "id": "6ajnOk0GcY9xbb5Ocaw8Gw",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/88mJSIDPi3JUsCK2FsVJqg/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "110 S 13th St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Philadelphia",
#                 "country": "US",
#                 "display_address": [
#                     "110 S 13th St",
#                     "Philadelphia, PA 19107"
#                 ],
#                 "state": "PA",
#                 "zip_code": "19107"
#             },
#             "name": "Barbuzzo",
#             "phone": "+12155469300",
#             "price": "$$",
#             "rating": 4.5,
#             "review_count": 2754,
#             "transactions": [
#                 "delivery",
#                 "pickup"
#             ],
#             "url": "https://www.yelp.com/biz/barbuzzo-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw"
#         },
#         {
#             "alias": "talulas-garden-philadelphia",
#             "categories": [
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 39.9473272217862,
#                 "longitude": -75.1535421779099
#             },
#             "display_phone": "(215) 592-7787",
#             "distance": 1667.8342649488502,
#             "id": "i_FWONQD1ZBqrNE2b-M5Ug",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/cv85EJnXUy97zoo5jWBCUg/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "210 W Washington Sq",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Philadelphia",
#                 "country": "US",
#                 "display_address": [
#                     "210 W Washington Sq",
#                     "Philadelphia, PA 19106"
#                 ],
#                 "state": "PA",
#                 "zip_code": "19106"
#             },
#             "name": "Talula's Garden",
#             "phone": "+12155927787",
#             "price": "$$$",
#             "rating": 4.5,
#             "review_count": 1792,
#             "transactions": [
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/talulas-garden-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw"
#         },
#         {
#             "alias": "the-dandelion-philadelphia",
#             "categories": [
#                 {
#                     "alias": "gastropubs",
#                     "title": "Gastropubs"
#                 },
#                 {
#                     "alias": "british",
#                     "title": "British"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 39.951004,
#                 "longitude": -75.170636
#             },
#             "display_phone": "(215) 558-2500",
#             "distance": 312.6758272785155,
#             "id": "8pqdJjefYq-a9IBSJJmKwA",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/IszoOQovGzgkCvJXFJEfWA/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "124 S 18th St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Philadelphia",
#                 "country": "US",
#                 "display_address": [
#                     "124 S 18th St",
#                     "Philadelphia, PA 19103"
#                 ],
#                 "state": "PA",
#                 "zip_code": "19103"
#             },
#             "name": "The Dandelion",
#             "phone": "+12155582500",
#             "price": "$$",
#             "rating": 4.0,
#             "review_count": 2366,
#             "transactions": [
#                 "delivery",
#                 "pickup"
#             ],
#             "url": "https://www.yelp.com/biz/the-dandelion-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw"
#         },
#         {
#             "alias": "zahav-philadelphia",
#             "categories": [
#                 {
#                     "alias": "mideastern",
#                     "title": "Middle Eastern"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 39.9462611465167,
#                 "longitude": -75.1451350778608
#             },
#             "display_phone": "(215) 625-8800",
#             "distance": 2374.303399662379,
#             "id": "ctHjyadbDQAtUFfkcAFEHw",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/iuZHAsd1P9GJsWhjNaV6xQ/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "237 St James Pl",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Philadelphia",
#                 "country": "US",
#                 "display_address": [
#                     "237 St James Pl",
#                     "Philadelphia, PA 19106"
#                 ],
#                 "state": "PA",
#                 "zip_code": "19106"
#             },
#             "name": "Zahav",
#             "phone": "+12156258800",
#             "price": "$$$",
#             "rating": 4.5,
#             "review_count": 2954,
#             "transactions": [
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/zahav-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw"
#         },
#         {
#             "alias": "harpers-garden-philadelphia",
#             "categories": [
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 },
#                 {
#                     "alias": "tapasmallplates",
#                     "title": "Tapas/Small Plates"
#                 },
#                 {
#                     "alias": "cocktailbars",
#                     "title": "Cocktail Bars"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 39.9523171,
#                 "longitude": -75.1700175
#             },
#             "display_phone": "(267) 886-8552",
#             "distance": 190.03850055789107,
#             "id": "v45E6gg6MrAziTepkiWByA",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/tMjdDPnmhJsZFby1KTuLQQ/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "31 S 18th St",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Philadelphia",
#                 "country": "US",
#                 "display_address": [
#                     "31 S 18th St",
#                     "Philadelphia, PA 19103"
#                 ],
#                 "state": "PA",
#                 "zip_code": "19103"
#             },
#             "name": "Harper's Garden",
#             "phone": "+12678868552",
#             "price": "$$",
#             "rating": 4.0,
#             "review_count": 401,
#             "transactions": [
#                 "delivery",
#                 "pickup"
#             ],
#             "url": "https://www.yelp.com/biz/harpers-garden-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw"
#         },
#         {
#             "alias": "juno-philadelphia",
#             "categories": [
#                 {
#                     "alias": "mexican",
#                     "title": "Mexican"
#                 },
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 },
#                 {
#                     "alias": "cocktailbars",
#                     "title": "Cocktail Bars"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 39.96196,
#                 "longitude": -75.15564
#             },
#             "display_phone": "(267) 639-2892",
#             "distance": 1606.9789710375342,
#             "id": "efxiiiwXpF2pEsCfgeQc8g",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/AZVK76FDoV0iKq-NDtpH0A/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "1033 Spring Garden St",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Philadelphia",
#                 "country": "US",
#                 "display_address": [
#                     "1033 Spring Garden St",
#                     "Philadelphia, PA 19123"
#                 ],
#                 "state": "PA",
#                 "zip_code": "19123"
#             },
#             "name": "Juno",
#             "phone": "+12676392892",
#             "rating": 4.0,
#             "review_count": 107,
#             "transactions": [
#                 "delivery",
#                 "pickup"
#             ],
#             "url": "https://www.yelp.com/biz/juno-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw"
#         },
#         {
#             "alias": "gran-caffe-l-aquila-philadelphia",
#             "categories": [
#                 {
#                     "alias": "coffee",
#                     "title": "Coffee & Tea"
#                 },
#                 {
#                     "alias": "italian",
#                     "title": "Italian"
#                 },
#                 {
#                     "alias": "gelato",
#                     "title": "Gelato"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 39.95127,
#                 "longitude": -75.1695
#             },
#             "display_phone": "(215) 568-5600",
#             "distance": 313.23491060398817,
#             "id": "-cEFKAznWmI0cledNOIQ7w",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/m1s25bq9yvsOcFqP4n9cpg/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "1716 Chestnut St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Philadelphia",
#                 "country": "US",
#                 "display_address": [
#                     "1716 Chestnut St",
#                     "Philadelphia, PA 19103"
#                 ],
#                 "state": "PA",
#                 "zip_code": "19103"
#             },
#             "name": "Gran Caffe L'Aquila",
#             "phone": "+12155685600",
#             "price": "$$",
#             "rating": 4.5,
#             "review_count": 986,
#             "transactions": [
#                 "delivery",
#                 "pickup"
#             ],
#             "url": "https://www.yelp.com/biz/gran-caffe-l-aquila-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw"
#         },
#         {
#             "alias": "butcher-bar-philadelphia-2",
#             "categories": [
#                 {
#                     "alias": "steak",
#                     "title": "Steakhouses"
#                 },
#                 {
#                     "alias": "bars",
#                     "title": "Bars"
#                 },
#                 {
#                     "alias": "comfortfood",
#                     "title": "Comfort Food"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 39.9520301000044,
#                 "longitude": -75.1748960092664
#             },
#             "display_phone": "(215) 563-6328",
#             "distance": 370.1494071100937,
#             "id": "jS3affmkXWrBnidXA-DIfQ",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/HoggPaiFQpIVKkndQEE0IA/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "2034 Chestnut St",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Philadelphia",
#                 "country": "US",
#                 "display_address": [
#                     "2034 Chestnut St",
#                     "Philadelphia, PA 19103"
#                 ],
#                 "state": "PA",
#                 "zip_code": "19103"
#             },
#             "name": "Butcher Bar",
#             "phone": "+12155636328",
#             "price": "$$",
#             "rating": 4.0,
#             "review_count": 643,
#             "transactions": [
#                 "delivery",
#                 "pickup"
#             ],
#             "url": "https://www.yelp.com/biz/butcher-bar-philadelphia-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw"
#         },
#         {
#             "alias": "the-love-philadelphia-2",
#             "categories": [
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 },
#                 {
#                     "alias": "breakfast_brunch",
#                     "title": "Breakfast & Brunch"
#                 },
#                 {
#                     "alias": "burgers",
#                     "title": "Burgers"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 39.95077,
#                 "longitude": -75.17085
#             },
#             "display_phone": "(215) 433-1555",
#             "distance": 347.22754356160016,
#             "id": "dChRGpit9fM_kZK5pafNyA",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/S-SOym855Q6uygm3KLbFHg/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "130 S 18th St",
#                 "address2": null,
#                 "address3": null,
#                 "city": "Philadelphia",
#                 "country": "US",
#                 "display_address": [
#                     "130 S 18th St",
#                     "Philadelphia, PA 19103"
#                 ],
#                 "state": "PA",
#                 "zip_code": "19103"
#             },
#             "name": "The Love",
#             "phone": "+12154331555",
#             "price": "$$$",
#             "rating": 4.0,
#             "review_count": 502,
#             "transactions": [
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/the-love-philadelphia-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw"
#         },
#         {
#             "alias": "suraya-philadelphia-2",
#             "categories": [
#                 {
#                     "alias": "lebanese",
#                     "title": "Lebanese"
#                 },
#                 {
#                     "alias": "gourmet",
#                     "title": "Specialty Food"
#                 },
#                 {
#                     "alias": "coffee",
#                     "title": "Coffee & Tea"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 39.9736865005167,
#                 "longitude": -75.1339557766914
#             },
#             "display_phone": "(215) 302-1900",
#             "distance": 3869.8516233332284,
#             "id": "vUrTGX_7HxqeoQ_6QCVz6g",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/q6tYSYOcCCRrD7F8lMU3bw/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "1528 Frankford Ave",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Philadelphia",
#                 "country": "US",
#                 "display_address": [
#                     "1528 Frankford Ave",
#                     "Philadelphia, PA 19125"
#                 ],
#                 "state": "PA",
#                 "zip_code": "19125"
#             },
#             "name": "Suraya",
#             "phone": "+12153021900",
#             "price": "$$",
#             "rating": 4.5,
#             "review_count": 957,
#             "transactions": [
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/suraya-philadelphia-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw"
#         },
#         {
#             "alias": "chubby-cattle-philadelphia-5",
#             "categories": [
#                 {
#                     "alias": "chinese",
#                     "title": "Chinese"
#                 },
#                 {
#                     "alias": "hotpot",
#                     "title": "Hot Pot"
#                 },
#                 {
#                     "alias": "seafood",
#                     "title": "Seafood"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 39.95498,
#                 "longitude": -75.15622
#             },
#             "display_phone": "(866) 622-8853",
#             "distance": 1291.7130230735665,
#             "id": "iksVwRfpWymIUUFqw0tXpw",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/ZfoHNW4vJ7NQdUzf0CrKLQ/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "146 N 10th St",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Philadelphia",
#                 "country": "US",
#                 "display_address": [
#                     "146 N 10th St",
#                     "Philadelphia, PA 19107"
#                 ],
#                 "state": "PA",
#                 "zip_code": "19107"
#             },
#             "name": "Chubby Cattle",
#             "phone": "+18666228853",
#             "rating": 4.5,
#             "review_count": 981,
#             "transactions": [
#                 "delivery",
#                 "pickup"
#             ],
#             "url": "https://www.yelp.com/biz/chubby-cattle-philadelphia-5?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw"
#         },
#         {
#             "alias": "village-whiskey-philadelphia",
#             "categories": [
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 },
#                 {
#                     "alias": "burgers",
#                     "title": "Burgers"
#                 },
#                 {
#                     "alias": "whiskeybars",
#                     "title": "Whiskey Bars"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 39.951416594943,
#                 "longitude": -75.173767791736
#             },
#             "display_phone": "(215) 665-1088",
#             "distance": 341.9908864804623,
#             "id": "EtKSTHV5Qx_Q7Aur9o4kQQ",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/uMRM9peN-kk2OvwLqVEJYA/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "118 S 20th St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Philadelphia",
#                 "country": "US",
#                 "display_address": [
#                     "118 S 20th St",
#                     "Philadelphia, PA 19103"
#                 ],
#                 "state": "PA",
#                 "zip_code": "19103"
#             },
#             "name": "Village Whiskey",
#             "phone": "+12156651088",
#             "price": "$$",
#             "rating": 4.0,
#             "review_count": 1528,
#             "transactions": [
#                 "delivery",
#                 "pickup"
#             ],
#             "url": "https://www.yelp.com/biz/village-whiskey-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw"
#         },
#         {
#             "alias": "urban-farmer-philadelphia-philadelphia-2",
#             "categories": [
#                 {
#                     "alias": "tradamerican",
#                     "title": "American (Traditional)"
#                 },
#                 {
#                     "alias": "steak",
#                     "title": "Steakhouses"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 39.957207,
#                 "longitude": -75.1699827
#             },
#             "display_phone": "(215) 963-2788",
#             "distance": 394.79398947464114,
#             "id": "xQE1fuwKCXJEBcJgSSCNbw",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/i30sXmLx8wi2ypOuW-pRJw/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "1850 Benjamin Franklin Pkwy",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Philadelphia",
#                 "country": "US",
#                 "display_address": [
#                     "1850 Benjamin Franklin Pkwy",
#                     "Philadelphia, PA 19103"
#                 ],
#                 "state": "PA",
#                 "zip_code": "19103"
#             },
#             "name": "Urban Farmer Philadelphia",
#             "phone": "+12159632788",
#             "price": "$$$",
#             "rating": 4.0,
#             "review_count": 540,
#             "transactions": [
#                 "delivery",
#                 "pickup"
#             ],
#             "url": "https://www.yelp.com/biz/urban-farmer-philadelphia-philadelphia-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw"
#         },
#         {
#             "alias": "dig-philadelphia",
#             "categories": [
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 39.9512017549924,
#                 "longitude": -75.1680316
#             },
#             "display_phone": "(215) 344-8440",
#             "distance": 394.2447946214543,
#             "id": "yj0SWZvJ0tGwAywoVxPT5A",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/vNFBhwIp-690Tb94xABQ4w/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "1616 Chestnut St",
#                 "address2": null,
#                 "address3": null,
#                 "city": "Philadelphia",
#                 "country": "US",
#                 "display_address": [
#                     "1616 Chestnut St",
#                     "Philadelphia, PA 19103"
#                 ],
#                 "state": "PA",
#                 "zip_code": "19103"
#             },
#             "name": "Dig",
#             "phone": "+12153448440",
#             "price": "$$",
#             "rating": 4.5,
#             "review_count": 72,
#             "transactions": [
#                 "delivery",
#                 "pickup"
#             ],
#             "url": "https://www.yelp.com/biz/dig-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw"
#         },
#         {
#             "alias": "parc-philadelphia-2",
#             "categories": [
#                 {
#                     "alias": "french",
#                     "title": "French"
#                 },
#                 {
#                     "alias": "wine_bars",
#                     "title": "Wine Bars"
#                 },
#                 {
#                     "alias": "breakfast_brunch",
#                     "title": "Breakfast & Brunch"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 39.9491724,
#                 "longitude": -75.1707273
#             },
#             "display_phone": "(215) 545-2262",
#             "distance": 514.1796872022128,
#             "id": "j-qtdD55OLfSqfsWuQTDJg",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/DNFDPj4vUDVRf7fx4JLI7A/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "227 S 18th St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Philadelphia",
#                 "country": "US",
#                 "display_address": [
#                     "227 S 18th St",
#                     "Philadelphia, PA 19103"
#                 ],
#                 "state": "PA",
#                 "zip_code": "19103"
#             },
#             "name": "Parc",
#             "phone": "+12155452262",
#             "price": "$$$",
#             "rating": 4.0,
#             "review_count": 2569,
#             "transactions": [
#                 "delivery",
#                 "pickup"
#             ],
#             "url": "https://www.yelp.com/biz/parc-philadelphia-2?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw"
#         },
#         {
#             "alias": "el-vez-philadelphia",
#             "categories": [
#                 {
#                     "alias": "mexican",
#                     "title": "Mexican"
#                 },
#                 {
#                     "alias": "breakfast_brunch",
#                     "title": "Breakfast & Brunch"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 39.9497020026001,
#                 "longitude": -75.1617702841759
#             },
#             "display_phone": "(215) 928-9800",
#             "distance": 923.2589856593123,
#             "id": "9PZxjhTIU7OgPIzuGi89Ew",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/iCMOOou3Z-ecogc322CzdQ/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "121 S 13th St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Philadelphia",
#                 "country": "US",
#                 "display_address": [
#                     "121 S 13th St",
#                     "Philadelphia, PA 19107"
#                 ],
#                 "state": "PA",
#                 "zip_code": "19107"
#             },
#             "name": "El Vez",
#             "phone": "+12159289800",
#             "price": "$$",
#             "rating": 4.0,
#             "review_count": 3055,
#             "transactions": [
#                 "delivery",
#                 "pickup"
#             ],
#             "url": "https://www.yelp.com/biz/el-vez-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw"
#         },
#         {
#             "alias": "cleavers-philadelphia",
#             "categories": [
#                 {
#                     "alias": "cheesesteaks",
#                     "title": "Cheesesteaks"
#                 },
#                 {
#                     "alias": "beer_and_wine",
#                     "title": "Beer, Wine & Spirits"
#                 },
#                 {
#                     "alias": "sportsbars",
#                     "title": "Sports Bars"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 39.9513931274414,
#                 "longitude": -75.1706237792969
#             },
#             "display_phone": "(215) 515-3828",
#             "distance": 268.68538495919023,
#             "id": "jxEMFqwDJXjCxmcm5t5jVQ",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/jp39Ael4-CfFCzxRll98mw/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "108 S 18th St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Philadelphia",
#                 "country": "US",
#                 "display_address": [
#                     "108 S 18th St",
#                     "Philadelphia, PA 19103"
#                 ],
#                 "state": "PA",
#                 "zip_code": "19103"
#             },
#             "name": "Cleavers",
#             "phone": "+12155153828",
#             "price": "$$",
#             "rating": 4.0,
#             "review_count": 1177,
#             "transactions": [
#                 "delivery",
#                 "pickup"
#             ],
#             "url": "https://www.yelp.com/biz/cleavers-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw"
#         },
#         {
#             "alias": "bar-hygge-philadelphia",
#             "categories": [
#                 {
#                     "alias": "breweries",
#                     "title": "Breweries"
#                 },
#                 {
#                     "alias": "comfortfood",
#                     "title": "Comfort Food"
#                 },
#                 {
#                     "alias": "breakfast_brunch",
#                     "title": "Breakfast & Brunch"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 39.9671254923543,
#                 "longitude": -75.1661240918427
#             },
#             "display_phone": "(215) 765-2274",
#             "distance": 1545.5867297711382,
#             "id": "Mwc3n5Psw9wRaQ22vZWDYQ",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/6FTRuuoT_ExUCF1geg-bHg/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "1720 Fairmount Ave",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Philadelphia",
#                 "country": "US",
#                 "display_address": [
#                     "1720 Fairmount Ave",
#                     "Philadelphia, PA 19130"
#                 ],
#                 "state": "PA",
#                 "zip_code": "19130"
#             },
#             "name": "Bar Hygge",
#             "phone": "+12157652274",
#             "price": "$$",
#             "rating": 4.5,
#             "review_count": 347,
#             "transactions": [
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/bar-hygge-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw"
#         },
#         {
#             "alias": "little-nonnas-philadelphia",
#             "categories": [
#                 {
#                     "alias": "italian",
#                     "title": "Italian"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 39.9477864380196,
#                 "longitude": -75.1618928090843
#             },
#             "display_phone": "(215) 546-2100",
#             "distance": 1036.521920338534,
#             "id": "lKU_kljhbEQKIPaM1Zbqiw",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/uFvTQzlZF6nd23Y8z72hWQ/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "1234 Locust St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Philadelphia",
#                 "country": "US",
#                 "display_address": [
#                     "1234 Locust St",
#                     "Philadelphia, PA 19107"
#                 ],
#                 "state": "PA",
#                 "zip_code": "19107"
#             },
#             "name": "Little Nonna's",
#             "phone": "+12155462100",
#             "price": "$$",
#             "rating": 4.0,
#             "review_count": 1058,
#             "transactions": [
#                 "delivery",
#                 "pickup"
#             ],
#             "url": "https://www.yelp.com/biz/little-nonnas-philadelphia?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw"
#         },
#         {
#             "alias": "jj-thai-cuisine-philadelphia-4",
#             "categories": [
#                 {
#                     "alias": "thai",
#                     "title": "Thai"
#                 },
#                 {
#                     "alias": "asianfusion",
#                     "title": "Asian Fusion"
#                 }
#             ],
#             "coordinates": {
#                 "latitude": 39.9521034288421,
#                 "longitude": -75.1747379090004
#             },
#             "display_phone": "(215) 568-7058",
#             "distance": 354.3990949417516,
#             "id": "vuE1iseFrgNPumUEfHIZZQ",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/hHVnHt3v_aAVnRLpH0efNg/o.jpg",
#             "is_closed": false,
#             "location": {
#                 "address1": "2028 Chestnut St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Philadelphia",
#                 "country": "US",
#                 "display_address": [
#                     "2028 Chestnut St",
#                     "Philadelphia, PA 19103"
#                 ],
#                 "state": "PA",
#                 "zip_code": "19103"
#             },
#             "name": "JJ Thai Cuisine",
#             "phone": "+12155687058",
#             "price": "$$",
#             "rating": 4.5,
#             "review_count": 350,
#             "transactions": [
#                 "delivery"
#             ],
#             "url": "https://www.yelp.com/biz/jj-thai-cuisine-philadelphia-4?adjust_creative=17ti_QiOAFYkxc4WiIVHvw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=17ti_QiOAFYkxc4WiIVHvw"
#         }
#     ],
#     "region": {
#         "center": {
#             "latitude": 39.95378209544653,
#             "longitude": -75.17120361328125
#         }
#     },
#     "total": 4500
# }
